# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import (preprocess_input)
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 32  # ✅ Smaller for BN layers
EPOCHS = 30
LEARNING_RATE = 1e-5  # ✅ Lower for frozen backbone

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 24007

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 19205 | Val samples: 4802

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = preprocess_input(img)  # ✅ For ResNet50: scale to [-1, 1] the same way as pretraining

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === DenseNet50 Model ===
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# ✅ Unfreeze last 30 layers
for layer in base_model.layers:    #[:-30]:
    layer.trainable = False
# for layer in base_model.layers[-30:]:
#     layer.trainable = True

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)  # Important: BN layers training mode ON for partial unfrozen!
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/30
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 1.2772 - accuracy: 0.4370
# 601/601 [==============================] - 139s 222ms/step - loss: 1.2772 - accuracy: 0.4370 - val_loss: 1.0528 - val_accuracy: 0.6045
# Epoch 2/30
# 📉 Learning rate at epoch 2: 0.000010>.] - ETA: 0s - loss: 1.0955 - accuracy: 0.5586
# 601/601 [==============================] - 132s 220ms/step - loss: 1.0956 - accuracy: 0.5586 - val_loss: 0.9613 - val_accuracy: 0.6576
# Epoch 3/30
# 📉 Learning rate at epoch 3: 0.000010>.] - ETA: 0s - loss: 1.0138 - accuracy: 0.6129
# 601/601 [==============================] - 132s 220ms/step - loss: 1.0139 - accuracy: 0.6129 - val_loss: 0.8902 - val_accuracy: 0.7114
# Epoch 4/30
# 📉 Learning rate at epoch 4: 0.000010>.] - ETA: 0s - loss: 0.9617 - accuracy: 0.6495
# 601/601 [==============================] - 132s 220ms/step - loss: 0.9617 - accuracy: 0.6496 - val_loss: 0.8593 - val_accuracy: 0.7282
# Epoch 5/30
# 📉 Learning rate at epoch 5: 0.000010>.] - ETA: 0s - loss: 0.9240 - accuracy: 0.6741
# 601/601 [==============================] - 132s 220ms/step - loss: 0.9240 - accuracy: 0.6741 - val_loss: 0.8300 - val_accuracy: 0.7416
# Epoch 6/30
# 📉 Learning rate at epoch 6: 0.000010>.] - ETA: 0s - loss: 0.9005 - accuracy: 0.6938
# 601/601 [==============================] - 132s 220ms/step - loss: 0.9005 - accuracy: 0.6938 - val_loss: 0.8269 - val_accuracy: 0.7389
# Epoch 7/30
# 📉 Learning rate at epoch 7: 0.000010>.] - ETA: 0s - loss: 0.8811 - accuracy: 0.7097
# 601/601 [==============================] - 132s 220ms/step - loss: 0.8811 - accuracy: 0.7097 - val_loss: 0.7963 - val_accuracy: 0.7645
# Epoch 8/30
# 📉 Learning rate at epoch 8: 0.000010>.] - ETA: 0s - loss: 0.8628 - accuracy: 0.7171
# 601/601 [==============================] - 132s 220ms/step - loss: 0.8630 - accuracy: 0.7169 - val_loss: 0.7896 - val_accuracy: 0.7701
# Epoch 9/30
# 📉 Learning rate at epoch 9: 0.000010>.] - ETA: 0s - loss: 0.8511 - accuracy: 0.7259
# 601/601 [==============================] - 132s 220ms/step - loss: 0.8511 - accuracy: 0.7259 - val_loss: 0.7903 - val_accuracy: 0.7601
# Epoch 10/30
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 0.8397 - accuracy: 0.7344
# 601/601 [==============================] - 133s 221ms/step - loss: 0.8397 - accuracy: 0.7344 - val_loss: 0.7680 - val_accuracy: 0.7874
# Epoch 11/30
# 📉 Learning rate at epoch 11: 0.000010.] - ETA: 0s - loss: 0.8308 - accuracy: 0.7403
# 601/601 [==============================] - 150s 250ms/step - loss: 0.8308 - accuracy: 0.7403 - val_loss: 0.7598 - val_accuracy: 0.7834
# Epoch 12/30
# 📉 Learning rate at epoch 12: 0.000010.] - ETA: 0s - loss: 0.8212 - accuracy: 0.7435
# 601/601 [==============================] - 153s 255ms/step - loss: 0.8212 - accuracy: 0.7436 - val_loss: 0.7551 - val_accuracy: 0.7861
# Epoch 13/30
# 📉 Learning rate at epoch 13: 0.000010.] - ETA: 0s - loss: 0.8133 - accuracy: 0.7476
# 601/601 [==============================] - 142s 236ms/step - loss: 0.8134 - accuracy: 0.7475 - val_loss: 0.7436 - val_accuracy: 0.7899
# Epoch 14/30
# 📉 Learning rate at epoch 14: 0.000010.] - ETA: 0s - loss: 0.8050 - accuracy: 0.7540
# 601/601 [==============================] - 135s 225ms/step - loss: 0.8050 - accuracy: 0.7540 - val_loss: 0.7486 - val_accuracy: 0.7943
# Epoch 15/30
# 📉 Learning rate at epoch 15: 0.000010.] - ETA: 0s - loss: 0.7957 - accuracy: 0.7627
# 601/601 [==============================] - 147s 245ms/step - loss: 0.7957 - accuracy: 0.7627 - val_loss: 0.7307 - val_accuracy: 0.8030
# Epoch 16/30
# 📉 Learning rate at epoch 16: 0.000010.] - ETA: 0s - loss: 0.7848 - accuracy: 0.7698
# 601/601 [==============================] - 154s 256ms/step - loss: 0.7849 - accuracy: 0.7697 - val_loss: 0.7404 - val_accuracy: 0.7951
# Epoch 17/30
# 📉 Learning rate at epoch 17: 0.000010.] - ETA: 0s - loss: 0.7816 - accuracy: 0.7680
# 601/601 [==============================] - 152s 253ms/step - loss: 0.7817 - accuracy: 0.7680 - val_loss: 0.7251 - val_accuracy: 0.8053
# Epoch 18/30
# 📉 Learning rate at epoch 18: 0.000010.] - ETA: 0s - loss: 0.7778 - accuracy: 0.7730
# 601/601 [==============================] - 148s 246ms/step - loss: 0.7777 - accuracy: 0.7731 - val_loss: 0.7191 - val_accuracy: 0.8032
# Epoch 19/30
# 📉 Learning rate at epoch 19: 0.000010.] - ETA: 0s - loss: 0.7729 - accuracy: 0.7783
# 601/601 [==============================] - 136s 226ms/step - loss: 0.7728 - accuracy: 0.7783 - val_loss: 0.7115 - val_accuracy: 0.8065
# Epoch 20/30
# 📉 Learning rate at epoch 20: 0.000010.] - ETA: 0s - loss: 0.7652 - accuracy: 0.7803
# 601/601 [==============================] - 137s 228ms/step - loss: 0.7652 - accuracy: 0.7803 - val_loss: 0.7107 - val_accuracy: 0.8167
# Epoch 21/30
# 📉 Learning rate at epoch 21: 0.000010.] - ETA: 0s - loss: 0.7632 - accuracy: 0.7803
# 601/601 [==============================] - 133s 221ms/step - loss: 0.7633 - accuracy: 0.7802 - val_loss: 0.7126 - val_accuracy: 0.8074
# Epoch 22/30
# 📉 Learning rate at epoch 22: 0.000010.] - ETA: 0s - loss: 0.7596 - accuracy: 0.7846
# 601/601 [==============================] - 133s 221ms/step - loss: 0.7596 - accuracy: 0.7846 - val_loss: 0.7146 - val_accuracy: 0.8101
# Epoch 23/30
# 📉 Learning rate at epoch 23: 0.000010.] - ETA: 0s - loss: 0.7557 - accuracy: 0.7861
# 601/601 [==============================] - 133s 222ms/step - loss: 0.7556 - accuracy: 0.7862 - val_loss: 0.7010 - val_accuracy: 0.8215
# Epoch 24/30
# 📉 Learning rate at epoch 24: 0.000010.] - ETA: 0s - loss: 0.7480 - accuracy: 0.7913
# 601/601 [==============================] - 133s 221ms/step - loss: 0.7479 - accuracy: 0.7914 - val_loss: 0.6929 - val_accuracy: 0.8251
# Epoch 25/30
# 📉 Learning rate at epoch 25: 0.000010.] - ETA: 0s - loss: 0.7461 - accuracy: 0.7924
# 601/601 [==============================] - 133s 221ms/step - loss: 0.7461 - accuracy: 0.7924 - val_loss: 0.7093 - val_accuracy: 0.8147
# Epoch 26/30
# 📉 Learning rate at epoch 26: 0.000010.] - ETA: 0s - loss: 0.7431 - accuracy: 0.7932
# 601/601 [==============================] - 133s 222ms/step - loss: 0.7431 - accuracy: 0.7931 - val_loss: 0.6840 - val_accuracy: 0.8317
# Epoch 27/30
# 📉 Learning rate at epoch 27: 0.000010.] - ETA: 0s - loss: 0.7367 - accuracy: 0.7998
# 601/601 [==============================] - 133s 221ms/step - loss: 0.7367 - accuracy: 0.7998 - val_loss: 0.6876 - val_accuracy: 0.8195
# Epoch 28/30
# 📉 Learning rate at epoch 28: 0.000010.] - ETA: 0s - loss: 0.7343 - accuracy: 0.7998
# 601/601 [==============================] - 133s 221ms/step - loss: 0.7343 - accuracy: 0.7997 - val_loss: 0.6870 - val_accuracy: 0.8272
# Epoch 29/30
# 📉 Learning rate at epoch 29: 0.000010.] - ETA: 0s - loss: 0.7276 - accuracy: 0.8056
# 601/601 [==============================] - 133s 222ms/step - loss: 0.7277 - accuracy: 0.8055 - val_loss: 0.6751 - val_accuracy: 0.8359
# Epoch 30/30
# 📉 Learning rate at epoch 30: 0.000010.] - ETA: 0s - loss: 0.7272 - accuracy: 0.8048
# 601/601 [==============================] - 133s 222ms/step - loss: 0.7273 - accuracy: 0.8047 - val_loss: 0.6751 - val_accuracy: 0.8355

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\aug_noaug\DenseNet121_Phase1_aug_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 1s 1s/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.94      0.95      0.94       720
#        BLAST       0.83      0.72      0.77      1423
#    BROWNSPOT       0.84      0.80      0.82      1116
#      HEALTHY       0.80      0.91      0.85      1543
#
#     accuracy                           0.83      4802
#    macro avg       0.85      0.85      0.85      4802
# weighted avg       0.84      0.83      0.83      4802
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\aug_noaug\DenseNet121_Phase1_aug_noaug.h5
