# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.nasnet import preprocess_input as nasnet_preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
# IMPORTANT: Set IMG_SIZE to (331, 331) for NASNetLarge
IMG_SIZE = (224, 224)

BATCH_SIZE = 16
EPOCHS = 60
LEARNING_RATE = 1e-5

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 24007

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 19205 | Val samples: 4802

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    # This line will resize your 224x224 images to IMG_SIZE (331, 331)
    img = tf.image.resize(img, IMG_SIZE)

    img = nasnet_preprocess_input(img)

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === NASNet Model (Phase 2) ===
# Load the model saved from Phase 1.
# Make sure this path points to your saved NASNetLarge model from Phase 1.

MODEL_PATH_PHASE1 = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\aug_noaug\NASNetMobile_Phase1_aug_noaug.h5"

model = load_model(MODEL_PATH_PHASE1)

# Unfreeze all layers for fine-tuning in Phase 2
for layer in model.layers:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/60
# 📉 Learning rate at epoch 1: 0.000010====] - ETA: 0s - loss: 0.6408 - accuracy: 0.7998
# 1201/1201 [==============================] - 347s 274ms/step - loss: 0.6408 - accuracy: 0.7998 - val_loss: 0.5225 - val_accuracy: 0.8634
# Epoch 2/60
# 📉 Learning rate at epoch 2: 0.000010====] - ETA: 0s - loss: 0.5285 - accuracy: 0.8608
# 1201/1201 [==============================] - 329s 274ms/step - loss: 0.5285 - accuracy: 0.8608 - val_loss: 0.4692 - val_accuracy: 0.8855
# Epoch 3/60
# 📉 Learning rate at epoch 3: 0.000010====] - ETA: 0s - loss: 0.4671 - accuracy: 0.8908
# 1201/1201 [==============================] - 292s 243ms/step - loss: 0.4671 - accuracy: 0.8908 - val_loss: 0.4016 - val_accuracy: 0.9190
# Epoch 4/60
# 📉 Learning rate at epoch 4: 0.000010====] - ETA: 0s - loss: 0.4212 - accuracy: 0.9136
# 1201/1201 [==============================] - 268s 223ms/step - loss: 0.4212 - accuracy: 0.9136 - val_loss: 0.3583 - val_accuracy: 0.9423
# Epoch 5/60
# 📉 Learning rate at epoch 5: 0.000010====] - ETA: 0s - loss: 0.3808 - accuracy: 0.9339
# 1201/1201 [==============================] - 277s 231ms/step - loss: 0.3808 - accuracy: 0.9339 - val_loss: 0.3525 - val_accuracy: 0.9413
# Epoch 6/60
# 📉 Learning rate at epoch 6: 0.000010====] - ETA: 0s - loss: 0.3497 - accuracy: 0.9475
# 1201/1201 [==============================] - 274s 228ms/step - loss: 0.3497 - accuracy: 0.9475 - val_loss: 0.3172 - val_accuracy: 0.9606
# Epoch 7/60
# 📉 Learning rate at epoch 7: 0.000010====] - ETA: 0s - loss: 0.3291 - accuracy: 0.9574
# 1201/1201 [==============================] - 247s 205ms/step - loss: 0.3291 - accuracy: 0.9574 - val_loss: 0.2805 - val_accuracy: 0.9752
# Epoch 8/60
# 📉 Learning rate at epoch 8: 0.000010====] - ETA: 0s - loss: 0.3087 - accuracy: 0.9659
# 1201/1201 [==============================] - 248s 206ms/step - loss: 0.3087 - accuracy: 0.9659 - val_loss: 0.2731 - val_accuracy: 0.9788
# Epoch 9/60
# 📉 Learning rate at epoch 9: 0.000010====] - ETA: 0s - loss: 0.2926 - accuracy: 0.9719
# 1201/1201 [==============================] - 275s 229ms/step - loss: 0.2926 - accuracy: 0.9719 - val_loss: 0.2624 - val_accuracy: 0.9808
# Epoch 10/60
# 📉 Learning rate at epoch 10: 0.000010===] - ETA: 0s - loss: 0.2780 - accuracy: 0.9790
# 1201/1201 [==============================] - 269s 224ms/step - loss: 0.2780 - accuracy: 0.9790 - val_loss: 0.2459 - val_accuracy: 0.9890
# Epoch 11/60
# 📉 Learning rate at epoch 11: 0.000010===] - ETA: 0s - loss: 0.2621 - accuracy: 0.9845
# 1201/1201 [==============================] - 308s 257ms/step - loss: 0.2621 - accuracy: 0.9845 - val_loss: 0.2412 - val_accuracy: 0.9900
# Epoch 12/60
# 📉 Learning rate at epoch 12: 0.000010===] - ETA: 0s - loss: 0.2554 - accuracy: 0.9866
# 1201/1201 [==============================] - 274s 228ms/step - loss: 0.2554 - accuracy: 0.9866 - val_loss: 0.2315 - val_accuracy: 0.9940
# Epoch 13/60
# 📉 Learning rate at epoch 13: 0.000010===] - ETA: 0s - loss: 0.2443 - accuracy: 0.9919
# 1201/1201 [==============================] - 287s 239ms/step - loss: 0.2443 - accuracy: 0.9919 - val_loss: 0.2312 - val_accuracy: 0.9944
# Epoch 14/60
# 📉 Learning rate at epoch 14: 0.000010===] - ETA: 0s - loss: 0.2401 - accuracy: 0.9929
# 1201/1201 [==============================] - 250s 208ms/step - loss: 0.2401 - accuracy: 0.9929 - val_loss: 0.2233 - val_accuracy: 0.9971
# Epoch 15/60
# 📉 Learning rate at epoch 15: 0.000010===] - ETA: 0s - loss: 0.2339 - accuracy: 0.9946
# 1201/1201 [==============================] - 246s 205ms/step - loss: 0.2339 - accuracy: 0.9946 - val_loss: 0.2169 - val_accuracy: 0.9992
# Epoch 16/60
# 📉 Learning rate at epoch 16: 0.000010===] - ETA: 0s - loss: 0.2287 - accuracy: 0.9963
# 1201/1201 [==============================] - 246s 205ms/step - loss: 0.2287 - accuracy: 0.9963 - val_loss: 0.2169 - val_accuracy: 0.9977
# Epoch 17/60
# 📉 Learning rate at epoch 17: 0.000010===] - ETA: 0s - loss: 0.2243 - accuracy: 0.9973
# 1201/1201 [==============================] - 246s 205ms/step - loss: 0.2243 - accuracy: 0.9973 - val_loss: 0.2168 - val_accuracy: 0.9973
# Epoch 18/60
# 📉 Learning rate at epoch 18: 0.000010===] - ETA: 0s - loss: 0.2235 - accuracy: 0.9972
# 1201/1201 [==============================] - 246s 205ms/step - loss: 0.2235 - accuracy: 0.9972 - val_loss: 0.2139 - val_accuracy: 0.9992
# Epoch 19/60
# 📉 Learning rate at epoch 19: 0.000010===] - ETA: 0s - loss: 0.2224 - accuracy: 0.9972
# 1201/1201 [==============================] - 246s 205ms/step - loss: 0.2224 - accuracy: 0.9972 - val_loss: 0.2141 - val_accuracy: 0.9975
# Epoch 20/60
# 📉 Learning rate at epoch 20: 0.000010===] - ETA: 0s - loss: 0.2171 - accuracy: 0.9988
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2171 - accuracy: 0.9988 - val_loss: 0.2111 - val_accuracy: 0.9985
# Epoch 21/60
# 📉 Learning rate at epoch 21: 0.000010===] - ETA: 0s - loss: 0.2196 - accuracy: 0.9973
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2196 - accuracy: 0.9973 - val_loss: 0.2130 - val_accuracy: 0.9994
# Epoch 22/60
# 📉 Learning rate at epoch 22: 0.000010===] - ETA: 0s - loss: 0.2148 - accuracy: 0.9989
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2148 - accuracy: 0.9989 - val_loss: 0.2158 - val_accuracy: 0.9965
# Epoch 23/60
# 📉 Learning rate at epoch 23: 0.000010===] - ETA: 0s - loss: 0.2161 - accuracy: 0.9984
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2161 - accuracy: 0.9984 - val_loss: 0.2075 - val_accuracy: 0.9994
# Epoch 24/60
# 📉 Learning rate at epoch 24: 0.000010===] - ETA: 0s - loss: 0.2151 - accuracy: 0.9984
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2151 - accuracy: 0.9984 - val_loss: 0.2083 - val_accuracy: 0.9983
# Epoch 25/60
# 📉 Learning rate at epoch 25: 0.000010===] - ETA: 0s - loss: 0.2128 - accuracy: 0.9989
# 1201/1201 [==============================] - 248s 206ms/step - loss: 0.2128 - accuracy: 0.9989 - val_loss: 0.2045 - val_accuracy: 1.0000
# Epoch 26/60
# 📉 Learning rate at epoch 26: 0.000010===] - ETA: 0s - loss: 0.2155 - accuracy: 0.9974
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2155 - accuracy: 0.9974 - val_loss: 0.2080 - val_accuracy: 0.9985
# Epoch 27/60
# 📉 Learning rate at epoch 27: 0.000010===] - ETA: 0s - loss: 0.2117 - accuracy: 0.9992
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2117 - accuracy: 0.9992 - val_loss: 0.2050 - val_accuracy: 0.9992
# Epoch 28/60
# 📉 Learning rate at epoch 28: 0.000010===] - ETA: 0s - loss: 0.2133 - accuracy: 0.9980
# 1201/1201 [==============================] - 248s 206ms/step - loss: 0.2133 - accuracy: 0.9980 - val_loss: 0.2063 - val_accuracy: 0.9996
# Epoch 29/60
# 📉 Learning rate at epoch 29: 0.000010===] - ETA: 0s - loss: 0.2093 - accuracy: 0.9997
# 1201/1201 [==============================] - 249s 207ms/step - loss: 0.2093 - accuracy: 0.9997 - val_loss: 0.2034 - val_accuracy: 1.0000
# Epoch 30/60
# 📉 Learning rate at epoch 30: 0.000010===] - ETA: 0s - loss: 0.2138 - accuracy: 0.9974
# 1201/1201 [==============================] - 248s 206ms/step - loss: 0.2138 - accuracy: 0.9974 - val_loss: 0.2040 - val_accuracy: 0.9998
# Epoch 31/60
# 📉 Learning rate at epoch 31: 0.000010===] - ETA: 0s - loss: 0.2069 - accuracy: 1.0000
# 1201/1201 [==============================] - 247s 205ms/step - loss: 0.2069 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 1.0000
# Epoch 32/60
# 📉 Learning rate at epoch 32: 0.000010===] - ETA: 0s - loss: 0.2171 - accuracy: 0.9962
# 1201/1201 [==============================] - 246s 205ms/step - loss: 0.2171 - accuracy: 0.9962 - val_loss: 0.2042 - val_accuracy: 0.9998
# Epoch 33/60
# 📉 Learning rate at epoch 33: 0.000010===] - ETA: 0s - loss: 0.2124 - accuracy: 0.9976
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2124 - accuracy: 0.9976 - val_loss: 0.2071 - val_accuracy: 0.9983
# Epoch 34/60
# 📉 Learning rate at epoch 34: 0.000010===] - ETA: 0s - loss: 0.2073 - accuracy: 0.9996
# 1201/1201 [==============================] - 248s 206ms/step - loss: 0.2073 - accuracy: 0.9996 - val_loss: 0.2029 - val_accuracy: 1.0000
# Epoch 35/60
# 📉 Learning rate at epoch 35: 0.000010===] - ETA: 0s - loss: 0.2111 - accuracy: 0.9978
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2111 - accuracy: 0.9978 - val_loss: 0.2759 - val_accuracy: 0.9723
# Epoch 36/60
# 📉 Learning rate at epoch 36: 0.000010===] - ETA: 0s - loss: 0.2171 - accuracy: 0.9957
# 1201/1201 [==============================] - 247s 206ms/step - loss: 0.2171 - accuracy: 0.9957 - val_loss: 0.2070 - val_accuracy: 0.9983
# Epoch 37/60
# 📉 Learning rate at epoch 37: 0.000010===] - ETA: 0s - loss: 0.2080 - accuracy: 0.9993
# 1201/1201 [==============================] - 248s 206ms/step - loss: 0.2080 - accuracy: 0.9993 - val_loss: 0.2234 - val_accuracy: 0.9921
# Epoch 38/60
# 📉 Learning rate at epoch 38: 0.000010===] - ETA: 0s - loss: 0.2097 - accuracy: 0.9983
# 1201/1201 [==============================] - 248s 206ms/step - loss: 0.2097 - accuracy: 0.9983 - val_loss: 0.2120 - val_accuracy: 0.9963

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\aug_noaug\NASNetMobile_Phase2_aug_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       1.00      1.00      1.00       696
#        BLAST       1.00      1.00      1.00      1401
#    BROWNSPOT       1.00      1.00      1.00      1086
#      HEALTHY       1.00      1.00      1.00      1619
#
#     accuracy                           1.00      4802
#    macro avg       1.00      1.00      1.00      4802
# weighted avg       1.00      1.00      1.00      4802
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\aug_noaug\NASNetMobile_Phase2_aug_noaug.h5
