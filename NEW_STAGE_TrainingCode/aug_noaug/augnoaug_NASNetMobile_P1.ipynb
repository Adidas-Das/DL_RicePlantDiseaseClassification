# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
# Import NASNetLarge or NASNetMobile
from tensorflow.keras.applications import NASNetLarge, NASNetMobile
# Import their respective preprocess_input functions
from tensorflow.keras.applications.nasnet import preprocess_input as nasnet_preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
# NASNetLarge expects input shape (331, 331), NASNetMobile expects (224, 224)
# Choose the appropriate IMG_SIZE based on your chosen NASNet model
# IMG_SIZE = (331, 331) # For NASNetLarge
IMG_SIZE = (224, 224) # For NASNetMobile
BATCH_SIZE = 32
EPOCHS = 30
LEARNING_RATE = 1e-5

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 24007

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 19205 | Val samples: 4802

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    # Use NASNet's preprocess_input function
    img = nasnet_preprocess_input(img)

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === NASNet Model ===
# Choose NASNetLarge or NASNetMobile
base_model = NASNetMobile(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))


# Unfreeze last few layers (adjust as needed for NASNet)
# NASNet models have a different layer structure than ResNet.
# Instead of unfreezing a fixed number of layers, it's often better to unfreeze
# a block or unfreeze all layers and use a very low learning rate.
# For simplicity and to adhere to "only modify what is absolutely necessary",
# we will keep the entire base model frozen for this phase 1 training.
# If you want to unfreeze, you would need to inspect the model.summary()
# to identify appropriate layers/blocks.
for layer in base_model.layers:
    layer.trainable = False

inputs = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/30
# 📉 Learning rate at epoch 1: 0.000010>.] - ETA: 0s - loss: 1.2755 - accuracy: 0.4278
# 601/601 [==============================] - 121s 182ms/step - loss: 1.2754 - accuracy: 0.4279 - val_loss: 1.1087 - val_accuracy: 0.5627
# Epoch 2/30
# 📉 Learning rate at epoch 2: 0.000010>.] - ETA: 0s - loss: 1.1282 - accuracy: 0.5406
# 601/601 [==============================] - 107s 178ms/step - loss: 1.1281 - accuracy: 0.5406 - val_loss: 1.0249 - val_accuracy: 0.6172
# Epoch 3/30
# 📉 Learning rate at epoch 3: 0.000010>.] - ETA: 0s - loss: 1.0617 - accuracy: 0.5868
# 601/601 [==============================] - 106s 177ms/step - loss: 1.0617 - accuracy: 0.5867 - val_loss: 0.9756 - val_accuracy: 0.6447
# Epoch 4/30
# 📉 Learning rate at epoch 4: 0.000010>.] - ETA: 0s - loss: 1.0164 - accuracy: 0.6194
# 601/601 [==============================] - 107s 178ms/step - loss: 1.0164 - accuracy: 0.6194 - val_loss: 0.9355 - val_accuracy: 0.6722
# Epoch 5/30
# 📉 Learning rate at epoch 5: 0.000010>.] - ETA: 0s - loss: 0.9856 - accuracy: 0.6406
# 601/601 [==============================] - 108s 180ms/step - loss: 0.9856 - accuracy: 0.6406 - val_loss: 0.9103 - val_accuracy: 0.6874
# Epoch 6/30
# 📉 Learning rate at epoch 6: 0.000010>.] - ETA: 0s - loss: 0.9670 - accuracy: 0.6519
# 601/601 [==============================] - 108s 179ms/step - loss: 0.9670 - accuracy: 0.6519 - val_loss: 0.9135 - val_accuracy: 0.6872
# Epoch 7/30
# 📉 Learning rate at epoch 7: 0.000010>.] - ETA: 0s - loss: 0.9487 - accuracy: 0.6629
# 601/601 [==============================] - 107s 177ms/step - loss: 0.9487 - accuracy: 0.6629 - val_loss: 0.8897 - val_accuracy: 0.6949
# Epoch 8/30
# 📉 Learning rate at epoch 8: 0.000010>.] - ETA: 0s - loss: 0.9349 - accuracy: 0.6760
# 601/601 [==============================] - 106s 177ms/step - loss: 0.9351 - accuracy: 0.6760 - val_loss: 0.8836 - val_accuracy: 0.6960
# Epoch 9/30
# 📉 Learning rate at epoch 9: 0.000010>.] - ETA: 0s - loss: 0.9210 - accuracy: 0.6780
# 601/601 [==============================] - 107s 177ms/step - loss: 0.9210 - accuracy: 0.6781 - val_loss: 0.8742 - val_accuracy: 0.7022
# Epoch 10/30
# 📉 Learning rate at epoch 10: 0.000010.] - ETA: 0s - loss: 0.9142 - accuracy: 0.6809
# 601/601 [==============================] - 107s 177ms/step - loss: 0.9142 - accuracy: 0.6809 - val_loss: 0.8618 - val_accuracy: 0.7191
# 601/601 [==============================] - 105s 175ms/step - loss: 0.8274 - accuracy: 0.7388 - val_loss: 0.7746 - val_accuracy: 0.7747
# Epoch 24/30
# 📉 Learning rate at epoch 24: 0.000010.] - ETA: 0s - loss: 0.8198 - accuracy: 0.7455
# 601/601 [==============================] - 106s 177ms/step - loss: 0.8198 - accuracy: 0.7455 - val_loss: 0.7612 - val_accuracy: 0.7822
# Epoch 25/30
# 📉 Learning rate at epoch 25: 0.000010.] - ETA: 0s - loss: 0.8173 - accuracy: 0.7478
# 601/601 [==============================] - 106s 177ms/step - loss: 0.8173 - accuracy: 0.7477 - val_loss: 0.7793 - val_accuracy: 0.7695
# Epoch 26/30
# 📉 Learning rate at epoch 26: 0.000010.] - ETA: 0s - loss: 0.8135 - accuracy: 0.7521
# 601/601 [==============================] - 106s 177ms/step - loss: 0.8135 - accuracy: 0.7521 - val_loss: 0.7484 - val_accuracy: 0.7901
# Epoch 27/30
# 📉 Learning rate at epoch 27: 0.000010.] - ETA: 0s - loss: 0.8095 - accuracy: 0.7568
# 601/601 [==============================] - 106s 177ms/step - loss: 0.8095 - accuracy: 0.7568 - val_loss: 0.7457 - val_accuracy: 0.7928
# Epoch 28/30
# 📉 Learning rate at epoch 28: 0.000010.] - ETA: 0s - loss: 0.8077 - accuracy: 0.7535
# 601/601 [==============================] - 106s 177ms/step - loss: 0.8077 - accuracy: 0.7534 - val_loss: 0.7549 - val_accuracy: 0.7905
# Epoch 29/30
# 📉 Learning rate at epoch 29: 0.000010.] - ETA: 0s - loss: 0.8017 - accuracy: 0.7596
# 601/601 [==============================] - 106s 177ms/step - loss: 0.8018 - accuracy: 0.7595 - val_loss: 0.7431 - val_accuracy: 0.7965
# Epoch 30/30
# 📉 Learning rate at epoch 30: 0.000010.] - ETA: 0s - loss: 0.7978 - accuracy: 0.7645
# 601/601 [==============================] - 107s 178ms/step - loss: 0.7978 - accuracy: 0.7644 - val_loss: 0.7392 - val_accuracy: 0.7953

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
# Update save path to reflect NASNet model
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\aug_noaug\NASNetMobile_Phase1_aug_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 3s 3s/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.91      0.90      0.90       720
#        BLAST       0.77      0.65      0.71      1423
#    BROWNSPOT       0.82      0.70      0.75      1116
#      HEALTHY       0.74      0.93      0.82      1543
#
#     accuracy                           0.79      4802
#    macro avg       0.81      0.79      0.80      4802
# weighted avg       0.79      0.79      0.78      4802
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\aug_noaug\NASNetMobile_Phase1_aug_noaug.h5
