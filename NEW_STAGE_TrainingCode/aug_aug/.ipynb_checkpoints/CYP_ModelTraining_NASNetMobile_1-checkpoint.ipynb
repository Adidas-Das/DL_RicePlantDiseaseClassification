# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
# Import NASNetLarge or NASNetMobile
from tensorflow.keras.applications import NASNetLarge, NASNetMobile
# Import their respective preprocess_input functions
from tensorflow.keras.applications.nasnet import preprocess_input as nasnet_preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASET_F1"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
# NASNetLarge expects input shape (331, 331), NASNetMobile expects (224, 224)
# Choose the appropriate IMG_SIZE based on your chosen NASNet model
# IMG_SIZE = (331, 331) # For NASNetLarge
IMG_SIZE = (224, 224) # For NASNetMobile
BATCH_SIZE = 32
EPOCHS = 30
LEARNING_RATE = 1e-5

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 32460

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 25968 | Val samples: 6492

# %%
# === Color Jitter ===
def color_jitter(image):
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.05)
    return tf.clip_by_value(image, 0.0, 255.0)

# === GridMask ===
def grid_mask(image, d_min=50, d_max=100, ratio=0.5):
    h, w, _ = image.shape
    d = tf.random.uniform([], d_min, d_max, dtype=tf.int32)
    l = tf.cast(tf.cast(d, tf.float32) * ratio, tf.int32)

    mask = tf.ones([h, w], dtype=tf.float32)

    for i in range(0, h, d):
        for j in range(0, w, d):
            y1 = i
            y2 = tf.minimum(i + l, h)
            x1 = j
            x2 = tf.minimum(j + l, w)

            y_range = tf.range(y1, y2)
            x_range = tf.range(x1, x2)
            yy, xx = tf.meshgrid(y_range, x_range, indexing='ij')
            indices = tf.stack([yy, xx], axis=-1)
            indices = tf.reshape(indices, [-1, 2])

            mask = tf.tensor_scatter_nd_update(
                mask,
                indices,
                tf.zeros([(y2 - y1) * (x2 - x1)], dtype=tf.float32)
            )

    mask = tf.expand_dims(mask, axis=-1)
    mask = tf.tile(mask, [1, 1, 3])
    return image * mask

# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = color_jitter(img)
    img = grid_mask(img)

    # Use NASNet's preprocess_input function
    img = nasnet_preprocess_input(img)

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# # === CutMix ===
# def cutmix(images, labels, alpha=1.0):
#     batch_size = tf.shape(images)[0]
#     img_h = tf.shape(images)[1]
#     img_w = tf.shape(images)[2]

#     lam = tfp.distributions.Beta(alpha, alpha).sample([batch_size])

#     rand_idx = tf.random.shuffle(tf.range(batch_size))
#     images2 = tf.gather(images, rand_idx)
#     labels2 = tf.gather(labels, rand_idx)

#     cut_rat = tf.math.sqrt(1. - lam)
#     cut_w = tf.cast(img_w, tf.float32) * cut_rat
#     cut_h = tf.cast(img_h, tf.float32) * cut_rat

#     cx = tf.random.uniform([batch_size], 0, tf.cast(img_w, tf.float32))
#     cy = tf.random.uniform([batch_size], 0, tf.cast(img_h, tf.float32))

#     x1 = tf.cast(cx - cut_w / 2, tf.int32)
#     y1 = tf.cast(cy - cut_h / 2, tf.int32)
#     x2 = tf.cast(cx + cut_w / 2, tf.int32)
#     y2 = tf.cast(cy + cut_h / 2, tf.int32)

#     x1 = tf.clip_by_value(x1, 0, img_w)
#     y1 = tf.clip_by_value(y1, 0, img_h)
#     x2 = tf.clip_by_value(x2, 0, img_w)
#     y2 = tf.clip_by_value(y2, 0, img_h)

#     def apply_cutmix(i):
#         img1 = images[i]
#         img2 = images2[i]
#         bbx1, bby1, bbx2, bby2 = x1[i], y1[i], x2[i], y2[i]

#         mask = tf.pad(
#             tf.zeros([bby2 - bby1, bbx2 - bbx1, 3]),
#             [[bby1, img_h - bby2],
#              [bbx1, img_w - bbx2],
#              [0, 0]],
#             constant_values=1.0
#         )
#         mask = 1.0 - mask
#         mixed = img1 * mask + img2 * (1.0 - mask)

#         area = tf.cast(bbx2 - bbx1, tf.float32) * tf.cast(bby2 - bby1, tf.float32)
#         lam_adjusted = 1.0 - (area / tf.cast(img_w * img_h, tf.float32))
#         new_label = lam_adjusted * labels[i] + (1.0 - lam_adjusted) * labels2[i]

#         return mixed, new_label

#     mixed_images, mixed_labels = tf.map_fn(
#         apply_cutmix,
#         tf.range(batch_size),
#         fn_output_signature=(tf.float32, tf.float32)
#     )

#     return mixed_images, mixed_labels

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
# train_ds = train_ds.map(lambda x, y: cutmix(x, y)).prefetch(tf.data.AUTOTUNE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === NASNet Model ===
# Choose NASNetLarge or NASNetMobile
# base_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
base_model = NASNetMobile(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))


# Unfreeze last few layers (adjust as needed for NASNet)
# NASNet models have a different layer structure than ResNet.
# Instead of unfreezing a fixed number of layers, it's often better to unfreeze
# a block or unfreeze all layers and use a very low learning rate.
# For simplicity and to adhere to "only modify what is absolutely necessary",
# we will keep the entire base model frozen for this phase 1 training.
# If you want to unfreeze, you would need to inspect the model.summary()
# to identify appropriate layers/blocks.
for layer in base_model.layers:
    layer.trainable = False

inputs = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
class_weights = dict(enumerate(class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(CLASSES)),
    y=y_train_int
)))
print("✅ Computed class weights:", class_weights)
# Out:
# ✅ Computed class weights: {0: 0.9976947902259106, 1: 1.0065116279069768, 2: 0.9925087907047851, 3: 1.003400309119011}

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()],
    class_weight=class_weights
)
# Out:
# Epoch 1/30
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 1.3027 - accuracy: 0.4077
# 812/812 [==============================] - 123s 142ms/step - loss: 1.3027 - accuracy: 0.4077 - val_loss: 1.1649 - val_accuracy: 0.5271
# Epoch 2/30
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 1.1824 - accuracy: 0.5023
# 812/812 [==============================] - 112s 138ms/step - loss: 1.1824 - accuracy: 0.5023 - val_loss: 1.0898 - val_accuracy: 0.5672
# Epoch 3/30
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 1.1311 - accuracy: 0.5363
# 812/812 [==============================] - 107s 132ms/step - loss: 1.1311 - accuracy: 0.5363 - val_loss: 1.0584 - val_accuracy: 0.5850
# Epoch 4/30
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 1.0974 - accuracy: 0.5597
# 812/812 [==============================] - 113s 139ms/step - loss: 1.0974 - accuracy: 0.5597 - val_loss: 1.0465 - val_accuracy: 0.5904
# Epoch 5/30
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 1.0728 - accuracy: 0.5744
# 812/812 [==============================] - 112s 138ms/step - loss: 1.0728 - accuracy: 0.5744 - val_loss: 1.0170 - val_accuracy: 0.6055
# Epoch 6/30
# 📉 Learning rate at epoch 6: 0.000010==] - ETA: 0s - loss: 1.0543 - accuracy: 0.5893
# 812/812 [==============================] - 108s 133ms/step - loss: 1.0543 - accuracy: 0.5893 - val_loss: 0.9981 - val_accuracy: 0.6165
# Epoch 7/30
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 1.0372 - accuracy: 0.6006
# 812/812 [==============================] - 108s 133ms/step - loss: 1.0372 - accuracy: 0.6006 - val_loss: 0.9797 - val_accuracy: 0.6328
# Epoch 8/30
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 1.0249 - accuracy: 0.6014
# 812/812 [==============================] - 113s 139ms/step - loss: 1.0249 - accuracy: 0.6014 - val_loss: 0.9607 - val_accuracy: 0.6454
# Epoch 9/30
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 1.0134 - accuracy: 0.6167
# 812/812 [==============================] - 112s 138ms/step - loss: 1.0134 - accuracy: 0.6167 - val_loss: 0.9635 - val_accuracy: 0.6315
# Epoch 10/30
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 1.0010 - accuracy: 0.6222
# 812/812 [==============================] - 112s 138ms/step - loss: 1.0010 - accuracy: 0.6222 - val_loss: 0.9446 - val_accuracy: 0.6536
# Epoch 11/30
# 📉 Learning rate at epoch 11: 0.000010=] - ETA: 0s - loss: 0.9914 - accuracy: 0.6279
# 812/812 [==============================] - 109s 134ms/step - loss: 0.9914 - accuracy: 0.6279 - val_loss: 0.9377 - val_accuracy: 0.6625
# Epoch 12/30
# 📉 Learning rate at epoch 12: 0.000010=] - ETA: 0s - loss: 0.9823 - accuracy: 0.6343
# 812/812 [==============================] - 113s 140ms/step - loss: 0.9823 - accuracy: 0.6343 - val_loss: 0.9469 - val_accuracy: 0.6513
# Epoch 13/30
# 📉 Learning rate at epoch 13: 0.000010=] - ETA: 0s - loss: 0.9781 - accuracy: 0.6382
# 812/812 [==============================] - 111s 137ms/step - loss: 0.9781 - accuracy: 0.6382 - val_loss: 0.9301 - val_accuracy: 0.6565
# Epoch 14/30
# 📉 Learning rate at epoch 14: 0.000010=] - ETA: 0s - loss: 0.9730 - accuracy: 0.6412
# 812/812 [==============================] - 107s 131ms/step - loss: 0.9730 - accuracy: 0.6412 - val_loss: 0.9252 - val_accuracy: 0.6705
# Epoch 15/30
# 📉 Learning rate at epoch 15: 0.000010=] - ETA: 0s - loss: 0.9661 - accuracy: 0.6455
# 812/812 [==============================] - 112s 138ms/step - loss: 0.9661 - accuracy: 0.6455 - val_loss: 0.9168 - val_accuracy: 0.6779
# Epoch 16/30
# 📉 Learning rate at epoch 16: 0.000010=] - ETA: 0s - loss: 0.9624 - accuracy: 0.6473
# 812/812 [==============================] - 109s 135ms/step - loss: 0.9624 - accuracy: 0.6473 - val_loss: 0.9138 - val_accuracy: 0.6731
# Epoch 17/30
# 📉 Learning rate at epoch 17: 0.000010=] - ETA: 0s - loss: 0.9563 - accuracy: 0.6552
# 812/812 [==============================] - 108s 133ms/step - loss: 0.9563 - accuracy: 0.6552 - val_loss: 0.9137 - val_accuracy: 0.6751
# Epoch 18/30
# 📉 Learning rate at epoch 18: 0.000010=] - ETA: 0s - loss: 0.9515 - accuracy: 0.6537
# 812/812 [==============================] - 110s 135ms/step - loss: 0.9515 - accuracy: 0.6537 - val_loss: 0.9022 - val_accuracy: 0.6865
# Epoch 19/30
# 📉 Learning rate at epoch 19: 0.000010=] - ETA: 0s - loss: 0.9445 - accuracy: 0.6592
# 812/812 [==============================] - 113s 139ms/step - loss: 0.9445 - accuracy: 0.6592 - val_loss: 0.8994 - val_accuracy: 0.6751
# Epoch 20/30
# 📉 Learning rate at epoch 20: 0.000010=] - ETA: 0s - loss: 0.9435 - accuracy: 0.6607
# 812/812 [==============================] - 111s 137ms/step - loss: 0.9435 - accuracy: 0.6607 - val_loss: 0.8878 - val_accuracy: 0.6895
# Epoch 21/30
# 📉 Learning rate at epoch 21: 0.000010=] - ETA: 0s - loss: 0.9345 - accuracy: 0.6689
# 812/812 [==============================] - 112s 137ms/step - loss: 0.9345 - accuracy: 0.6689 - val_loss: 0.8923 - val_accuracy: 0.6910
# Epoch 22/30
# 📉 Learning rate at epoch 22: 0.000010=] - ETA: 0s - loss: 0.9344 - accuracy: 0.6635
# 812/812 [==============================] - 113s 139ms/step - loss: 0.9344 - accuracy: 0.6635 - val_loss: 0.8829 - val_accuracy: 0.6981
# Epoch 23/30
# 📉 Learning rate at epoch 23: 0.000010=] - ETA: 0s - loss: 0.9308 - accuracy: 0.6691
# 812/812 [==============================] - 111s 137ms/step - loss: 0.9308 - accuracy: 0.6691 - val_loss: 0.8806 - val_accuracy: 0.6970
# Epoch 24/30
# 📉 Learning rate at epoch 24: 0.000010=] - ETA: 0s - loss: 0.9234 - accuracy: 0.6744
# 812/812 [==============================] - 105s 130ms/step - loss: 0.9234 - accuracy: 0.6744 - val_loss: 0.8730 - val_accuracy: 0.7053
# Epoch 25/30
# 📉 Learning rate at epoch 25: 0.000010.] - ETA: 0s - loss: 0.9163 - accuracy: 0.6803
# 812/812 [==============================] - 106s 130ms/step - loss: 0.9163 - accuracy: 0.6803 - val_loss: 0.8892 - val_accuracy: 0.6841
# Epoch 26/30
# 📉 Learning rate at epoch 26: 0.000010=] - ETA: 0s - loss: 0.9143 - accuracy: 0.6773
# 812/812 [==============================] - 112s 137ms/step - loss: 0.9143 - accuracy: 0.6773 - val_loss: 0.8665 - val_accuracy: 0.7072
# Epoch 27/30
# 📉 Learning rate at epoch 27: 0.000010=] - ETA: 0s - loss: 0.9132 - accuracy: 0.6796
# 812/812 [==============================] - 108s 133ms/step - loss: 0.9132 - accuracy: 0.6796 - val_loss: 0.8704 - val_accuracy: 0.7073
# Epoch 28/30
# 📉 Learning rate at epoch 28: 0.000010=] - ETA: 0s - loss: 0.9114 - accuracy: 0.6811
# 812/812 [==============================] - 105s 129ms/step - loss: 0.9114 - accuracy: 0.6811 - val_loss: 0.8682 - val_accuracy: 0.6972
# Epoch 29/30
# 📉 Learning rate at epoch 29: 0.000010=] - ETA: 0s - loss: 0.9019 - accuracy: 0.6881
# 812/812 [==============================] - 105s 130ms/step - loss: 0.9019 - accuracy: 0.6881 - val_loss: 0.8561 - val_accuracy: 0.7141
# Epoch 30/30
# 📉 Learning rate at epoch 30: 0.000010=] - ETA: 0s - loss: 0.9013 - accuracy: 0.6899
# 812/812 [==============================] - 106s 131ms/step - loss: 0.9013 - accuracy: 0.6899 - val_loss: 0.8527 - val_accuracy: 0.7206

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
# Update save path to reflect NASNet model
# SAVE_PATH = r"Desktop\Machine Learning\CP_MODEL\NASNetLarge_Phase1_CutMix_GridMask.h5"
SAVE_PATH = r"Desktop\Machine Learning\CP_MODEL\NASNetMobile_Phase1_GridMask.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 2s 2s/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.83      0.83      0.83      1666
#        BLAST       0.59      0.55      0.57      1608
#    BROWNSPOT       0.77      0.67      0.72      1614
#      HEALTHY       0.67      0.80      0.73      1604
#
#     accuracy                           0.71      6492
#    macro avg       0.71      0.71      0.71      6492
# weighted avg       0.71      0.71      0.71      6492
# ✅ Model saved at: Desktop\Machine Learning\CP_MODEL\NASNetMobile_Phase1_GridMask.h5
