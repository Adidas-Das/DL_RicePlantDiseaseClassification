# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.xception import (preprocess_input)
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
# from tensorflow.keras.applications.resnet import preprocess_input

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 8  # ✅ Smaller for BN layers
EPOCHS = 60
LEARNING_RATE = 1e-5  # ✅ Lower for frozen backbone

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "og")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 4913

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 3930 | Val samples: 983

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)
    
    img = preprocess_input(img)  # ✅ For ResNet50: scale to [-1, 1] the same way as pretraining

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
model = load_model(r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\Xception_Phase1_og_noaug.h5")
for layer in model.layers:
    layer.trainable = True
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        # If using a scheduler, it might be a callable or tensor
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch + 1}: {lr:.6f}")


# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/60
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0656s vs `on_train_batch_end` time: 0.1148s). Check your callbacks.
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 0.5892 - accuracy: 0.8254
# 492/492 [==============================] - 103s 195ms/step - loss: 0.5892 - accuracy: 0.8254 - val_loss: 0.4351 - val_accuracy: 0.9044
# Epoch 2/60
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 0.4799 - accuracy: 0.8847
# 492/492 [==============================] - 96s 196ms/step - loss: 0.4799 - accuracy: 0.8847 - val_loss: 0.3755 - val_accuracy: 0.9349
# Epoch 3/60
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 0.3992 - accuracy: 0.9262
# 492/492 [==============================] - 96s 194ms/step - loss: 0.3992 - accuracy: 0.9262 - val_loss: 0.3244 - val_accuracy: 0.9512
# Epoch 4/60
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 0.3556 - accuracy: 0.9448
# 492/492 [==============================] - 96s 195ms/step - loss: 0.3556 - accuracy: 0.9448 - val_loss: 0.2753 - val_accuracy: 0.9756
# Epoch 5/60
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 0.3157 - accuracy: 0.9641
# 492/492 [==============================] - 93s 189ms/step - loss: 0.3157 - accuracy: 0.9641 - val_loss: 0.2695 - val_accuracy: 0.9837
# Epoch 6/60
# 📉 Learning rate at epoch 6: 0.000010>.] - ETA: 0s - loss: 0.2923 - accuracy: 0.9735
# 492/492 [==============================] - 83s 169ms/step - loss: 0.2923 - accuracy: 0.9735 - val_loss: 0.2474 - val_accuracy: 0.9949
# Epoch 7/60
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 0.2764 - accuracy: 0.9807
# 492/492 [==============================] - 85s 173ms/step - loss: 0.2764 - accuracy: 0.9807 - val_loss: 0.2452 - val_accuracy: 0.9868
# Epoch 8/60
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 0.2538 - accuracy: 0.9891
# 492/492 [==============================] - 91s 185ms/step - loss: 0.2538 - accuracy: 0.9891 - val_loss: 0.2296 - val_accuracy: 0.9980
# Epoch 9/60
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 0.2455 - accuracy: 0.9916
# 492/492 [==============================] - 94s 191ms/step - loss: 0.2455 - accuracy: 0.9916 - val_loss: 0.2343 - val_accuracy: 0.9949
# Epoch 10/60
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 0.2355 - accuracy: 0.9962
# 492/492 [==============================] - 89s 182ms/step - loss: 0.2355 - accuracy: 0.9962 - val_loss: 0.2217 - val_accuracy: 1.0000
# Epoch 11/60
# 📉 Learning rate at epoch 11: 0.000010=] - ETA: 0s - loss: 0.2304 - accuracy: 0.9972
# 492/492 [==============================] - 92s 187ms/step - loss: 0.2304 - accuracy: 0.9972 - val_loss: 0.2188 - val_accuracy: 1.0000
# Epoch 12/60
# 📉 Learning rate at epoch 12: 0.000010=] - ETA: 0s - loss: 0.2243 - accuracy: 0.9985
# 492/492 [==============================] - 96s 194ms/step - loss: 0.2243 - accuracy: 0.9985 - val_loss: 0.2123 - val_accuracy: 1.0000
# Epoch 13/60
# 📉 Learning rate at epoch 13: 0.000010=] - ETA: 0s - loss: 0.2205 - accuracy: 0.9992
# 492/492 [==============================] - 96s 195ms/step - loss: 0.2205 - accuracy: 0.9992 - val_loss: 0.2138 - val_accuracy: 0.9990
# Epoch 14/60
# 📉 Learning rate at epoch 14: 0.000010=] - ETA: 0s - loss: 0.2183 - accuracy: 0.9995
# 492/492 [==============================] - 96s 195ms/step - loss: 0.2183 - accuracy: 0.9995 - val_loss: 0.2155 - val_accuracy: 1.0000
# Epoch 15/60
# 📉 Learning rate at epoch 15: 0.000010=] - ETA: 0s - loss: 0.2167 - accuracy: 0.9995
# 492/492 [==============================] - 96s 195ms/step - loss: 0.2167 - accuracy: 0.9995 - val_loss: 0.2099 - val_accuracy: 1.0000
# Epoch 16/60
# 📉 Learning rate at epoch 16: 0.000010=] - ETA: 0s - loss: 0.2169 - accuracy: 0.9995
# 492/492 [==============================] - 97s 196ms/step - loss: 0.2169 - accuracy: 0.9995 - val_loss: 0.2113 - val_accuracy: 1.0000
# Epoch 17/60
# 📉 Learning rate at epoch 17: 0.000010=] - ETA: 0s - loss: 0.2271 - accuracy: 0.9954
# 492/492 [==============================] - 95s 194ms/step - loss: 0.2271 - accuracy: 0.9954 - val_loss: 0.2188 - val_accuracy: 0.9959
# Epoch 18/60
# 📉 Learning rate at epoch 18: 0.000010=] - ETA: 0s - loss: 0.2231 - accuracy: 0.9969
# 492/492 [==============================] - 91s 184ms/step - loss: 0.2231 - accuracy: 0.9969 - val_loss: 0.2074 - val_accuracy: 1.0000
# Epoch 19/60
# 📉 Learning rate at epoch 19: 0.000010=] - ETA: 0s - loss: 0.2132 - accuracy: 0.9997
# 492/492 [==============================] - 89s 181ms/step - loss: 0.2132 - accuracy: 0.9997 - val_loss: 0.2055 - val_accuracy: 1.0000
# Epoch 20/60
# 📉 Learning rate at epoch 20: 0.000010=] - ETA: 0s - loss: 0.2113 - accuracy: 0.9997
# 492/492 [==============================] - 88s 178ms/step - loss: 0.2113 - accuracy: 0.9997 - val_loss: 0.2077 - val_accuracy: 1.0000
# Epoch 21/60
# 📉 Learning rate at epoch 21: 0.000010=] - ETA: 0s - loss: 0.2110 - accuracy: 0.9997
# 492/492 [==============================] - 89s 181ms/step - loss: 0.2110 - accuracy: 0.9997 - val_loss: 0.2098 - val_accuracy: 0.9990
# Epoch 22/60
# 📉 Learning rate at epoch 22: 0.000010=] - ETA: 0s - loss: 0.2110 - accuracy: 0.9997
# 492/492 [==============================] - 89s 181ms/step - loss: 0.2110 - accuracy: 0.9997 - val_loss: 0.2052 - val_accuracy: 1.0000
# Epoch 23/60
# 📉 Learning rate at epoch 23: 0.000010=] - ETA: 0s - loss: 0.2104 - accuracy: 0.9995
# 492/492 [==============================] - 92s 187ms/step - loss: 0.2104 - accuracy: 0.9995 - val_loss: 0.2057 - val_accuracy: 1.0000
# Epoch 24/60
# 📉 Learning rate at epoch 24: 0.000010=] - ETA: 0s - loss: 0.2161 - accuracy: 0.9967
# 492/492 [==============================] - 94s 191ms/step - loss: 0.2161 - accuracy: 0.9967 - val_loss: 0.2820 - val_accuracy: 0.9715
# Epoch 25/60
# 📉 Learning rate at epoch 25: 0.000010=] - ETA: 0s - loss: 0.2271 - accuracy: 0.9936
# 492/492 [==============================] - 94s 191ms/step - loss: 0.2271 - accuracy: 0.9936 - val_loss: 0.2071 - val_accuracy: 1.0000
# Epoch 26/60
# 📉 Learning rate at epoch 26: 0.000010=] - ETA: 0s - loss: 0.2100 - accuracy: 0.9995
# 492/492 [==============================] - 93s 190ms/step - loss: 0.2100 - accuracy: 0.9995 - val_loss: 0.2050 - val_accuracy: 1.0000
# Epoch 27/60
# 📉 Learning rate at epoch 27: 0.000010=] - ETA: 0s - loss: 0.2087 - accuracy: 0.9995
# 492/492 [==============================] - 89s 181ms/step - loss: 0.2087 - accuracy: 0.9995 - val_loss: 0.2047 - val_accuracy: 1.0000
# Epoch 28/60
# 📉 Learning rate at epoch 28: 0.000010=] - ETA: 0s - loss: 0.2083 - accuracy: 0.9995
# 492/492 [==============================] - 87s 176ms/step - loss: 0.2083 - accuracy: 0.9995 - val_loss: 0.2042 - val_accuracy: 1.0000
# Epoch 29/60
# 📉 Learning rate at epoch 29: 0.000010=] - ETA: 0s - loss: 0.2081 - accuracy: 0.9995
# 492/492 [==============================] - 83s 168ms/step - loss: 0.2081 - accuracy: 0.9995 - val_loss: 0.2034 - val_accuracy: 1.0000
# Epoch 30/60
# 📉 Learning rate at epoch 30: 0.000010=] - ETA: 0s - loss: 0.2076 - accuracy: 1.0000
# 492/492 [==============================] - 81s 165ms/step - loss: 0.2076 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 1.0000
# Epoch 31/60
# 📉 Learning rate at epoch 31: 0.000010=] - ETA: 0s - loss: 0.2101 - accuracy: 0.9987
# 492/492 [==============================] - 81s 164ms/step - loss: 0.2101 - accuracy: 0.9987 - val_loss: 0.2042 - val_accuracy: 1.0000
# Epoch 32/60
# 📉 Learning rate at epoch 32: 0.000010=] - ETA: 0s - loss: 0.2080 - accuracy: 0.9997
# 492/492 [==============================] - 81s 165ms/step - loss: 0.2080 - accuracy: 0.9997 - val_loss: 0.2040 - val_accuracy: 1.0000
# Epoch 33/60
# 📉 Learning rate at epoch 33: 0.000010=] - ETA: 0s - loss: 0.2076 - accuracy: 0.9997
# 492/492 [==============================] - 85s 173ms/step - loss: 0.2076 - accuracy: 0.9997 - val_loss: 0.2042 - val_accuracy: 0.9990
# Epoch 34/60
# 📉 Learning rate at epoch 34: 0.000010=] - ETA: 0s - loss: 0.2074 - accuracy: 1.0000
# 492/492 [==============================] - 87s 176ms/step - loss: 0.2074 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 1.0000

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\Xception_Phase2_og_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 1s 526ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       1.00      1.00      1.00       183
#        BLAST       1.00      1.00      1.00       255
#    BROWNSPOT       1.00      1.00      1.00       224
#      HEALTHY       1.00      1.00      1.00       321
#
#     accuracy                           1.00       983
#    macro avg       1.00      1.00      1.00       983
# weighted avg       1.00      1.00      1.00       983
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\Xception_Phase2_og_noaug.h5
