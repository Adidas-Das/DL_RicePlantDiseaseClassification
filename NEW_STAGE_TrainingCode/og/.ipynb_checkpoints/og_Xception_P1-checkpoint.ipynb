# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import (preprocess_input)
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 16  # ✅ Smaller for BN layers
EPOCHS = 30
LEARNING_RATE = 1e-5  # ✅ Lower for frozen backbone

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "og")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 4913

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 3930 | Val samples: 983

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = preprocess_input(img)  # ✅ For ResNet50: scale to [-1, 1] the same way as pretraining

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === ResNet50 Model ===
base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# ✅ Unfreeze last 30 layers
for layer in base_model.layers:  # [:-30]:
    layer.trainable = False
# for layer in base_model.layers[-30:]:
#     layer.trainable = True

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)  # Important: BN layers training mode ON for partial unfrozen!
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        # If using a scheduler, it might be a callable or tensor
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch + 1}: {lr:.6f}")


# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/30
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 1.2934 - accuracy: 0.4344
# 246/246 [==============================] - 34s 119ms/step - loss: 1.2934 - accuracy: 0.4344 - val_loss: 1.1607 - val_accuracy: 0.5687
# Epoch 2/30
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 1.1505 - accuracy: 0.5331
# 246/246 [==============================] - 32s 130ms/step - loss: 1.1505 - accuracy: 0.5331 - val_loss: 1.0762 - val_accuracy: 0.6124
# Epoch 3/30
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 1.0828 - accuracy: 0.5824
# 246/246 [==============================] - 31s 125ms/step - loss: 1.0828 - accuracy: 0.5824 - val_loss: 1.0160 - val_accuracy: 0.6409
# Epoch 4/30
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 1.0408 - accuracy: 0.6127
# 246/246 [==============================] - 29s 119ms/step - loss: 1.0408 - accuracy: 0.6127 - val_loss: 0.9448 - val_accuracy: 0.6897
# Epoch 5/30
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 0.9877 - accuracy: 0.6506
# 246/246 [==============================] - 30s 122ms/step - loss: 0.9877 - accuracy: 0.6506 - val_loss: 0.9375 - val_accuracy: 0.6877
# Epoch 6/30
# 📉 Learning rate at epoch 6: 0.000010==] - ETA: 0s - loss: 0.9650 - accuracy: 0.6677
# 246/246 [==============================] - 30s 123ms/step - loss: 0.9650 - accuracy: 0.6677 - val_loss: 0.9050 - val_accuracy: 0.6958
# Epoch 7/30
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 0.9285 - accuracy: 0.6776
# 246/246 [==============================] - 30s 121ms/step - loss: 0.9285 - accuracy: 0.6776 - val_loss: 0.8898 - val_accuracy: 0.7121
# Epoch 8/30
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 0.8989 - accuracy: 0.7043
# 246/246 [==============================] - 30s 121ms/step - loss: 0.8989 - accuracy: 0.7043 - val_loss: 0.8306 - val_accuracy: 0.7487
# Epoch 9/30
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 0.8997 - accuracy: 0.6977
# 246/246 [==============================] - 29s 118ms/step - loss: 0.8997 - accuracy: 0.6977 - val_loss: 0.8581 - val_accuracy: 0.7233
# Epoch 10/30
# 📉 Learning rate at epoch 10: 0.000010.] - ETA: 0s - loss: 0.8705 - accuracy: 0.7156
# 246/246 [==============================] - 28s 114ms/step - loss: 0.8709 - accuracy: 0.7158 - val_loss: 0.8169 - val_accuracy: 0.7548
# Epoch 11/30
# 📉 Learning rate at epoch 11: 0.000010=] - ETA: 0s - loss: 0.8655 - accuracy: 0.7206
# 246/246 [==============================] - 30s 120ms/step - loss: 0.8655 - accuracy: 0.7206 - val_loss: 0.8165 - val_accuracy: 0.7548
# Epoch 12/30
# 📉 Learning rate at epoch 12: 0.000010=] - ETA: 0s - loss: 0.8460 - accuracy: 0.7351
# 246/246 [==============================] - 29s 118ms/step - loss: 0.8460 - accuracy: 0.7351 - val_loss: 0.8069 - val_accuracy: 0.7620
# Epoch 13/30
# 📉 Learning rate at epoch 13: 0.000010=] - ETA: 0s - loss: 0.8346 - accuracy: 0.7455
# 246/246 [==============================] - 29s 118ms/step - loss: 0.8346 - accuracy: 0.7455 - val_loss: 0.7758 - val_accuracy: 0.7792
# Epoch 14/30
# 📉 Learning rate at epoch 14: 0.000010=] - ETA: 0s - loss: 0.8185 - accuracy: 0.7489
# 246/246 [==============================] - 29s 119ms/step - loss: 0.8185 - accuracy: 0.7489 - val_loss: 0.7724 - val_accuracy: 0.7772
# Epoch 15/30
# 📉 Learning rate at epoch 15: 0.000010=] - ETA: 0s - loss: 0.8147 - accuracy: 0.7550
# 246/246 [==============================] - 30s 122ms/step - loss: 0.8147 - accuracy: 0.7550 - val_loss: 0.7684 - val_accuracy: 0.7772
# Epoch 16/30
# 📉 Learning rate at epoch 16: 0.000010=] - ETA: 0s - loss: 0.8082 - accuracy: 0.7560
# 246/246 [==============================] - 30s 121ms/step - loss: 0.8082 - accuracy: 0.7560 - val_loss: 0.7510 - val_accuracy: 0.7854
# Epoch 17/30
# 📉 Learning rate at epoch 17: 0.000010=] - ETA: 0s - loss: 0.7974 - accuracy: 0.7613
# 246/246 [==============================] - 29s 117ms/step - loss: 0.7974 - accuracy: 0.7613 - val_loss: 0.7502 - val_accuracy: 0.7915
# Epoch 18/30
# 📉 Learning rate at epoch 18: 0.000010=] - ETA: 0s - loss: 0.7848 - accuracy: 0.7730
# 246/246 [==============================] - 29s 119ms/step - loss: 0.7848 - accuracy: 0.7730 - val_loss: 0.7375 - val_accuracy: 0.7945
# Epoch 19/30
# 📉 Learning rate at epoch 19: 0.000010=] - ETA: 0s - loss: 0.7839 - accuracy: 0.7804
# 246/246 [==============================] - 30s 123ms/step - loss: 0.7839 - accuracy: 0.7804 - val_loss: 0.7501 - val_accuracy: 0.7854
# Epoch 20/30
# 📉 Learning rate at epoch 20: 0.000010=] - ETA: 0s - loss: 0.7774 - accuracy: 0.7774
# 246/246 [==============================] - 30s 122ms/step - loss: 0.7774 - accuracy: 0.7774 - val_loss: 0.7393 - val_accuracy: 0.7965
# Epoch 21/30
# 📉 Learning rate at epoch 21: 0.000010=] - ETA: 0s - loss: 0.7670 - accuracy: 0.7822
# 246/246 [==============================] - 29s 117ms/step - loss: 0.7670 - accuracy: 0.7822 - val_loss: 0.7095 - val_accuracy: 0.8179
# Epoch 22/30
# 📉 Learning rate at epoch 22: 0.000010=] - ETA: 0s - loss: 0.7532 - accuracy: 0.7931
# 246/246 [==============================] - 29s 117ms/step - loss: 0.7532 - accuracy: 0.7931 - val_loss: 0.7160 - val_accuracy: 0.8118
# Epoch 23/30
# 📉 Learning rate at epoch 23: 0.000010=] - ETA: 0s - loss: 0.7486 - accuracy: 0.7982
# 246/246 [==============================] - 30s 120ms/step - loss: 0.7486 - accuracy: 0.7982 - val_loss: 0.7011 - val_accuracy: 0.8281
# Epoch 24/30
# 📉 Learning rate at epoch 24: 0.000010=] - ETA: 0s - loss: 0.7468 - accuracy: 0.8023
# 246/246 [==============================] - 29s 118ms/step - loss: 0.7468 - accuracy: 0.8023 - val_loss: 0.6888 - val_accuracy: 0.8362
# Epoch 25/30
# 📉 Learning rate at epoch 25: 0.000010=] - ETA: 0s - loss: 0.7448 - accuracy: 0.8036
# 246/246 [==============================] - 29s 119ms/step - loss: 0.7448 - accuracy: 0.8036 - val_loss: 0.7006 - val_accuracy: 0.8250
# Epoch 26/30
# 📉 Learning rate at epoch 26: 0.000010=] - ETA: 0s - loss: 0.7366 - accuracy: 0.8048
# 246/246 [==============================] - 28s 113ms/step - loss: 0.7366 - accuracy: 0.8048 - val_loss: 0.7087 - val_accuracy: 0.8057
# Epoch 27/30
# 📉 Learning rate at epoch 27: 0.000010.] - ETA: 0s - loss: 0.7344 - accuracy: 0.8051
# 246/246 [==============================] - 29s 117ms/step - loss: 0.7341 - accuracy: 0.8053 - val_loss: 0.6841 - val_accuracy: 0.8383
# Epoch 28/30
# 📉 Learning rate at epoch 28: 0.000010=] - ETA: 0s - loss: 0.7257 - accuracy: 0.8127
# 246/246 [==============================] - 29s 118ms/step - loss: 0.7257 - accuracy: 0.8127 - val_loss: 0.6834 - val_accuracy: 0.8362
# Epoch 29/30
# 📉 Learning rate at epoch 29: 0.000010=] - ETA: 0s - loss: 0.7193 - accuracy: 0.8094
# 246/246 [==============================] - 29s 116ms/step - loss: 0.7193 - accuracy: 0.8094 - val_loss: 0.6834 - val_accuracy: 0.8240
# Epoch 30/30
# 📉 Learning rate at epoch 30: 0.000010=] - ETA: 0s - loss: 0.7156 - accuracy: 0.8089
# 246/246 [==============================] - 29s 116ms/step - loss: 0.7156 - accuracy: 0.8089 - val_loss: 0.6720 - val_accuracy: 0.8403

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\Xception_Phase1_og_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 10ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.96      0.93      0.95       175
#        BLAST       0.76      0.77      0.77       267
#    BROWNSPOT       0.82      0.76      0.79       213
#      HEALTHY       0.82      0.87      0.84       328
#
#     accuracy                           0.83       983
#    macro avg       0.84      0.83      0.84       983
# weighted avg       0.83      0.83      0.83       983
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\Xception_Phase1_og_noaug.h5
