# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (299, 299) # InceptionV3 typically expects (299, 299)
BATCH_SIZE = 8
EPOCHS = 60 # Can be more for fine-tuning
LEARNING_RATE = 1e-5 # Lower learning rate for fine-tuning

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "og")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 4913

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 3930 | Val samples: 983

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    # InceptionV3 preprocess_input expects inputs in range [0, 255] and handles normalization internally
    img = preprocess_input(img)

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline (with CutMix and GridMask) ===

train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE) # Re-added CutMix
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === Load InceptionV3 Model from Phase 1 ===
model = load_model(r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\InceptionV3_Phase1_og_noaug.h5") # Updated path to match Phase 1 save

# Unfreeze all layers for fine-tuning
model.trainable = True

# Recompile the model with a lower learning rate and adjusted label smoothing
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/60
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 0.6220 - accuracy: 0.8150
# 492/492 [==============================] - 118s 209ms/step - loss: 0.6220 - accuracy: 0.8150 - val_loss: 0.4551 - val_accuracy: 0.8881
# Epoch 2/60
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 0.4697 - accuracy: 0.8931
# 492/492 [==============================] - 101s 206ms/step - loss: 0.4697 - accuracy: 0.8931 - val_loss: 0.3837 - val_accuracy: 0.9379
# Epoch 3/60
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 0.4062 - accuracy: 0.9242
# 492/492 [==============================] - 101s 205ms/step - loss: 0.4062 - accuracy: 0.9242 - val_loss: 0.3312 - val_accuracy: 0.9532
# Epoch 4/60
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 0.3537 - accuracy: 0.9519
# 492/492 [==============================] - 102s 207ms/step - loss: 0.3537 - accuracy: 0.9519 - val_loss: 0.2800 - val_accuracy: 0.9756
# Epoch 5/60
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 0.3179 - accuracy: 0.9601
# 492/492 [==============================] - 102s 206ms/step - loss: 0.3179 - accuracy: 0.9601 - val_loss: 0.2758 - val_accuracy: 0.9797
# Epoch 6/60
# 📉 Learning rate at epoch 6: 0.000010==] - ETA: 0s - loss: 0.2916 - accuracy: 0.9715
# 492/492 [==============================] - 103s 208ms/step - loss: 0.2916 - accuracy: 0.9715 - val_loss: 0.2691 - val_accuracy: 0.9776
# Epoch 7/60
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 0.2812 - accuracy: 0.9748
# 492/492 [==============================] - 103s 208ms/step - loss: 0.2812 - accuracy: 0.9748 - val_loss: 0.2627 - val_accuracy: 0.9817
# Epoch 8/60
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 0.2592 - accuracy: 0.9842
# 492/492 [==============================] - 101s 205ms/step - loss: 0.2592 - accuracy: 0.9842 - val_loss: 0.2558 - val_accuracy: 0.9776
# Epoch 9/60
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 0.2552 - accuracy: 0.9850
# 492/492 [==============================] - 102s 206ms/step - loss: 0.2552 - accuracy: 0.9850 - val_loss: 0.2275 - val_accuracy: 0.9949
# Epoch 10/60
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 0.2374 - accuracy: 0.9924
# 492/492 [==============================] - 102s 206ms/step - loss: 0.2374 - accuracy: 0.9924 - val_loss: 0.2513 - val_accuracy: 0.9858
# Epoch 11/60
# 📉 Learning rate at epoch 11: 0.000010=] - ETA: 0s - loss: 0.2410 - accuracy: 0.9898
# 492/492 [==============================] - 100s 204ms/step - loss: 0.2410 - accuracy: 0.9898 - val_loss: 0.2212 - val_accuracy: 0.9969
# Epoch 12/60
# 📉 Learning rate at epoch 12: 0.000010=] - ETA: 0s - loss: 0.2341 - accuracy: 0.9921
# 492/492 [==============================] - 102s 206ms/step - loss: 0.2341 - accuracy: 0.9921 - val_loss: 0.2315 - val_accuracy: 0.9969
# Epoch 13/60
# 📉 Learning rate at epoch 13: 0.000010=] - ETA: 0s - loss: 0.2363 - accuracy: 0.9924
# 492/492 [==============================] - 101s 204ms/step - loss: 0.2363 - accuracy: 0.9924 - val_loss: 0.2151 - val_accuracy: 0.9980
# Epoch 14/60
# 📉 Learning rate at epoch 14: 0.000010=] - ETA: 0s - loss: 0.2248 - accuracy: 0.9964
# 492/492 [==============================] - 102s 207ms/step - loss: 0.2248 - accuracy: 0.9964 - val_loss: 0.2148 - val_accuracy: 0.9990
# Epoch 15/60
# 📉 Learning rate at epoch 15: 0.000010=] - ETA: 0s - loss: 0.2183 - accuracy: 0.9982
# 492/492 [==============================] - 102s 207ms/step - loss: 0.2183 - accuracy: 0.9982 - val_loss: 0.2067 - val_accuracy: 1.0000
# Epoch 16/60
# 📉 Learning rate at epoch 16: 0.000010=] - ETA: 0s - loss: 0.2133 - accuracy: 0.9987
# 492/492 [==============================] - 103s 208ms/step - loss: 0.2133 - accuracy: 0.9987 - val_loss: 0.2062 - val_accuracy: 0.9990
# Epoch 17/60
# 📉 Learning rate at epoch 17: 0.000010=] - ETA: 0s - loss: 0.2107 - accuracy: 0.9995
# 492/492 [==============================] - 101s 206ms/step - loss: 0.2107 - accuracy: 0.9995 - val_loss: 0.2046 - val_accuracy: 1.0000
# Epoch 18/60
# 📉 Learning rate at epoch 18: 0.000010=] - ETA: 0s - loss: 0.2509 - accuracy: 0.9858
# 492/492 [==============================] - 101s 205ms/step - loss: 0.2509 - accuracy: 0.9858 - val_loss: 0.2458 - val_accuracy: 0.9858
# Epoch 19/60
# 📉 Learning rate at epoch 19: 0.000010=] - ETA: 0s - loss: 0.2483 - accuracy: 0.9827
# 492/492 [==============================] - 102s 207ms/step - loss: 0.2483 - accuracy: 0.9827 - val_loss: 0.2150 - val_accuracy: 0.9969
# Epoch 20/60
# 📉 Learning rate at epoch 20: 0.000010=] - ETA: 0s - loss: 0.2326 - accuracy: 0.9916
# 492/492 [==============================] - 102s 206ms/step - loss: 0.2326 - accuracy: 0.9916 - val_loss: 0.2153 - val_accuracy: 0.9969
# Epoch 21/60
# 📉 Learning rate at epoch 21: 0.000010=] - ETA: 0s - loss: 0.2165 - accuracy: 0.9972
# 492/492 [==============================] - 101s 205ms/step - loss: 0.2165 - accuracy: 0.9972 - val_loss: 0.2047 - val_accuracy: 1.0000

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\InceptionV3_Phase2_og_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.99      1.00      1.00       156
#        BLAST       1.00      1.00      1.00       270
#    BROWNSPOT       1.00      1.00      1.00       225
#      HEALTHY       1.00      1.00      1.00       332
#
#     accuracy                           1.00       983
#    macro avg       1.00      1.00      1.00       983
# weighted avg       1.00      1.00      1.00       983
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\InceptionV3_Phase2_og_noaug.h5
