# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.densenet import preprocess_input

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 8  # ✅ Smaller for BN layers
EPOCHS = 60
LEARNING_RATE = 1e-5  # ✅ Lower for frozen backbone

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "og")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 4913

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 3930 | Val samples: 983

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = preprocess_input(img)  # ✅ For ResNet50: scale to [-1, 1] the same way as pretraining

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === Load Model ===
model = load_model(r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\DenseNet121_Phase1_og_noaug.h5")


for layer in model.layers:
    layer.trainable = True


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/60
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 0.6435 - accuracy: 0.8023
# 492/492 [==============================] - 117s 215ms/step - loss: 0.6435 - accuracy: 0.8023 - val_loss: 0.4669 - val_accuracy: 0.8830
# Epoch 2/60
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 0.5226 - accuracy: 0.8618
# 492/492 [==============================] - 105s 212ms/step - loss: 0.5226 - accuracy: 0.8618 - val_loss: 0.4318 - val_accuracy: 0.9084
# Epoch 3/60
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 0.4599 - accuracy: 0.8924
# 492/492 [==============================] - 104s 212ms/step - loss: 0.4599 - accuracy: 0.8924 - val_loss: 0.3773 - val_accuracy: 0.9339
# Epoch 4/60
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 0.4122 - accuracy: 0.9214
# 492/492 [==============================] - 105s 212ms/step - loss: 0.4122 - accuracy: 0.9214 - val_loss: 0.3074 - val_accuracy: 0.9685
# Epoch 5/60
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 0.3742 - accuracy: 0.9389
# 492/492 [==============================] - 105s 214ms/step - loss: 0.3742 - accuracy: 0.9389 - val_loss: 0.3278 - val_accuracy: 0.9603
# Epoch 6/60
# 📉 Learning rate at epoch 6: 0.000010==] - ETA: 0s - loss: 0.3505 - accuracy: 0.9524
# 492/492 [==============================] - 104s 212ms/step - loss: 0.3505 - accuracy: 0.9524 - val_loss: 0.3009 - val_accuracy: 0.9664
# Epoch 7/60
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 0.3276 - accuracy: 0.9601
# 492/492 [==============================] - 104s 211ms/step - loss: 0.3276 - accuracy: 0.9601 - val_loss: 0.2886 - val_accuracy: 0.9746
# Epoch 8/60
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 0.2993 - accuracy: 0.9705
# 492/492 [==============================] - 111s 225ms/step - loss: 0.2993 - accuracy: 0.9705 - val_loss: 0.3061 - val_accuracy: 0.9603
# Epoch 9/60
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 0.2931 - accuracy: 0.9712
# 492/492 [==============================] - 106s 214ms/step - loss: 0.2931 - accuracy: 0.9712 - val_loss: 0.2784 - val_accuracy: 0.9756
# Epoch 10/60
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 0.2772 - accuracy: 0.9817
# 492/492 [==============================] - 106s 216ms/step - loss: 0.2772 - accuracy: 0.9817 - val_loss: 0.2503 - val_accuracy: 0.9868
# Epoch 11/60
# 📉 Learning rate at epoch 11: 0.000010=] - ETA: 0s - loss: 0.2721 - accuracy: 0.9817
# 492/492 [==============================] - 105s 214ms/step - loss: 0.2721 - accuracy: 0.9817 - val_loss: 0.2539 - val_accuracy: 0.9847
# Epoch 12/60
# 📉 Learning rate at epoch 12: 0.000010=] - ETA: 0s - loss: 0.2654 - accuracy: 0.9842
# 492/492 [==============================] - 109s 222ms/step - loss: 0.2654 - accuracy: 0.9842 - val_loss: 0.2408 - val_accuracy: 0.9908
# Epoch 13/60
# 📉 Learning rate at epoch 13: 0.000010=] - ETA: 0s - loss: 0.2505 - accuracy: 0.9903
# 492/492 [==============================] - 109s 222ms/step - loss: 0.2505 - accuracy: 0.9903 - val_loss: 0.2274 - val_accuracy: 0.9959
# Epoch 14/60
# 📉 Learning rate at epoch 14: 0.000010=] - ETA: 0s - loss: 0.2449 - accuracy: 0.9906
# 492/492 [==============================] - 110s 223ms/step - loss: 0.2449 - accuracy: 0.9906 - val_loss: 0.2373 - val_accuracy: 0.9908
# Epoch 15/60
# 📉 Learning rate at epoch 15: 0.000010=] - ETA: 0s - loss: 0.2435 - accuracy: 0.9913
# 492/492 [==============================] - 109s 222ms/step - loss: 0.2435 - accuracy: 0.9913 - val_loss: 0.2349 - val_accuracy: 0.9929
# Epoch 16/60
# 📉 Learning rate at epoch 16: 0.000010=] - ETA: 0s - loss: 0.2366 - accuracy: 0.9952
# 492/492 [==============================] - 110s 224ms/step - loss: 0.2366 - accuracy: 0.9952 - val_loss: 0.2193 - val_accuracy: 0.9959
# Epoch 17/60
# 📉 Learning rate at epoch 17: 0.000010=] - ETA: 0s - loss: 0.2309 - accuracy: 0.9969
# 492/492 [==============================] - 109s 221ms/step - loss: 0.2309 - accuracy: 0.9969 - val_loss: 0.2151 - val_accuracy: 0.9980
# Epoch 18/60
# 📉 Learning rate at epoch 18: 0.000010=] - ETA: 0s - loss: 0.2371 - accuracy: 0.9929
# 492/492 [==============================] - 109s 222ms/step - loss: 0.2371 - accuracy: 0.9929 - val_loss: 0.2185 - val_accuracy: 0.9949
# Epoch 19/60
# 📉 Learning rate at epoch 19: 0.000010=] - ETA: 0s - loss: 0.2317 - accuracy: 0.9952
# 492/492 [==============================] - 108s 220ms/step - loss: 0.2317 - accuracy: 0.9952 - val_loss: 0.2182 - val_accuracy: 0.9980
# Epoch 20/60
# 📉 Learning rate at epoch 20: 0.000010=] - ETA: 0s - loss: 0.2287 - accuracy: 0.9954
# 492/492 [==============================] - 104s 212ms/step - loss: 0.2287 - accuracy: 0.9954 - val_loss: 0.2213 - val_accuracy: 0.9939
# Epoch 21/60
# 📉 Learning rate at epoch 21: 0.000010=] - ETA: 0s - loss: 0.2424 - accuracy: 0.9893
# 492/492 [==============================] - 106s 215ms/step - loss: 0.2424 - accuracy: 0.9893 - val_loss: 0.2163 - val_accuracy: 0.9980

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\DenseNet121_Phase2_og_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.99      1.00      1.00       156
#        BLAST       1.00      0.99      0.99       270
#    BROWNSPOT       1.00      1.00      1.00       225
#      HEALTHY       0.99      1.00      1.00       332
#
#     accuracy                           1.00       983
#    macro avg       1.00      1.00      1.00       983
# weighted avg       1.00      1.00      1.00       983
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\DenseNet121_Phase2_og_noaug.h5
