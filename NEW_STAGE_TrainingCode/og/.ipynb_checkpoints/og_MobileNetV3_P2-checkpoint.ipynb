# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_OGplusGA"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 10
EPOCHS = 60 # Can be adjusted, often more epochs for fine-tuning
LEARNING_RATE = 1e-5 # Even lower learning rate for fine-tuning

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "og")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 4913

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 3930 | Val samples: 983

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = preprocess_input(img) # For MobileNetV3

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === MobileNetV3 Model (Load from Phase 1 and Unfreeze) ===
# Load the model saved from Phase 1
model = load_model(r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\MobileNetV3_Phase1_og_noaug.h5")

# Unfreeze all layers of the model for fine-tuning
# You might choose to unfreeze only a portion, e.g., model.layers[-N:]
for layer in model.layers:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05), # Slightly reduced label smoothing
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
print("\nStarting Phase 2 Training (MobileNetV3 - Fine-tuning)...")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()] # Increased patience for fine-tuning
    # class_weight=class_weights
)
# Out:
# Starting Phase 2 Training (MobileNetV3 - Fine-tuning)...
# Epoch 1/60
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 0.6687 - accuracy: 0.7903
# 393/393 [==============================] - 35s 74ms/step - loss: 0.6687 - accuracy: 0.7903 - val_loss: 0.5316 - val_accuracy: 0.8576
# Epoch 2/60
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 0.5999 - accuracy: 0.8224
# 393/393 [==============================] - 28s 72ms/step - loss: 0.5999 - accuracy: 0.8224 - val_loss: 0.5144 - val_accuracy: 0.8688
# Epoch 3/60
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 0.5424 - accuracy: 0.8514
# 393/393 [==============================] - 28s 72ms/step - loss: 0.5424 - accuracy: 0.8514 - val_loss: 0.4726 - val_accuracy: 0.8850
# Epoch 4/60
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 0.5142 - accuracy: 0.8710
# 393/393 [==============================] - 28s 72ms/step - loss: 0.5142 - accuracy: 0.8710 - val_loss: 0.4153 - val_accuracy: 0.9227
# Epoch 5/60
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 0.4842 - accuracy: 0.8852
# 393/393 [==============================] - 28s 72ms/step - loss: 0.4842 - accuracy: 0.8852 - val_loss: 0.4322 - val_accuracy: 0.9074
# Epoch 6/60
# 📉 Learning rate at epoch 6: 0.000010==] - ETA: 0s - loss: 0.4488 - accuracy: 0.9046
# 393/393 [==============================] - 28s 72ms/step - loss: 0.4488 - accuracy: 0.9046 - val_loss: 0.3829 - val_accuracy: 0.9369
# Epoch 7/60
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 0.4374 - accuracy: 0.9087
# 393/393 [==============================] - 28s 72ms/step - loss: 0.4374 - accuracy: 0.9087 - val_loss: 0.3923 - val_accuracy: 0.9308
# Epoch 8/60
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 0.4124 - accuracy: 0.9201
# 393/393 [==============================] - 28s 72ms/step - loss: 0.4124 - accuracy: 0.9201 - val_loss: 0.3598 - val_accuracy: 0.9420
# Epoch 9/60
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 0.3983 - accuracy: 0.9226
# 393/393 [==============================] - 28s 72ms/step - loss: 0.3983 - accuracy: 0.9226 - val_loss: 0.3682 - val_accuracy: 0.9390
# Epoch 10/60
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 0.3890 - accuracy: 0.9344
# 📉 Learning rate at epoch 44: 0.000010=] - ETA: 0s - loss: 0.2163 - accuracy: 0.9990
# 393/393 [==============================] - 31s 78ms/step - loss: 0.2163 - accuracy: 0.9990 - val_loss: 0.2067 - val_accuracy: 1.0000
# Epoch 45/60
# 📉 Learning rate at epoch 45: 0.000010=] - ETA: 0s - loss: 0.2144 - accuracy: 0.9997
# 393/393 [==============================] - 31s 78ms/step - loss: 0.2144 - accuracy: 0.9997 - val_loss: 0.2052 - val_accuracy: 1.0000
# Epoch 46/60
# 📉 Learning rate at epoch 46: 0.000010=] - ETA: 0s - loss: 0.2141 - accuracy: 0.9997
# 393/393 [==============================] - 31s 78ms/step - loss: 0.2141 - accuracy: 0.9997 - val_loss: 0.2059 - val_accuracy: 1.0000
# Epoch 47/60
# 📉 Learning rate at epoch 47: 0.000010=] - ETA: 0s - loss: 0.2168 - accuracy: 0.9995
# 393/393 [==============================] - 31s 78ms/step - loss: 0.2168 - accuracy: 0.9995 - val_loss: 0.2313 - val_accuracy: 0.9888
# Epoch 48/60
# 📉 Learning rate at epoch 48: 0.000010=] - ETA: 0s - loss: 0.2185 - accuracy: 0.9977
# 393/393 [==============================] - 29s 72ms/step - loss: 0.2185 - accuracy: 0.9977 - val_loss: 0.2079 - val_accuracy: 0.9990
# Epoch 49/60
# 📉 Learning rate at epoch 49: 0.000010=] - ETA: 0s - loss: 0.2143 - accuracy: 0.9997
# 393/393 [==============================] - 30s 76ms/step - loss: 0.2143 - accuracy: 0.9997 - val_loss: 0.2078 - val_accuracy: 0.9990

# %%
# === Evaluate ===
print("\n📊 Evaluating Phase 2 Model...")
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report (Phase 2):")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix (Phase 2)")
plt.tight_layout()
plt.show()

# === Save ===

SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\MobileNetV3_Phase2_og_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Phase 2 MobileNetV3 Model saved at: {SAVE_PATH}")
# Out:
# 📊 Evaluating Phase 2 Model...
# 1/1 [==============================] - 1s 627ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
#
# 📊 Classification Report (Phase 2):
#               precision    recall  f1-score   support
#
#       BLIGHT       1.00      1.00      1.00       166
#        BLAST       1.00      1.00      1.00       282
#    BROWNSPOT       1.00      1.00      1.00       241
#      HEALTHY       1.00      1.00      1.00       294
#
#     accuracy                           1.00       983
#    macro avg       1.00      1.00      1.00       983
# weighted avg       1.00      1.00      1.00       983
# ✅ Phase 2 MobileNetV3 Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\og\MobileNetV3_Phase2_og_noaug.h5
