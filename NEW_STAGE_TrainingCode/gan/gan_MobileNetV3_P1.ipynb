# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_GAN"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224) # MobileNetV3Large typically uses 224x224
BATCH_SIZE = 32
EPOCHS = 30 # Can be adjusted
LEARNING_RATE = 1e-5 # Slightly higher than ResNet50 frozen, but still low

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 32460

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 25968 | Val samples: 6492

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = preprocess_input(img) # For MobileNetV3: scales pixels to [-1, 1]

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === MobileNetV3 Model ===
# Use MobileNetV3Large for better performance
base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

inputs = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
# It's important to set training=False when using the base model for feature extraction
# especially if it contains BatchNorm layers, to keep them in inference mode.
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1), # Using label smoothing
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# Temporarily unbatch and concatenate labels to compute class weights
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
print("\n🚀 Starting Phase 1 Training (MobileNetV3 - Feature Extraction)...")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()] # Increased patience
    # class_weight=class_weights
)
# Out:
# 🚀 Starting Phase 1 Training (MobileNetV3 - Feature Extraction)...
# Epoch 1/30
# 📉 Learning rate at epoch 1: 0.000010>.] - ETA: 0s - loss: 1.2133 - accuracy: 0.5009
# 812/812 [==============================] - 67s 74ms/step - loss: 1.2134 - accuracy: 0.5009 - val_loss: 0.9132 - val_accuracy: 0.6921
# Epoch 2/30
# 📉 Learning rate at epoch 2: 0.000010>.] - ETA: 0s - loss: 0.9672 - accuracy: 0.6541
# 812/812 [==============================] - 60s 73ms/step - loss: 0.9671 - accuracy: 0.6541 - val_loss: 0.8087 - val_accuracy: 0.7508
# Epoch 3/30
# 📉 Learning rate at epoch 3: 0.000010>.] - ETA: 0s - loss: 0.8844 - accuracy: 0.7053
# 812/812 [==============================] - 59s 72ms/step - loss: 0.8843 - accuracy: 0.7054 - val_loss: 0.7608 - val_accuracy: 0.7831
# Epoch 4/30
# 📉 Learning rate at epoch 4: 0.000010>.] - ETA: 0s - loss: 0.8358 - accuracy: 0.7357
# 812/812 [==============================] - 59s 72ms/step - loss: 0.8357 - accuracy: 0.7358 - val_loss: 0.7294 - val_accuracy: 0.7973
# Epoch 5/30
# 📉 Learning rate at epoch 5: 0.000010>.] - ETA: 0s - loss: 0.7987 - accuracy: 0.7595
# 812/812 [==============================] - 59s 72ms/step - loss: 0.7986 - accuracy: 0.7596 - val_loss: 0.7144 - val_accuracy: 0.8135
# Epoch 6/30
# 📉 Learning rate at epoch 6: 0.000010>.] - ETA: 0s - loss: 0.7779 - accuracy: 0.7746
# 812/812 [==============================] - 59s 72ms/step - loss: 0.7779 - accuracy: 0.7746 - val_loss: 0.6929 - val_accuracy: 0.8156
# Epoch 7/30
# 📉 Learning rate at epoch 7: 0.000010>.] - ETA: 0s - loss: 0.7585 - accuracy: 0.7870
# 812/812 [==============================] - 59s 72ms/step - loss: 0.7585 - accuracy: 0.7870 - val_loss: 0.6865 - val_accuracy: 0.8249
# Epoch 8/30
# 📉 Learning rate at epoch 8: 0.000010>.] - ETA: 0s - loss: 0.7411 - accuracy: 0.7965
# 812/812 [==============================] - 59s 72ms/step - loss: 0.7411 - accuracy: 0.7965 - val_loss: 0.6720 - val_accuracy: 0.8372
# Epoch 9/30
# 📉 Learning rate at epoch 9: 0.000010>.] - ETA: 0s - loss: 0.7297 - accuracy: 0.8044
# 812/812 [==============================] - 59s 72ms/step - loss: 0.7299 - accuracy: 0.8043 - val_loss: 0.6668 - val_accuracy: 0.8369
# Epoch 10/30
# 📉 Learning rate at epoch 10: 0.000010.] - ETA: 0s - loss: 0.7171 - accuracy: 0.8119
# 812/812 [==============================] - 59s 72ms/step - loss: 0.7171 - accuracy: 0.8119 - val_loss: 0.6583 - val_accuracy: 0.8373
# Epoch 11/30
# 📉 Learning rate at epoch 11: 0.000010.] - ETA: 0s - loss: 0.7077 - accuracy: 0.8168
# 812/812 [==============================] - 59s 72ms/step - loss: 0.7077 - accuracy: 0.8169 - val_loss: 0.6401 - val_accuracy: 0.8554
# Epoch 12/30
# 📉 Learning rate at epoch 12: 0.000010.] - ETA: 0s - loss: 0.6988 - accuracy: 0.8206
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6988 - accuracy: 0.8206 - val_loss: 0.6503 - val_accuracy: 0.8500
# Epoch 13/30
# 📉 Learning rate at epoch 13: 0.000010.] - ETA: 0s - loss: 0.6896 - accuracy: 0.8273
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6896 - accuracy: 0.8274 - val_loss: 0.6302 - val_accuracy: 0.8617
# Epoch 14/30
# 📉 Learning rate at epoch 14: 0.000010.] - ETA: 0s - loss: 0.6835 - accuracy: 0.8297
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6837 - accuracy: 0.8295 - val_loss: 0.6279 - val_accuracy: 0.8624
# Epoch 15/30
# 📉 Learning rate at epoch 15: 0.000010.] - ETA: 0s - loss: 0.6755 - accuracy: 0.8352
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6755 - accuracy: 0.8351 - val_loss: 0.6214 - val_accuracy: 0.8648
# Epoch 16/30
# 📉 Learning rate at epoch 16: 0.000010.] - ETA: 0s - loss: 0.6692 - accuracy: 0.8392
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6692 - accuracy: 0.8391 - val_loss: 0.6195 - val_accuracy: 0.8678
# Epoch 17/30
# 📉 Learning rate at epoch 17: 0.000010.] - ETA: 0s - loss: 0.6608 - accuracy: 0.8442
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6609 - accuracy: 0.8442 - val_loss: 0.6126 - val_accuracy: 0.8723
# Epoch 18/30
# 📉 Learning rate at epoch 18: 0.000010.] - ETA: 0s - loss: 0.6597 - accuracy: 0.8469
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6596 - accuracy: 0.8470 - val_loss: 0.6104 - val_accuracy: 0.8728
# Epoch 19/30
# 📉 Learning rate at epoch 19: 0.000010.] - ETA: 0s - loss: 0.6532 - accuracy: 0.8499
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6533 - accuracy: 0.8499 - val_loss: 0.6012 - val_accuracy: 0.8777
# Epoch 20/30
# 📉 Learning rate at epoch 20: 0.000010.] - ETA: 0s - loss: 0.6461 - accuracy: 0.8550
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6461 - accuracy: 0.8550 - val_loss: 0.6014 - val_accuracy: 0.8758
# Epoch 21/30
# 📉 Learning rate at epoch 21: 0.000010.] - ETA: 0s - loss: 0.6449 - accuracy: 0.8558
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6449 - accuracy: 0.8558 - val_loss: 0.5907 - val_accuracy: 0.8839
# Epoch 22/30
# 📉 Learning rate at epoch 22: 0.000010.] - ETA: 0s - loss: 0.6386 - accuracy: 0.8620
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6385 - accuracy: 0.8621 - val_loss: 0.5946 - val_accuracy: 0.8842
# Epoch 23/30
# 📉 Learning rate at epoch 23: 0.000010.] - ETA: 0s - loss: 0.6348 - accuracy: 0.8598
# 812/812 [==============================] - 59s 72ms/step - loss: 0.6348 - accuracy: 0.8598 - val_loss: 0.5849 - val_accuracy: 0.8926
# Epoch 24/30
# 📉 Learning rate at epoch 24: 0.000010.] - ETA: 0s - loss: 0.6317 - accuracy: 0.8636
# 812/812 [==============================] - 61s 75ms/step - loss: 0.6317 - accuracy: 0.8637 - val_loss: 0.5799 - val_accuracy: 0.8896
# Epoch 25/30
# 📉 Learning rate at epoch 25: 0.000010.] - ETA: 0s - loss: 0.6231 - accuracy: 0.8709
# 812/812 [==============================] - 61s 75ms/step - loss: 0.6232 - accuracy: 0.8708 - val_loss: 0.5764 - val_accuracy: 0.8902
# Epoch 26/30
# 📉 Learning rate at epoch 26: 0.000010.] - ETA: 0s - loss: 0.6208 - accuracy: 0.8701
# 812/812 [==============================] - 60s 73ms/step - loss: 0.6208 - accuracy: 0.8701 - val_loss: 0.5759 - val_accuracy: 0.8945
# Epoch 27/30
# 📉 Learning rate at epoch 27: 0.000010.] - ETA: 0s - loss: 0.6199 - accuracy: 0.8707
# 812/812 [==============================] - 60s 74ms/step - loss: 0.6198 - accuracy: 0.8707 - val_loss: 0.5780 - val_accuracy: 0.8943
# Epoch 28/30
# 📉 Learning rate at epoch 28: 0.000010.] - ETA: 0s - loss: 0.6163 - accuracy: 0.8728
# 812/812 [==============================] - 60s 74ms/step - loss: 0.6164 - accuracy: 0.8728 - val_loss: 0.5670 - val_accuracy: 0.8959
# Epoch 29/30
# 📉 Learning rate at epoch 29: 0.000010.] - ETA: 0s - loss: 0.6115 - accuracy: 0.8745
# 812/812 [==============================] - 60s 74ms/step - loss: 0.6115 - accuracy: 0.8745 - val_loss: 0.5704 - val_accuracy: 0.8962
# Epoch 30/30
# 📉 Learning rate at epoch 30: 0.000010.] - ETA: 0s - loss: 0.6091 - accuracy: 0.8747
# 812/812 [==============================] - 60s 74ms/step - loss: 0.6091 - accuracy: 0.8747 - val_loss: 0.5555 - val_accuracy: 0.9037

# %%
# === Evaluate ===
print("\n📊 Evaluating Phase 1 Model...")
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report (Phase 1):")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix (Phase 1)")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\gan\MobileNetV3_Phase1_gan_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Phase 1 MobileNetV3 Model saved at: {SAVE_PATH}")
# Out:
# 📊 Evaluating Phase 1 Model...
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 1s 580ms/step
#
# 📊 Classification Report (Phase 1):
#               precision    recall  f1-score   support
#
#       BLIGHT       0.99      0.99      0.99      1615
#        BLAST       0.89      0.82      0.85      1618
#    BROWNSPOT       0.93      0.88      0.91      1636
#      HEALTHY       0.82      0.93      0.87      1623
#
#     accuracy                           0.90      6492
#    macro avg       0.91      0.90      0.90      6492
# weighted avg       0.91      0.90      0.90      6492
# ✅ Phase 1 MobileNetV3 Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\gan\MobileNetV3_Phase1_gan_noaug.h5
