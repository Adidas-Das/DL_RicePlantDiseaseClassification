# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
# Import NASNetLarge or NASNetMobile
from tensorflow.keras.applications import NASNetLarge, NASNetMobile
# Import their respective preprocess_input functions
from tensorflow.keras.applications.nasnet import preprocess_input as nasnet_preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_GAN"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
# NASNetLarge expects input shape (331, 331), NASNetMobile expects (224, 224)
# Choose the appropriate IMG_SIZE based on your chosen NASNet model
# IMG_SIZE = (331, 331) # For NASNetLarge
IMG_SIZE = (224, 224) # For NASNetMobile
BATCH_SIZE = 32
EPOCHS = 30
LEARNING_RATE = 1e-5

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 32460

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 25968 | Val samples: 6492

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    # Use NASNet's preprocess_input function
    img = nasnet_preprocess_input(img)

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === NASNet Model ===
# Choose NASNetLarge or NASNetMobile
# base_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
base_model = NASNetMobile(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))


# Unfreeze last few layers (adjust as needed for NASNet)
# NASNet models have a different layer structure than ResNet.
# Instead of unfreezing a fixed number of layers, it's often better to unfreeze
# a block or unfreeze all layers and use a very low learning rate.
# For simplicity and to adhere to "only modify what is absolutely necessary",
# we will keep the entire base model frozen for this phase 1 training.
# If you want to unfreeze, you would need to inspect the model.summary()
# to identify appropriate layers/blocks.
for layer in base_model.layers:
    layer.trainable = False

inputs = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/30
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 1.2246 - accuracy: 0.4699
# 812/812 [==============================] - 127s 144ms/step - loss: 1.2246 - accuracy: 0.4699 - val_loss: 1.0367 - val_accuracy: 0.6235
# Epoch 2/30
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 1.0378 - accuracy: 0.6099
# 812/812 [==============================] - 110s 136ms/step - loss: 1.0378 - accuracy: 0.6099 - val_loss: 0.9272 - val_accuracy: 0.6747
# Epoch 3/30
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 0.9650 - accuracy: 0.6488
# 812/812 [==============================] - 109s 134ms/step - loss: 0.9650 - accuracy: 0.6488 - val_loss: 0.8786 - val_accuracy: 0.7002
# Epoch 4/30
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 0.9255 - accuracy: 0.6744
# 812/812 [==============================] - 122s 150ms/step - loss: 0.9255 - accuracy: 0.6744 - val_loss: 0.8432 - val_accuracy: 0.7235
# Epoch 5/30
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 0.8910 - accuracy: 0.6965
# 812/812 [==============================] - 122s 151ms/step - loss: 0.8910 - accuracy: 0.6965 - val_loss: 0.8280 - val_accuracy: 0.7355
# Epoch 6/30
# 📉 Learning rate at epoch 6: 0.000010==] - ETA: 0s - loss: 0.8662 - accuracy: 0.7153
# 812/812 [==============================] - 122s 151ms/step - loss: 0.8662 - accuracy: 0.7153 - val_loss: 0.7939 - val_accuracy: 0.7563
# Epoch 7/30
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 0.8508 - accuracy: 0.7224
# 812/812 [==============================] - 123s 151ms/step - loss: 0.8508 - accuracy: 0.7224 - val_loss: 0.7945 - val_accuracy: 0.7559
# Epoch 8/30
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 0.8360 - accuracy: 0.7346
# 812/812 [==============================] - 126s 155ms/step - loss: 0.8360 - accuracy: 0.7346 - val_loss: 0.7779 - val_accuracy: 0.7714
# Epoch 9/30
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 0.8228 - accuracy: 0.7412
# 812/812 [==============================] - 118s 145ms/step - loss: 0.8228 - accuracy: 0.7412 - val_loss: 0.7778 - val_accuracy: 0.7694
# Epoch 10/30
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 0.8136 - accuracy: 0.7482
# 812/812 [==============================] - 117s 144ms/step - loss: 0.8136 - accuracy: 0.7482 - val_loss: 0.7630 - val_accuracy: 0.7723
# Epoch 11/30
# 📉 Learning rate at epoch 11: 0.000010=] - ETA: 0s - loss: 0.8034 - accuracy: 0.7550
# 812/812 [==============================] - 111s 136ms/step - loss: 0.8034 - accuracy: 0.7550 - val_loss: 0.7461 - val_accuracy: 0.7910
# Epoch 12/30
# 📉 Learning rate at epoch 12: 0.000010=] - ETA: 0s - loss: 0.7917 - accuracy: 0.7596
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7917 - accuracy: 0.7596 - val_loss: 0.7495 - val_accuracy: 0.7891
# Epoch 13/30
# 📉 Learning rate at epoch 13: 0.000010=] - ETA: 0s - loss: 0.7842 - accuracy: 0.7691
# 812/812 [==============================] - 113s 139ms/step - loss: 0.7842 - accuracy: 0.7691 - val_loss: 0.7370 - val_accuracy: 0.7962
# Epoch 14/30
# 📉 Learning rate at epoch 14: 0.000010=] - ETA: 0s - loss: 0.7774 - accuracy: 0.7747
# 812/812 [==============================] - 118s 145ms/step - loss: 0.7774 - accuracy: 0.7747 - val_loss: 0.7305 - val_accuracy: 0.7965
# Epoch 15/30
# 📉 Learning rate at epoch 15: 0.000010=] - ETA: 0s - loss: 0.7697 - accuracy: 0.7730
# 812/812 [==============================] - 118s 145ms/step - loss: 0.7697 - accuracy: 0.7730 - val_loss: 0.7112 - val_accuracy: 0.8138
# Epoch 16/30
# 📉 Learning rate at epoch 16: 0.000010=] - ETA: 0s - loss: 0.7667 - accuracy: 0.7797
# 812/812 [==============================] - 116s 143ms/step - loss: 0.7667 - accuracy: 0.7797 - val_loss: 0.7191 - val_accuracy: 0.8042
# Epoch 17/30
# 📉 Learning rate at epoch 17: 0.000010=] - ETA: 0s - loss: 0.7566 - accuracy: 0.7851
# 812/812 [==============================] - 122s 150ms/step - loss: 0.7566 - accuracy: 0.7851 - val_loss: 0.7112 - val_accuracy: 0.8122
# Epoch 18/30
# 📉 Learning rate at epoch 18: 0.000010=] - ETA: 0s - loss: 0.7519 - accuracy: 0.7889
# 812/812 [==============================] - 120s 148ms/step - loss: 0.7519 - accuracy: 0.7889 - val_loss: 0.7131 - val_accuracy: 0.8107
# Epoch 19/30
# 📉 Learning rate at epoch 19: 0.000010=] - ETA: 0s - loss: 0.7483 - accuracy: 0.7895
# 812/812 [==============================] - 122s 150ms/step - loss: 0.7483 - accuracy: 0.7895 - val_loss: 0.6965 - val_accuracy: 0.8164
# Epoch 20/30
# 📉 Learning rate at epoch 20: 0.000010=] - ETA: 0s - loss: 0.7420 - accuracy: 0.7949
# 812/812 [==============================] - 113s 139ms/step - loss: 0.7420 - accuracy: 0.7949 - val_loss: 0.7027 - val_accuracy: 0.8167
# Epoch 21/30
# 📉 Learning rate at epoch 21: 0.000010=] - ETA: 0s - loss: 0.7382 - accuracy: 0.7966
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7382 - accuracy: 0.7966 - val_loss: 0.6916 - val_accuracy: 0.8273
# Epoch 22/30
# 📉 Learning rate at epoch 22: 0.000010=] - ETA: 0s - loss: 0.7321 - accuracy: 0.8016
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7321 - accuracy: 0.8016 - val_loss: 0.6894 - val_accuracy: 0.8299
# Epoch 23/30
# 📉 Learning rate at epoch 23: 0.000010=] - ETA: 0s - loss: 0.7309 - accuracy: 0.8001
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7309 - accuracy: 0.8001 - val_loss: 0.6921 - val_accuracy: 0.8255
# Epoch 24/30
# 📉 Learning rate at epoch 24: 0.000010=] - ETA: 0s - loss: 0.7250 - accuracy: 0.8052
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7250 - accuracy: 0.8052 - val_loss: 0.6790 - val_accuracy: 0.8349
# Epoch 25/30
# 📉 Learning rate at epoch 25: 0.000010=] - ETA: 0s - loss: 0.7236 - accuracy: 0.8079
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7236 - accuracy: 0.8079 - val_loss: 0.6776 - val_accuracy: 0.8312
# Epoch 26/30
# 📉 Learning rate at epoch 26: 0.000010=] - ETA: 0s - loss: 0.7158 - accuracy: 0.8103
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7158 - accuracy: 0.8103 - val_loss: 0.6657 - val_accuracy: 0.8441
# Epoch 27/30
# 📉 Learning rate at epoch 27: 0.000010=] - ETA: 0s - loss: 0.7139 - accuracy: 0.8122
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7139 - accuracy: 0.8122 - val_loss: 0.6678 - val_accuracy: 0.8366
# Epoch 28/30
# 📉 Learning rate at epoch 28: 0.000010=] - ETA: 0s - loss: 0.7097 - accuracy: 0.8141
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7097 - accuracy: 0.8141 - val_loss: 0.6649 - val_accuracy: 0.8453
# Epoch 29/30
# 📉 Learning rate at epoch 29: 0.000010=] - ETA: 0s - loss: 0.7057 - accuracy: 0.8180
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7057 - accuracy: 0.8180 - val_loss: 0.6626 - val_accuracy: 0.8453
# Epoch 30/30
# 📉 Learning rate at epoch 30: 0.000010=] - ETA: 0s - loss: 0.7045 - accuracy: 0.8220
# 812/812 [==============================] - 104s 128ms/step - loss: 0.7045 - accuracy: 0.8220 - val_loss: 0.6435 - val_accuracy: 0.8537

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
# Update save path to reflect NASNet model
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\gan\NASNetMobile_Phase1_gan_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 2s 2s/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.95      0.95      0.95      1615
#        BLAST       0.80      0.72      0.76      1618
#    BROWNSPOT       0.88      0.82      0.85      1636
#      HEALTHY       0.77      0.91      0.84      1623
#
#     accuracy                           0.85      6492
#    macro avg       0.85      0.85      0.85      6492
# weighted avg       0.85      0.85      0.85      6492
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\gan\NASNetMobile_Phase1_gan_noaug.h5
