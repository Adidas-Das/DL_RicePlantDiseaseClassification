# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import (preprocess_input)
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASETS\new\CP_DATASET_GAN"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 32  # ✅ Smaller for BN layers
EPOCHS = 30
LEARNING_RATE = 1e-5  # ✅ Lower for frozen backbone

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 32460

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 25968 | Val samples: 6492

# %%
# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = preprocess_input(img)  # ✅ For ResNet50: scale to [-1, 1] the same way as pretraining

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === ResNet50 Model ===
base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# ✅ Unfreeze last 30 layers
for layer in base_model.layers:  # [:-30]:
    layer.trainable = False
# for layer in base_model.layers[-30:]:
#     layer.trainable = True

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)  # Important: BN layers training mode ON for partial unfrozen!
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        # If using a scheduler, it might be a callable or tensor
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch + 1}: {lr:.6f}")


# === Compute class weights ===
# y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
# class_weights = dict(enumerate(class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.arange(len(CLASSES)),
#     y=y_train_int
# )))
# print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()]
    # class_weight=class_weights
)
# Out:
# Epoch 1/30
# 📉 Learning rate at epoch 1: 0.000010==] - ETA: 0s - loss: 1.1560 - accuracy: 0.5356
# 812/812 [==============================] - 167s 201ms/step - loss: 1.1560 - accuracy: 0.5356 - val_loss: 0.9598 - val_accuracy: 0.6696
# Epoch 2/30
# 📉 Learning rate at epoch 2: 0.000010==] - ETA: 0s - loss: 0.9489 - accuracy: 0.6724
# 812/812 [==============================] - 162s 199ms/step - loss: 0.9489 - accuracy: 0.6724 - val_loss: 0.8451 - val_accuracy: 0.7318
# Epoch 3/30
# 📉 Learning rate at epoch 3: 0.000010==] - ETA: 0s - loss: 0.8799 - accuracy: 0.7126
# 812/812 [==============================] - 162s 200ms/step - loss: 0.8799 - accuracy: 0.7126 - val_loss: 0.8051 - val_accuracy: 0.7537
# Epoch 4/30
# 📉 Learning rate at epoch 4: 0.000010==] - ETA: 0s - loss: 0.8356 - accuracy: 0.7376
# 812/812 [==============================] - 162s 200ms/step - loss: 0.8356 - accuracy: 0.7376 - val_loss: 0.7662 - val_accuracy: 0.7790
# Epoch 5/30
# 📉 Learning rate at epoch 5: 0.000010==] - ETA: 0s - loss: 0.8068 - accuracy: 0.7543
# 812/812 [==============================] - 177s 218ms/step - loss: 0.8068 - accuracy: 0.7543 - val_loss: 0.7535 - val_accuracy: 0.7828
# Epoch 6/30
# 📉 Learning rate at epoch 6: 0.000010==] - ETA: 0s - loss: 0.7890 - accuracy: 0.7690
# 812/812 [==============================] - 190s 234ms/step - loss: 0.7890 - accuracy: 0.7690 - val_loss: 0.7266 - val_accuracy: 0.8048
# Epoch 7/30
# 📉 Learning rate at epoch 7: 0.000010==] - ETA: 0s - loss: 0.7722 - accuracy: 0.7787
# 812/812 [==============================] - 173s 213ms/step - loss: 0.7722 - accuracy: 0.7787 - val_loss: 0.7248 - val_accuracy: 0.8051
# Epoch 8/30
# 📉 Learning rate at epoch 8: 0.000010==] - ETA: 0s - loss: 0.7564 - accuracy: 0.7909
# 812/812 [==============================] - 189s 233ms/step - loss: 0.7564 - accuracy: 0.7909 - val_loss: 0.7079 - val_accuracy: 0.8212
# Epoch 9/30
# 📉 Learning rate at epoch 9: 0.000010==] - ETA: 0s - loss: 0.7431 - accuracy: 0.7964
# 812/812 [==============================] - 179s 221ms/step - loss: 0.7431 - accuracy: 0.7964 - val_loss: 0.6971 - val_accuracy: 0.8255
# Epoch 10/30
# 📉 Learning rate at epoch 10: 0.000010=] - ETA: 0s - loss: 0.7330 - accuracy: 0.8006
# 812/812 [==============================] - 167s 206ms/step - loss: 0.7330 - accuracy: 0.8006 - val_loss: 0.6941 - val_accuracy: 0.8210
# Epoch 11/30
# 📉 Learning rate at epoch 11: 0.000010=] - ETA: 0s - loss: 0.7233 - accuracy: 0.8065
# 812/812 [==============================] - 161s 199ms/step - loss: 0.7233 - accuracy: 0.8065 - val_loss: 0.6779 - val_accuracy: 0.8292
# Epoch 12/30
# 📉 Learning rate at epoch 12: 0.000010=] - ETA: 0s - loss: 0.7141 - accuracy: 0.8131
# 812/812 [==============================] - 166s 205ms/step - loss: 0.7141 - accuracy: 0.8131 - val_loss: 0.6793 - val_accuracy: 0.8318
# Epoch 13/30
# 📉 Learning rate at epoch 13: 0.000010=] - ETA: 0s - loss: 0.7065 - accuracy: 0.8183
# 812/812 [==============================] - 190s 234ms/step - loss: 0.7065 - accuracy: 0.8183 - val_loss: 0.6657 - val_accuracy: 0.8420
# Epoch 14/30
# 📉 Learning rate at epoch 14: 0.000010=] - ETA: 0s - loss: 0.6985 - accuracy: 0.8267
# 812/812 [==============================] - 186s 229ms/step - loss: 0.6985 - accuracy: 0.8267 - val_loss: 0.6637 - val_accuracy: 0.8440
# Epoch 15/30
# 📉 Learning rate at epoch 15: 0.000010=] - ETA: 0s - loss: 0.6912 - accuracy: 0.8264
# 812/812 [==============================] - 190s 234ms/step - loss: 0.6912 - accuracy: 0.8264 - val_loss: 0.6527 - val_accuracy: 0.8489
# Epoch 16/30
# 📉 Learning rate at epoch 16: 0.000010=] - ETA: 0s - loss: 0.6872 - accuracy: 0.8289
# 812/812 [==============================] - 185s 228ms/step - loss: 0.6872 - accuracy: 0.8289 - val_loss: 0.6474 - val_accuracy: 0.8478
# Epoch 17/30
# 📉 Learning rate at epoch 17: 0.000010=] - ETA: 0s - loss: 0.6800 - accuracy: 0.8351
# 812/812 [==============================] - 180s 222ms/step - loss: 0.6800 - accuracy: 0.8351 - val_loss: 0.6451 - val_accuracy: 0.8524
# Epoch 18/30
# 📉 Learning rate at epoch 18: 0.000010=] - ETA: 0s - loss: 0.6756 - accuracy: 0.8373
# 812/812 [==============================] - 173s 213ms/step - loss: 0.6756 - accuracy: 0.8373 - val_loss: 0.6387 - val_accuracy: 0.8595
# Epoch 19/30
# 📉 Learning rate at epoch 19: 0.000010=] - ETA: 0s - loss: 0.6683 - accuracy: 0.8418
# 812/812 [==============================] - 209s 257ms/step - loss: 0.6683 - accuracy: 0.8418 - val_loss: 0.6336 - val_accuracy: 0.8561
# Epoch 20/30
# 📉 Learning rate at epoch 20: 0.000010=] - ETA: 0s - loss: 0.6614 - accuracy: 0.8458
# 812/812 [==============================] - 212s 260ms/step - loss: 0.6614 - accuracy: 0.8458 - val_loss: 0.6279 - val_accuracy: 0.8601
# Epoch 21/30
# 📉 Learning rate at epoch 21: 0.000010=] - ETA: 0s - loss: 0.6599 - accuracy: 0.8474
# 812/812 [==============================] - 193s 238ms/step - loss: 0.6599 - accuracy: 0.8474 - val_loss: 0.6235 - val_accuracy: 0.8649
# Epoch 22/30
# 📉 Learning rate at epoch 22: 0.000010=] - ETA: 0s - loss: 0.6531 - accuracy: 0.8512
# 812/812 [==============================] - 161s 199ms/step - loss: 0.6531 - accuracy: 0.8512 - val_loss: 0.6222 - val_accuracy: 0.8666
# Epoch 23/30
# 📉 Learning rate at epoch 23: 0.000010=] - ETA: 0s - loss: 0.6520 - accuracy: 0.8490
# 812/812 [==============================] - 161s 199ms/step - loss: 0.6520 - accuracy: 0.8490 - val_loss: 0.6144 - val_accuracy: 0.8742
# Epoch 24/30
# 📉 Learning rate at epoch 24: 0.000010=] - ETA: 0s - loss: 0.6471 - accuracy: 0.8540
# 812/812 [==============================] - 181s 223ms/step - loss: 0.6471 - accuracy: 0.8540 - val_loss: 0.6099 - val_accuracy: 0.8766
# Epoch 25/30
# 📉 Learning rate at epoch 25: 0.000010=] - ETA: 0s - loss: 0.6416 - accuracy: 0.8579
# 812/812 [==============================] - 198s 244ms/step - loss: 0.6416 - accuracy: 0.8579 - val_loss: 0.6034 - val_accuracy: 0.8805
# Epoch 26/30
# 📉 Learning rate at epoch 26: 0.000010=] - ETA: 0s - loss: 0.6366 - accuracy: 0.8621
# 812/812 [==============================] - 174s 215ms/step - loss: 0.6366 - accuracy: 0.8621 - val_loss: 0.6036 - val_accuracy: 0.8789
# Epoch 27/30
# 📉 Learning rate at epoch 27: 0.000010=] - ETA: 0s - loss: 0.6363 - accuracy: 0.8608
# 812/812 [==============================] - 175s 215ms/step - loss: 0.6363 - accuracy: 0.8608 - val_loss: 0.6009 - val_accuracy: 0.8805
# Epoch 28/30
# 📉 Learning rate at epoch 28: 0.000010=] - ETA: 0s - loss: 0.6312 - accuracy: 0.8632
# 812/812 [==============================] - 176s 217ms/step - loss: 0.6312 - accuracy: 0.8632 - val_loss: 0.5950 - val_accuracy: 0.8832
# Epoch 29/30
# 📉 Learning rate at epoch 29: 0.000010=] - ETA: 0s - loss: 0.6271 - accuracy: 0.8673
# 812/812 [==============================] - 186s 229ms/step - loss: 0.6271 - accuracy: 0.8673 - val_loss: 0.5920 - val_accuracy: 0.8834
# Epoch 30/30
# 📉 Learning rate at epoch 30: 0.000010=] - ETA: 0s - loss: 0.6247 - accuracy: 0.8679
# 812/812 [==============================] - 183s 226ms/step - loss: 0.6247 - accuracy: 0.8679 - val_loss: 0.5761 - val_accuracy: 0.8976

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\gan\Xception_Phase1_gan_noaug.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 444ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       0.97      0.98      0.98      1615
#        BLAST       0.86      0.81      0.83      1618
#    BROWNSPOT       0.94      0.85      0.89      1636
#      HEALTHY       0.82      0.94      0.87      1623
#
#     accuracy                           0.89      6492
#    macro avg       0.90      0.89      0.89      6492
# weighted avg       0.90      0.89      0.89      6492
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\NEW_STAGE_MODELS\gan\Xception_Phase1_gan_noaug.h5
