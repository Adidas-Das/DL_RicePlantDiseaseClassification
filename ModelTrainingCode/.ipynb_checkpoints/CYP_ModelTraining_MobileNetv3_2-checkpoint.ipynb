# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASET_F1"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 16
EPOCHS = 60 # Can be adjusted, often more epochs for fine-tuning
LEARNING_RATE = 1e-5 # Even lower learning rate for fine-tuning

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 32460

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 25968 | Val samples: 6492

# %%
# === Color Jitter ===
def color_jitter(image):
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.05)
    return tf.clip_by_value(image, 0.0, 255.0)

# === GridMask ===
def grid_mask(image, d_min=50, d_max=100, ratio=0.5):
    h, w, _ = image.shape
    d = tf.random.uniform([], d_min, d_max, dtype=tf.int32)
    l = tf.cast(tf.cast(d, tf.float32) * ratio, tf.int32)

    mask = tf.ones([h, w], dtype=tf.float32)

    for i in range(0, h, d):
        for j in range(0, w, d):
            y1 = i
            y2 = tf.minimum(i + l, h)
            x1 = j
            x2 = tf.minimum(j + l, w)

            y_range = tf.range(y1, y2)
            x_range = tf.range(x1, x2)
            yy, xx = tf.meshgrid(y_range, x_range, indexing='ij')
            indices = tf.stack([yy, xx], axis=-1)
            indices = tf.reshape(indices, [-1, 2])

            mask = tf.tensor_scatter_nd_update(
                mask,
                indices,
                tf.zeros([(y2 - y1) * (x2 - x1)], dtype=tf.float32)
            )

    mask = tf.expand_dims(mask, axis=-1)
    mask = tf.tile(mask, [1, 1, 3])
    return image * mask

# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = color_jitter(img)
    img = grid_mask(img)

    img = preprocess_input(img) # For MobileNetV3

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# # === CutMix ===
# def cutmix(images, labels, alpha=1.0):
#     batch_size = tf.shape(images)[0]
#     img_h = tf.shape(images)[1]
#     img_w = tf.shape(images)[2]

#     lam = tfp.distributions.Beta(alpha, alpha).sample([batch_size])

#     rand_idx = tf.random.shuffle(tf.range(batch_size))
#     images2 = tf.gather(images, rand_idx)
#     labels2 = tf.gather(labels, rand_idx)

#     cut_rat = tf.math.sqrt(1. - lam)
#     cut_w = tf.cast(img_w, tf.float32) * cut_rat
#     cut_h = tf.cast(img_h, tf.float32) * cut_rat

#     cx = tf.random.uniform([batch_size], 0, tf.cast(img_w, tf.float32))
#     cy = tf.random.uniform([batch_size], 0, tf.cast(img_h, tf.float32))

#     x1 = tf.cast(cx - cut_w / 2, tf.int32)
#     y1 = tf.cast(cy - cut_h / 2, tf.int32)
#     x2 = tf.cast(cx + cut_w / 2, tf.int32)
#     y2 = tf.cast(cy + cut_h / 2, tf.int32)

#     x1 = tf.clip_by_value(x1, 0, img_w)
#     y1 = tf.clip_by_value(y1, 0, img_h)
#     x2 = tf.clip_by_value(x2, 0, img_w)
#     y2 = tf.clip_by_value(y2, 0, img_h)

#     def apply_cutmix(i):
#         img1 = images[i]
#         img2 = images2[i]
#         bbx1, bby1, bbx2, bby2 = x1[i], y1[i], x2[i], y2[i]

#         mask = tf.pad(
#             tf.zeros([bby2 - bby1, bbx2 - bbx1, 3]),
#             [[bby1, img_h - bby2],
#              [bbx1, img_w - bbx2],
#              [0, 0]],
#             constant_values=1.0
#         )
#         mask = 1.0 - mask
#         mixed = img1 * mask + img2 * (1.0 - mask)

#         area = tf.cast(bbx2 - bbx1, tf.float32) * tf.cast(bby2 - bby1, tf.float32)
#         lam_adjusted = 1.0 - (area / tf.cast(img_w * img_h, tf.float32))
#         new_label = lam_adjusted * labels[i] + (1.0 - lam_adjusted) * labels2[i]

#         return mixed, new_label

#     mixed_images, mixed_labels = tf.map_fn(
#         apply_cutmix,
#         tf.range(batch_size),
#         fn_output_signature=(tf.float32, tf.float32)
#     )

#     return mixed_images, mixed_labels

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
# train_ds = train_ds.map(lambda x, y: cutmix(x, y)).prefetch(tf.data.AUTOTUNE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === MobileNetV3 Model (Load from Phase 1 and Unfreeze) ===
# Load the model saved from Phase 1
# model = load_model(r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\MobileNetV3_Phase1_CutMix_GridMask.h5")
model = load_model(r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\MobileNetV3_Phase1_GridMask.h5")

# Unfreeze all layers of the model for fine-tuning
# You might choose to unfreeze only a portion, e.g., model.layers[-N:]
for layer in model.layers:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05), # Slightly reduced label smoothing
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
class_weights = dict(enumerate(class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(CLASSES)),
    y=y_train_int
)))
print("✅ Computed class weights:", class_weights)
# Out:
# ✅ Computed class weights: {0: 0.9976947902259106, 1: 1.0065116279069768, 2: 0.9925087907047851, 3: 1.003400309119011}

# %%
# === Train ===
print("\nStarting Phase 2 Training (MobileNetV3 - Fine-tuning)...")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=5, restore_best_weights=True), LearningRateLogger()], # Increased patience for fine-tuning
    class_weight=class_weights
)
# Out:
# Starting Phase 2 Training (MobileNetV3 - Fine-tuning)...
# Epoch 1/60
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0435s vs `on_train_batch_end` time: 0.0667s). Check your callbacks.
# 📉 Learning rate at epoch 1: 0.000010====] - ETA: 0s - loss: 0.6401 - accuracy: 0.7940
# 1623/1623 [==============================] - 187s 111ms/step - loss: 0.6401 - accuracy: 0.7940 - val_loss: 0.5603 - val_accuracy: 0.8358
# Epoch 2/60
# 📉 Learning rate at epoch 2: 0.000010====] - ETA: 0s - loss: 0.5720 - accuracy: 0.8329
# 1623/1623 [==============================] - 180s 111ms/step - loss: 0.5720 - accuracy: 0.8329 - val_loss: 0.5160 - val_accuracy: 0.8611
# Epoch 3/60
# 📉 Learning rate at epoch 3: 0.000010====] - ETA: 0s - loss: 0.5309 - accuracy: 0.8539
# 1623/1623 [==============================] - 196s 121ms/step - loss: 0.5309 - accuracy: 0.8539 - val_loss: 0.4830 - val_accuracy: 0.8765
# Epoch 4/60
# 📉 Learning rate at epoch 4: 0.000010====] - ETA: 0s - loss: 0.5054 - accuracy: 0.8675
# 1623/1623 [==============================] - 203s 125ms/step - loss: 0.5054 - accuracy: 0.8675 - val_loss: 0.4703 - val_accuracy: 0.8797
# Epoch 5/60
# 📉 Learning rate at epoch 5: 0.000010====] - ETA: 0s - loss: 0.4807 - accuracy: 0.8802
# 1623/1623 [==============================] - 190s 117ms/step - loss: 0.4807 - accuracy: 0.8802 - val_loss: 0.4392 - val_accuracy: 0.8990
# Epoch 6/60
# 📉 Learning rate at epoch 6: 0.000010====] - ETA: 0s - loss: 0.4668 - accuracy: 0.8859
# 1623/1623 [==============================] - 178s 110ms/step - loss: 0.4668 - accuracy: 0.8859 - val_loss: 0.4363 - val_accuracy: 0.8971
# Epoch 7/60
# 📉 Learning rate at epoch 7: 0.000010====] - ETA: 0s - loss: 0.4525 - accuracy: 0.8940
# 1623/1623 [==============================] - 188s 116ms/step - loss: 0.4525 - accuracy: 0.8940 - val_loss: 0.4242 - val_accuracy: 0.9019
# Epoch 8/60
# 📉 Learning rate at epoch 8: 0.000010====] - ETA: 0s - loss: 0.4405 - accuracy: 0.8990
# 1623/1623 [==============================] - 180s 111ms/step - loss: 0.4405 - accuracy: 0.8990 - val_loss: 0.4098 - val_accuracy: 0.9148
# Epoch 9/60
# 📉 Learning rate at epoch 9: 0.000010====] - ETA: 0s - loss: 0.4248 - accuracy: 0.9057
# 1623/1623 [==============================] - 188s 116ms/step - loss: 0.4248 - accuracy: 0.9057 - val_loss: 0.3954 - val_accuracy: 0.9202
# Epoch 10/60
# 📉 Learning rate at epoch 10: 0.000010===] - ETA: 0s - loss: 0.4166 - accuracy: 0.9121
# 1623/1623 [==============================] - 186s 114ms/step - loss: 0.4166 - accuracy: 0.9121 - val_loss: 0.3885 - val_accuracy: 0.9225
# Epoch 11/60
# 📉 Learning rate at epoch 11: 0.000010===] - ETA: 0s - loss: 0.4106 - accuracy: 0.9136
# 1623/1623 [==============================] - 180s 111ms/step - loss: 0.4106 - accuracy: 0.9136 - val_loss: 0.3807 - val_accuracy: 0.9230
# Epoch 12/60
# 📉 Learning rate at epoch 12: 0.000010===] - ETA: 0s - loss: 0.3982 - accuracy: 0.9207
# 1623/1623 [==============================] - 182s 112ms/step - loss: 0.3982 - accuracy: 0.9207 - val_loss: 0.3757 - val_accuracy: 0.9251
# Epoch 13/60
# 📉 Learning rate at epoch 13: 0.000010===] - ETA: 0s - loss: 0.3905 - accuracy: 0.9220
# 1623/1623 [==============================] - 180s 111ms/step - loss: 0.3905 - accuracy: 0.9220 - val_loss: 0.3711 - val_accuracy: 0.9264
# Epoch 14/60
# 📉 Learning rate at epoch 14: 0.000010===] - ETA: 0s - loss: 0.3845 - accuracy: 0.9255
# 1623/1623 [==============================] - 187s 115ms/step - loss: 0.3845 - accuracy: 0.9255 - val_loss: 0.3706 - val_accuracy: 0.9279
# Epoch 15/60
# 📉 Learning rate at epoch 15: 0.000010===] - ETA: 0s - loss: 0.3749 - accuracy: 0.9290
# 1623/1623 [==============================] - 179s 110ms/step - loss: 0.3749 - accuracy: 0.9290 - val_loss: 0.3626 - val_accuracy: 0.9310
# Epoch 16/60
# 📉 Learning rate at epoch 16: 0.000010===] - ETA: 0s - loss: 0.3722 - accuracy: 0.9295
# 1623/1623 [==============================] - 191s 117ms/step - loss: 0.3722 - accuracy: 0.9295 - val_loss: 0.3571 - val_accuracy: 0.9336
# Epoch 17/60
# 📉 Learning rate at epoch 17: 0.000010===] - ETA: 0s - loss: 0.3653 - accuracy: 0.9333
# 1623/1623 [==============================] - 185s 114ms/step - loss: 0.3653 - accuracy: 0.9333 - val_loss: 0.3388 - val_accuracy: 0.9422
# Epoch 18/60
# 📉 Learning rate at epoch 18: 0.000010===] - ETA: 0s - loss: 0.3596 - accuracy: 0.9378
# 1623/1623 [==============================] - 187s 115ms/step - loss: 0.3596 - accuracy: 0.9378 - val_loss: 0.3372 - val_accuracy: 0.9422
# Epoch 19/60
# 📉 Learning rate at epoch 19: 0.000010===] - ETA: 0s - loss: 0.3540 - accuracy: 0.9387
# 1623/1623 [==============================] - 193s 119ms/step - loss: 0.3540 - accuracy: 0.9387 - val_loss: 0.3358 - val_accuracy: 0.9445
# Epoch 20/60
# 📉 Learning rate at epoch 20: 0.000010===] - ETA: 0s - loss: 0.3468 - accuracy: 0.9421
# 1623/1623 [==============================] - 191s 118ms/step - loss: 0.3468 - accuracy: 0.9421 - val_loss: 0.3291 - val_accuracy: 0.9490
# Epoch 21/60
# 📉 Learning rate at epoch 21: 0.000010===] - ETA: 0s - loss: 0.3448 - accuracy: 0.9423
# 1623/1623 [==============================] - 191s 118ms/step - loss: 0.3448 - accuracy: 0.9423 - val_loss: 0.3217 - val_accuracy: 0.9524
# Epoch 22/60
# 📉 Learning rate at epoch 22: 0.000010===] - ETA: 0s - loss: 0.3367 - accuracy: 0.9465
# 1623/1623 [==============================] - 192s 118ms/step - loss: 0.3367 - accuracy: 0.9465 - val_loss: 0.3176 - val_accuracy: 0.9526
# Epoch 23/60
# 📉 Learning rate at epoch 23: 0.000010===] - ETA: 0s - loss: 0.3325 - accuracy: 0.9480
# 1623/1623 [==============================] - 192s 118ms/step - loss: 0.3325 - accuracy: 0.9480 - val_loss: 0.3185 - val_accuracy: 0.9550
# Epoch 24/60
# 📉 Learning rate at epoch 24: 0.000010===] - ETA: 0s - loss: 0.3303 - accuracy: 0.9491
# 1623/1623 [==============================] - 200s 123ms/step - loss: 0.3303 - accuracy: 0.9491 - val_loss: 0.3064 - val_accuracy: 0.9564
# Epoch 25/60
# 📉 Learning rate at epoch 25: 0.000010===] - ETA: 0s - loss: 0.3222 - accuracy: 0.9522
# 1623/1623 [==============================] - 197s 121ms/step - loss: 0.3222 - accuracy: 0.9522 - val_loss: 0.3103 - val_accuracy: 0.9550
# Epoch 26/60
# 📉 Learning rate at epoch 26: 0.000010===] - ETA: 0s - loss: 0.3186 - accuracy: 0.9543
# 1623/1623 [==============================] - 201s 124ms/step - loss: 0.3186 - accuracy: 0.9543 - val_loss: 0.2942 - val_accuracy: 0.9643
# Epoch 27/60
# 📉 Learning rate at epoch 27: 0.000010===] - ETA: 0s - loss: 0.3150 - accuracy: 0.9561
# 1623/1623 [==============================] - 188s 116ms/step - loss: 0.3150 - accuracy: 0.9561 - val_loss: 0.3004 - val_accuracy: 0.9586
# Epoch 28/60
# 📉 Learning rate at epoch 28: 0.000010===] - ETA: 0s - loss: 0.3123 - accuracy: 0.9572
# 1623/1623 [==============================] - 170s 105ms/step - loss: 0.3123 - accuracy: 0.9572 - val_loss: 0.2957 - val_accuracy: 0.9604
# Epoch 29/60
# 📉 Learning rate at epoch 29: 0.000010===] - ETA: 0s - loss: 0.3074 - accuracy: 0.9591
# 1623/1623 [==============================] - 171s 105ms/step - loss: 0.3074 - accuracy: 0.9591 - val_loss: 0.2887 - val_accuracy: 0.9664
# Epoch 30/60
# 📉 Learning rate at epoch 30: 0.000010===] - ETA: 0s - loss: 0.3051 - accuracy: 0.9604
# 1623/1623 [==============================] - 171s 106ms/step - loss: 0.3051 - accuracy: 0.9604 - val_loss: 0.2822 - val_accuracy: 0.9698
# Epoch 31/60
# 📉 Learning rate at epoch 31: 0.000010===] - ETA: 0s - loss: 0.3016 - accuracy: 0.9611
# 1623/1623 [==============================] - 170s 105ms/step - loss: 0.3016 - accuracy: 0.9611 - val_loss: 0.2889 - val_accuracy: 0.9646
# Epoch 32/60
# 📉 Learning rate at epoch 32: 0.000010===] - ETA: 0s - loss: 0.2979 - accuracy: 0.9628
# 1623/1623 [==============================] - 170s 105ms/step - loss: 0.2979 - accuracy: 0.9628 - val_loss: 0.2787 - val_accuracy: 0.9700
# Epoch 33/60
# 📉 Learning rate at epoch 33: 0.000010===] - ETA: 0s - loss: 0.2923 - accuracy: 0.9658
# 1623/1623 [==============================] - 171s 105ms/step - loss: 0.2923 - accuracy: 0.9658 - val_loss: 0.2830 - val_accuracy: 0.9675
# Epoch 34/60
# 📉 Learning rate at epoch 34: 0.000010===] - ETA: 0s - loss: 0.2882 - accuracy: 0.9680
# 1623/1623 [==============================] - 171s 105ms/step - loss: 0.2882 - accuracy: 0.9680 - val_loss: 0.2726 - val_accuracy: 0.9715
# Epoch 35/60
# 📉 Learning rate at epoch 35: 0.000010===] - ETA: 0s - loss: 0.2870 - accuracy: 0.9671
# 1623/1623 [==============================] - 171s 105ms/step - loss: 0.2870 - accuracy: 0.9671 - val_loss: 0.2699 - val_accuracy: 0.9720
# Epoch 36/60
# 📉 Learning rate at epoch 36: 0.000010===] - ETA: 0s - loss: 0.2832 - accuracy: 0.9702
# 1623/1623 [==============================] - 170s 105ms/step - loss: 0.2832 - accuracy: 0.9702 - val_loss: 0.2696 - val_accuracy: 0.9740
# Epoch 37/60
# 📉 Learning rate at epoch 37: 0.000010===] - ETA: 0s - loss: 0.2807 - accuracy: 0.9715
# 1623/1623 [==============================] - 214s 132ms/step - loss: 0.2807 - accuracy: 0.9715 - val_loss: 0.2634 - val_accuracy: 0.9777
# Epoch 38/60
# 📉 Learning rate at epoch 38: 0.000010===] - ETA: 0s - loss: 0.2779 - accuracy: 0.9717
# 1623/1623 [==============================] - 207s 127ms/step - loss: 0.2779 - accuracy: 0.9717 - val_loss: 0.2667 - val_accuracy: 0.9730
# Epoch 39/60
# 📉 Learning rate at epoch 39: 0.000010===] - ETA: 0s - loss: 0.2757 - accuracy: 0.9726
# 1623/1623 [==============================] - 173s 107ms/step - loss: 0.2757 - accuracy: 0.9726 - val_loss: 0.2599 - val_accuracy: 0.9789
# Epoch 40/60
# 📉 Learning rate at epoch 40: 0.000010===] - ETA: 0s - loss: 0.2717 - accuracy: 0.9745
# 1623/1623 [==============================] - 174s 107ms/step - loss: 0.2717 - accuracy: 0.9745 - val_loss: 0.2562 - val_accuracy: 0.9811
# Epoch 41/60
# 📉 Learning rate at epoch 41: 0.000010===] - ETA: 0s - loss: 0.2715 - accuracy: 0.9745
# 1623/1623 [==============================] - 174s 107ms/step - loss: 0.2715 - accuracy: 0.9745 - val_loss: 0.2519 - val_accuracy: 0.9817
# Epoch 42/60
# 📉 Learning rate at epoch 42: 0.000010===] - ETA: 0s - loss: 0.2664 - accuracy: 0.9769
# 1623/1623 [==============================] - 173s 106ms/step - loss: 0.2664 - accuracy: 0.9769 - val_loss: 0.2523 - val_accuracy: 0.9817
# Epoch 43/60
# 📉 Learning rate at epoch 43: 0.000010===] - ETA: 0s - loss: 0.2654 - accuracy: 0.9768
# 1623/1623 [==============================] - 197s 121ms/step - loss: 0.2654 - accuracy: 0.9768 - val_loss: 0.2582 - val_accuracy: 0.9787
# Epoch 44/60
# 📉 Learning rate at epoch 44: 0.000010===] - ETA: 0s - loss: 0.2636 - accuracy: 0.9781
# 1623/1623 [==============================] - 176s 108ms/step - loss: 0.2636 - accuracy: 0.9781 - val_loss: 0.2512 - val_accuracy: 0.9803
# Epoch 45/60
# 📉 Learning rate at epoch 45: 0.000010===] - ETA: 0s - loss: 0.2602 - accuracy: 0.9788
# 1623/1623 [==============================] - 196s 121ms/step - loss: 0.2602 - accuracy: 0.9788 - val_loss: 0.2482 - val_accuracy: 0.9827
# Epoch 46/60
# 📉 Learning rate at epoch 46: 0.000010===] - ETA: 0s - loss: 0.2601 - accuracy: 0.9800
# 1623/1623 [==============================] - 214s 132ms/step - loss: 0.2601 - accuracy: 0.9800 - val_loss: 0.2557 - val_accuracy: 0.9803
# Epoch 47/60
# 📉 Learning rate at epoch 47: 0.000010===] - ETA: 0s - loss: 0.2553 - accuracy: 0.9818
# 1623/1623 [==============================] - 173s 106ms/step - loss: 0.2553 - accuracy: 0.9818 - val_loss: 0.2488 - val_accuracy: 0.9827
# Epoch 48/60
# 📉 Learning rate at epoch 48: 0.000010===] - ETA: 0s - loss: 0.2545 - accuracy: 0.9822
# 1623/1623 [==============================] - 178s 109ms/step - loss: 0.2545 - accuracy: 0.9822 - val_loss: 0.2408 - val_accuracy: 0.9863
# Epoch 49/60
# 📉 Learning rate at epoch 49: 0.000010===] - ETA: 0s - loss: 0.2514 - accuracy: 0.9834
# 1623/1623 [==============================] - 180s 111ms/step - loss: 0.2514 - accuracy: 0.9834 - val_loss: 0.2435 - val_accuracy: 0.9857
# Epoch 50/60
# 📉 Learning rate at epoch 50: 0.000010===] - ETA: 0s - loss: 0.2502 - accuracy: 0.9839
# 1623/1623 [==============================] - 178s 110ms/step - loss: 0.2502 - accuracy: 0.9839 - val_loss: 0.2428 - val_accuracy: 0.9844
# Epoch 51/60
# 📉 Learning rate at epoch 51: 0.000010===] - ETA: 0s - loss: 0.2483 - accuracy: 0.9844
# 1623/1623 [==============================] - 193s 119ms/step - loss: 0.2483 - accuracy: 0.9844 - val_loss: 0.2408 - val_accuracy: 0.9878
# Epoch 52/60
# 📉 Learning rate at epoch 52: 0.000010===] - ETA: 0s - loss: 0.2449 - accuracy: 0.9858
# 1623/1623 [==============================] - 202s 124ms/step - loss: 0.2449 - accuracy: 0.9858 - val_loss: 0.2378 - val_accuracy: 0.9877
# Epoch 53/60
# 📉 Learning rate at epoch 53: 0.000010===] - ETA: 0s - loss: 0.2464 - accuracy: 0.9858
# 1623/1623 [==============================] - 174s 107ms/step - loss: 0.2464 - accuracy: 0.9858 - val_loss: 0.2402 - val_accuracy: 0.9863
# Epoch 54/60
# 📉 Learning rate at epoch 54: 0.000010===] - ETA: 0s - loss: 0.2455 - accuracy: 0.9858
# 1623/1623 [==============================] - 174s 107ms/step - loss: 0.2455 - accuracy: 0.9858 - val_loss: 0.2409 - val_accuracy: 0.9857
# Epoch 55/60
# 📉 Learning rate at epoch 55: 0.000010===] - ETA: 0s - loss: 0.2432 - accuracy: 0.9864
# 1623/1623 [==============================] - 176s 108ms/step - loss: 0.2432 - accuracy: 0.9864 - val_loss: 0.2328 - val_accuracy: 0.9900
# Epoch 56/60
# 📉 Learning rate at epoch 56: 0.000010===] - ETA: 0s - loss: 0.2422 - accuracy: 0.9871
# 1623/1623 [==============================] - 174s 107ms/step - loss: 0.2422 - accuracy: 0.9871 - val_loss: 0.2322 - val_accuracy: 0.9895
# Epoch 57/60
# 📉 Learning rate at epoch 57: 0.000010===] - ETA: 0s - loss: 0.2398 - accuracy: 0.9879
# 1623/1623 [==============================] - 177s 109ms/step - loss: 0.2398 - accuracy: 0.9879 - val_loss: 0.2328 - val_accuracy: 0.9901
# Epoch 58/60
# 📉 Learning rate at epoch 58: 0.000010===] - ETA: 0s - loss: 0.2399 - accuracy: 0.9884
# 1623/1623 [==============================] - 173s 106ms/step - loss: 0.2399 - accuracy: 0.9884 - val_loss: 0.2310 - val_accuracy: 0.9897
# Epoch 59/60
# 📉 Learning rate at epoch 59: 0.000010===] - ETA: 0s - loss: 0.2381 - accuracy: 0.9887
# 1623/1623 [==============================] - 173s 106ms/step - loss: 0.2381 - accuracy: 0.9887 - val_loss: 0.2291 - val_accuracy: 0.9921
# Epoch 60/60
# 📉 Learning rate at epoch 60: 0.000010===] - ETA: 0s - loss: 0.2355 - accuracy: 0.9905
# 1623/1623 [==============================] - 175s 108ms/step - loss: 0.2355 - accuracy: 0.9905 - val_loss: 0.2346 - val_accuracy: 0.9874

# %%
# === Evaluate ===
print("\n📊 Evaluating Phase 2 Model...")
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report (Phase 2):")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix (Phase 2)")
plt.tight_layout()
plt.show()

# === Save ===

SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\MobileNetV3_Phase2_GridMask.h5"
model.save(SAVE_PATH)
print(f"✅ Phase 2 MobileNetV3 Model saved at: {SAVE_PATH}")
# Out:
# 📊 Evaluating Phase 2 Model...
# 1/1 [==============================] - 1s 655ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
#
# 📊 Classification Report (Phase 2):
#               precision    recall  f1-score   support
#
#       BLIGHT       1.00      1.00      1.00      1556
#        BLAST       0.98      0.98      0.98      1666
#    BROWNSPOT       1.00      0.99      0.99      1635
#      HEALTHY       0.98      0.99      0.98      1635
#
#     accuracy                           0.99      6492
#    macro avg       0.99      0.99      0.99      6492
# weighted avg       0.99      0.99      0.99      6492
# ✅ Phase 2 MobileNetV3 Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\MobileNetV3_Phase2_GridMask.h5
