# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
import tensorflow_hub as hub # Import for Vision Transformer

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASET"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
# ViT models often work well with 224x224 or 384x384. Let's stick to 224 for consistency initially.
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 2
LEARNING_RATE = 1e-5

# Vision Transformer Model URL from TensorFlow Hub
# Example: EfficientNetV2 S/M/L are also good choices if ViT proves too heavy.
# For ViT, we can use a pre-trained model like 'vit_b16_fe' (Feature Extractor)
VIT_MODEL_URL = "https://tfhub.dev/google/imagenet/vit_base/patch16/224/feature_extractor/1"

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 24004

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 19203 | Val samples: 4801

# %%
# === Color Jitter ===
def color_jitter(image):
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.05)
    return tf.clip_by_value(image, 0.0, 255.0)

# === GridMask ===
def grid_mask(image, d_min=50, d_max=100, ratio=0.5):
    h, w, _ = image.shape
    d = tf.random.uniform([], d_min, d_max, dtype=tf.int32)
    l = tf.cast(tf.cast(d, tf.float32) * ratio, tf.int32)

    mask = tf.ones([h, w], dtype=tf.float32)

    for i in range(0, h, d):
        for j in range(0, w, d):
            y1 = i
            y2 = tf.minimum(i + l, h)
            x1 = j
            x2 = tf.minimum(j + l, w)

            y_range = tf.range(y1, y2)
            x_range = tf.range(x1, x2)
            yy, xx = tf.meshgrid(y_range, x_range, indexing='ij')
            indices = tf.stack([yy, xx], axis=-1)
            indices = tf.reshape(indices, [-1, 2])

            mask = tf.tensor_scatter_nd_update(
                mask,
                indices,
                tf.zeros([(y2 - y1) * (x2 - x1)], dtype=tf.float32)
            )

    mask = tf.expand_dims(mask, axis=-1)
    mask = tf.tile(mask, [1, 1, 3])
    return image * mask

# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32) # Cast to float32 for consistent processing

    img = color_jitter(img)  # keep values 0-255
    img = grid_mask(img)     # keep values 0-255

    # ViT models from TensorFlow Hub often expect values in [0, 1]
    img = img / 255.0 # Scale to [0, 1]

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# === CutMix ===
def cutmix(images, labels, alpha=1.0):
    batch_size = tf.shape(images)[0]
    img_h = tf.shape(images)[1]
    img_w = tf.shape(images)[2]

    lam = tfp.distributions.Beta(alpha, alpha).sample([batch_size])

    rand_idx = tf.random.shuffle(tf.range(batch_size))
    images2 = tf.gather(images, rand_idx)
    labels2 = tf.gather(labels, rand_idx)

    cut_rat = tf.math.sqrt(1. - lam)
    cut_w = tf.cast(img_w, tf.float32) * cut_rat
    cut_h = tf.cast(img_h, tf.float32) * cut_rat

    cx = tf.random.uniform([batch_size], 0, tf.cast(img_w, tf.float32))
    cy = tf.random.uniform([batch_size], 0, tf.cast(img_h, tf.float32))

    x1 = tf.cast(cx - cut_w / 2, tf.int32)
    y1 = tf.cast(cy - cut_h / 2, tf.int32)
    x2 = tf.cast(cx + cut_w / 2, tf.int32)
    y2 = tf.cast(cy + cut_h / 2, tf.int32)

    x1 = tf.clip_by_value(x1, 0, img_w)
    y1 = tf.clip_by_value(y1, 0, img_h)
    x2 = tf.clip_by_value(x2, 0, img_w)
    y2 = tf.clip_by_value(y2, 0, img_h)

    def apply_cutmix(i):
        img1 = images[i]
        img2 = images2[i]
        bbx1, bby1, bbx2, bby2 = x1[i], y1[i], x2[i], y2[i]

        mask = tf.pad(
            tf.zeros([bby2 - bby1, bbx2 - bbx1, 3]),
            [[bby1, img_h - bby2],
             [bbx1, img_w - bbx2],
             [0, 0]],
            constant_values=1.0
        )
        mask = 1.0 - mask
        mixed = img1 * mask + img2 * (1.0 - mask)

        area = tf.cast(bbx2 - bbx1, tf.float32) * tf.cast(bby2 - bby1, tf.float32)
        lam_adjusted = 1.0 - (area / tf.cast(img_w * img_h, tf.float32))
        new_label = lam_adjusted * labels[i] + (1.0 - lam_adjusted) * labels2[i]

        return mixed, new_label

    mixed_images, mixed_labels = tf.map_fn(
        apply_cutmix,
        tf.range(batch_size),
        fn_output_signature=(tf.float32, tf.float32)
    )

    return mixed_images, mixed_labels

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.map(lambda x, y: cutmix(x, y)).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# === Vision Transformer Model ===
# Load a pre-trained Vision Transformer feature extractor
vit_model = hub.KerasLayer(VIT_MODEL_URL, trainable=False, name='vit_feature_extractor')

inputs = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = vit_model(inputs) # The feature extractor outputs features directly
x = Dropout(0.5)(x) # ViT outputs are often already flattened or pooled
x = Dense(256, activation='relu')(x) # Reduced intermediate layer for potentially flatter ViT features
outputs = Dense(len(CLASSES), activation='softmax')(x)
model = Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:191, in nti(s)
#     190     s = nts(s, "ascii", "strict")
# --> 191     n = int(s.strip() or "0", 8)
#     192 except ValueError:
#
# ValueError: invalid literal for int() with base 8: 'ts" cont'
#
# During handling of the above exception, another exception occurred:
#
# InvalidHeaderError                        Traceback (most recent call last)
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:2712, in TarFile.next(self)
#    2711 try:
# -> 2712     tarinfo = self.tarinfo.fromtarfile(self)
#    2713 except EOFHeaderError as e:
#
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:1312, in TarInfo.fromtarfile(cls, tarfile)
#    1311 buf = tarfile.fileobj.read(BLOCKSIZE)
# -> 1312 obj = cls.frombuf(buf, tarfile.encoding, tarfile.errors)
#    1313 obj.offset = tarfile.fileobj.tell() - BLOCKSIZE
#
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:1254, in TarInfo.frombuf(cls, buf, encoding, errors)
#    1252     raise EOFHeaderError("end of file header")
# -> 1254 chksum = nti(buf[148:156])
#    1255 if chksum not in calc_chksums(buf):
#
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:193, in nti(s)
#     192     except ValueError:
# --> 193         raise InvalidHeaderError("invalid header")
#     194 return n
#
# InvalidHeaderError: invalid header
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\resolver.py:189, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     188 try:
# --> 189   file_utils.extract_tarfile_to_destination(
#     190       fileobj, dst_path, log_function=self._log_progress)
#     191   total_size_str = tf_utils.bytes_to_readable_str(
#     192       self._total_bytes_downloaded, True)
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\file_utils.py:47, in extract_tarfile_to_destination(fileobj, dst_path, log_function)
#      46 """Extract a tarfile. Optional: log the progress."""
# ---> 47 with tarfile.open(mode="r|*", fileobj=fileobj) as tgz:
#      48   for tarinfo in tgz:
#
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:1868, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1867 try:
# -> 1868     t = cls(name, filemode, stream, **kwargs)
#    1869 except:
#
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:1749, in TarFile.__init__(self, name, mode, fileobj, format, tarinfo, dereference, ignore_zeros, encoding, errors, pax_headers, debug, errorlevel, copybufsize)
#    1748     self.firstmember = None
# -> 1749     self.firstmember = self.next()
#    1751 if self.mode == "a":
#    1752     # Move to the end of the archive,
#    1753     # before the first empty block.
#
# File ~\.conda\envs\tf2.10.1\lib\tarfile.py:2724, in TarFile.next(self)
#    2723     elif self.offset == 0:
# -> 2724         raise ReadError(str(e))
#    2725 except EmptyHeaderError:
#
# ReadError: invalid header
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 3
#       1 # === Vision Transformer Model ===
#       2 # Load a pre-trained Vision Transformer feature extractor
# ----> 3 vit_model = hub.KerasLayer(VIT_MODEL_URL, trainable=False, name='vit_feature_extractor')
#       5 inputs = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
#       6 x = vit_model(inputs) # The feature extractor outputs features directly
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\keras_layer.py:153, in KerasLayer.__init__(self, handle, trainable, arguments, _sentinel, tags, signature, signature_outputs_as_dict, output_key, output_shape, load_options, **kwargs)
#     149   self._output_shape = data_structures.NoDependency(
#     150       _convert_nest_to_shapes(output_shape))
#     152 self._load_options = load_options
# --> 153 self._func = load_module(handle, tags, self._load_options)
#     154 self._has_training_argument = func_has_training_argument(self._func)
#     155 self._is_hub_module_v1 = getattr(self._func, "_is_hub_module_v1", False)
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\keras_layer.py:449, in load_module(handle, tags, load_options)
#     447   except ImportError:  # Expected before TF2.4.
#     448     set_load_options = load_options
# --> 449 return module_v2.load(handle, tags=tags, options=set_load_options)
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\module_v2.py:92, in load(handle, tags, options)
#      90 if not isinstance(handle, str):
#      91   raise ValueError("Expected a string, got %s" % handle)
# ---> 92 module_path = resolve(handle)
#      93 is_hub_module_v1 = tf.io.gfile.exists(
#      94     native_module.get_module_proto_path(module_path))
#      95 if tags is None and is_hub_module_v1:
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\module_v2.py:47, in resolve(handle)
#      23 def resolve(handle):
#      24   """Resolves a module handle into a path.
#      25
#      26   This function works both for plain TF2 SavedModels and the legacy TF1 Hub
#    (...)
#      45     A string representing the Module path.
#      46   """
# ---> 47   return registry.resolver(handle)
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\registry.py:51, in MultiImplRegister.__call__(self, *args, **kwargs)
#      49 for impl in reversed(self._impls):
#      50   if impl.is_supported(*args, **kwargs):
# ---> 51     return impl(*args, **kwargs)
#      52   else:
#      53     fails.append(type(impl).__name__)
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\compressed_module_resolver.py:67, in HttpCompressedFileResolver.__call__(self, handle)
#      63   response = self._call_urlopen(request)
#      64   return resolver.DownloadManager(handle).download_and_uncompress(
#      65       response, tmp_dir)
# ---> 67 return resolver.atomic_download(handle, download, module_dir,
#      68                                 self._lock_file_timeout_sec())
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\resolver.py:418, in atomic_download(handle, download_fn, module_dir, lock_file_timeout_sec)
#     416 logging.info("Downloading TF-Hub Module '%s'.", handle)
#     417 tf.compat.v1.gfile.MakeDirs(tmp_dir)
# --> 418 download_fn(handle, tmp_dir)
#     419 # Write module descriptor to capture information about which module was
#     420 # downloaded by whom and when. The file stored at the same level as a
#     421 # directory in order to keep the content of the 'model_dir' exactly as it
#    (...)
#     426 # module caching protocol and no code in the TF-Hub library reads its
#     427 # content.
#     428 _write_module_descriptor_file(handle, module_dir)
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\compressed_module_resolver.py:64, in HttpCompressedFileResolver.__call__.<locals>.download(handle, tmp_dir)
#      61 request = urllib.request.Request(
#      62     self._append_compressed_format_query(handle))
#      63 response = self._call_urlopen(request)
# ---> 64 return resolver.DownloadManager(handle).download_and_uncompress(
#      65     response, tmp_dir)
#
# File ~\.conda\envs\tf2.10.1\lib\site-packages\tensorflow_hub\resolver.py:197, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     193   self._print_download_progress_msg(
#     194       "Downloaded %s, Total size: %s" % (self._url, total_size_str),
#     195       flush=True)
#     196 except tarfile.ReadError:
# --> 197   raise IOError("%s does not appear to be a valid module." % self._url)
#
# OSError: https://tfhub.dev/google/imagenet/vit_base/patch16/224/feature_extractor/1 does not appear to be a valid module.

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

# === Compute class weights ===
y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
class_weights = dict(enumerate(class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(CLASSES)),
    y=y_train_int
)))
print("✅ Computed class weights:", class_weights)

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()],
    class_weight=class_weights
)

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\ViT_Phase1_CutMix_GridMask.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
