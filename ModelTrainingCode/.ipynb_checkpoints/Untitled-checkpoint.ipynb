# %%
import h5py
MODEL_PATH_PHASE1_WEIGHTS = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\EfficientNetB0_Phase1_CutMix_GridMask_weights.h5"
with h5py.File(MODEL_PATH_PHASE1_WEIGHTS, 'r') as f:
    def print_attrs(name, obj):
        if isinstance(obj, h5py.Dataset):
            print(f"{name}: shape={obj.shape}")
    f.visititems(print_attrs)
# Out:
# dense/dense/bias:0: shape=(512,)
# dense/dense/kernel:0: shape=(1280, 512)
# dense_1/dense_1/bias:0: shape=(256,)
# dense_1/dense_1/kernel:0: shape=(512, 256)
# dense_2/dense_2/bias:0: shape=(4,)
# dense_2/dense_2/kernel:0: shape=(256, 4)
# efficientnetb0/block1a_bn/beta:0: shape=(32,)
# efficientnetb0/block1a_bn/gamma:0: shape=(32,)
# efficientnetb0/block1a_bn/moving_mean:0: shape=(32,)
# efficientnetb0/block1a_bn/moving_variance:0: shape=(32,)
# efficientnetb0/block1a_dwconv/depthwise_kernel:0: shape=(3, 3, 32, 1)
# efficientnetb0/block1a_project_bn/beta:0: shape=(16,)
# efficientnetb0/block1a_project_bn/gamma:0: shape=(16,)
# efficientnetb0/block1a_project_bn/moving_mean:0: shape=(16,)
# efficientnetb0/block1a_project_bn/moving_variance:0: shape=(16,)
# efficientnetb0/block1a_project_conv/kernel:0: shape=(1, 1, 32, 16)
# efficientnetb0/block1a_se_expand/bias:0: shape=(32,)
# efficientnetb0/block1a_se_expand/kernel:0: shape=(1, 1, 8, 32)
# efficientnetb0/block1a_se_reduce/bias:0: shape=(8,)
# efficientnetb0/block1a_se_reduce/kernel:0: shape=(1, 1, 32, 8)
# efficientnetb0/block2a_bn/beta:0: shape=(96,)
# efficientnetb0/block2a_bn/gamma:0: shape=(96,)
# efficientnetb0/block2a_bn/moving_mean:0: shape=(96,)
# efficientnetb0/block2a_bn/moving_variance:0: shape=(96,)
# efficientnetb0/block2a_dwconv/depthwise_kernel:0: shape=(3, 3, 96, 1)
# efficientnetb0/block2a_expand_bn/beta:0: shape=(96,)
# efficientnetb0/block2a_expand_bn/gamma:0: shape=(96,)
# efficientnetb0/block2a_expand_bn/moving_mean:0: shape=(96,)
# efficientnetb0/block2a_expand_bn/moving_variance:0: shape=(96,)
# efficientnetb0/block2a_expand_conv/kernel:0: shape=(1, 1, 16, 96)
# efficientnetb0/block2a_project_bn/beta:0: shape=(24,)
# efficientnetb0/block2a_project_bn/gamma:0: shape=(24,)
# efficientnetb0/block2a_project_bn/moving_mean:0: shape=(24,)
# efficientnetb0/block2a_project_bn/moving_variance:0: shape=(24,)
# efficientnetb0/block2a_project_conv/kernel:0: shape=(1, 1, 96, 24)
# efficientnetb0/block2a_se_expand/bias:0: shape=(96,)
# efficientnetb0/block2a_se_expand/kernel:0: shape=(1, 1, 4, 96)
# efficientnetb0/block2a_se_reduce/bias:0: shape=(4,)
# efficientnetb0/block2a_se_reduce/kernel:0: shape=(1, 1, 96, 4)
# efficientnetb0/block2b_bn/beta:0: shape=(144,)
# efficientnetb0/block2b_bn/gamma:0: shape=(144,)
# efficientnetb0/block2b_bn/moving_mean:0: shape=(144,)
# efficientnetb0/block2b_bn/moving_variance:0: shape=(144,)
# efficientnetb0/block2b_dwconv/depthwise_kernel:0: shape=(3, 3, 144, 1)
# efficientnetb0/block2b_expand_bn/beta:0: shape=(144,)
# efficientnetb0/block2b_expand_bn/gamma:0: shape=(144,)
# efficientnetb0/block2b_expand_bn/moving_mean:0: shape=(144,)
# efficientnetb0/block2b_expand_bn/moving_variance:0: shape=(144,)
# efficientnetb0/block2b_expand_conv/kernel:0: shape=(1, 1, 24, 144)
# efficientnetb0/block2b_project_bn/beta:0: shape=(24,)
# efficientnetb0/block2b_project_bn/gamma:0: shape=(24,)
# efficientnetb0/block2b_project_bn/moving_mean:0: shape=(24,)
# efficientnetb0/block2b_project_bn/moving_variance:0: shape=(24,)
# efficientnetb0/block2b_project_conv/kernel:0: shape=(1, 1, 144, 24)
# efficientnetb0/block2b_se_expand/bias:0: shape=(144,)
# efficientnetb0/block2b_se_expand/kernel:0: shape=(1, 1, 6, 144)
# efficientnetb0/block2b_se_reduce/bias:0: shape=(6,)
# efficientnetb0/block2b_se_reduce/kernel:0: shape=(1, 1, 144, 6)
# efficientnetb0/block3a_bn/beta:0: shape=(144,)
# efficientnetb0/block3a_bn/gamma:0: shape=(144,)
# efficientnetb0/block3a_bn/moving_mean:0: shape=(144,)
# efficientnetb0/block3a_bn/moving_variance:0: shape=(144,)
# efficientnetb0/block3a_dwconv/depthwise_kernel:0: shape=(5, 5, 144, 1)
# efficientnetb0/block3a_expand_bn/beta:0: shape=(144,)
# efficientnetb0/block3a_expand_bn/gamma:0: shape=(144,)
# efficientnetb0/block3a_expand_bn/moving_mean:0: shape=(144,)
# efficientnetb0/block3a_expand_bn/moving_variance:0: shape=(144,)
# efficientnetb0/block3a_expand_conv/kernel:0: shape=(1, 1, 24, 144)
# efficientnetb0/block3a_project_bn/beta:0: shape=(40,)
# efficientnetb0/block3a_project_bn/gamma:0: shape=(40,)
# efficientnetb0/block3a_project_bn/moving_mean:0: shape=(40,)
# efficientnetb0/block3a_project_bn/moving_variance:0: shape=(40,)
# efficientnetb0/block3a_project_conv/kernel:0: shape=(1, 1, 144, 40)
# efficientnetb0/block3a_se_expand/bias:0: shape=(144,)
# efficientnetb0/block3a_se_expand/kernel:0: shape=(1, 1, 6, 144)
# efficientnetb0/block3a_se_reduce/bias:0: shape=(6,)
# efficientnetb0/block3a_se_reduce/kernel:0: shape=(1, 1, 144, 6)
# efficientnetb0/block3b_bn/beta:0: shape=(240,)
# efficientnetb0/block3b_bn/gamma:0: shape=(240,)
# efficientnetb0/block3b_bn/moving_mean:0: shape=(240,)
# efficientnetb0/block3b_bn/moving_variance:0: shape=(240,)
# efficientnetb0/block3b_dwconv/depthwise_kernel:0: shape=(5, 5, 240, 1)
# efficientnetb0/block3b_expand_bn/beta:0: shape=(240,)
# efficientnetb0/block3b_expand_bn/gamma:0: shape=(240,)
# efficientnetb0/block3b_expand_bn/moving_mean:0: shape=(240,)
# efficientnetb0/block3b_expand_bn/moving_variance:0: shape=(240,)
# efficientnetb0/block3b_expand_conv/kernel:0: shape=(1, 1, 40, 240)
# efficientnetb0/block3b_project_bn/beta:0: shape=(40,)
# efficientnetb0/block3b_project_bn/gamma:0: shape=(40,)
# efficientnetb0/block3b_project_bn/moving_mean:0: shape=(40,)
# efficientnetb0/block3b_project_bn/moving_variance:0: shape=(40,)
# efficientnetb0/block3b_project_conv/kernel:0: shape=(1, 1, 240, 40)
# efficientnetb0/block3b_se_expand/bias:0: shape=(240,)
# efficientnetb0/block3b_se_expand/kernel:0: shape=(1, 1, 10, 240)
# efficientnetb0/block3b_se_reduce/bias:0: shape=(10,)
# efficientnetb0/block3b_se_reduce/kernel:0: shape=(1, 1, 240, 10)
# efficientnetb0/block4a_bn/beta:0: shape=(240,)
# efficientnetb0/block4a_bn/gamma:0: shape=(240,)
# efficientnetb0/block4a_bn/moving_mean:0: shape=(240,)
# efficientnetb0/block4a_bn/moving_variance:0: shape=(240,)
# efficientnetb0/block4a_dwconv/depthwise_kernel:0: shape=(3, 3, 240, 1)
# efficientnetb0/block4a_expand_bn/beta:0: shape=(240,)
# efficientnetb0/block4a_expand_bn/gamma:0: shape=(240,)
# efficientnetb0/block4a_expand_bn/moving_mean:0: shape=(240,)
# efficientnetb0/block4a_expand_bn/moving_variance:0: shape=(240,)
# efficientnetb0/block4a_expand_conv/kernel:0: shape=(1, 1, 40, 240)
# efficientnetb0/block4a_project_bn/beta:0: shape=(80,)
# efficientnetb0/block4a_project_bn/gamma:0: shape=(80,)
# efficientnetb0/block4a_project_bn/moving_mean:0: shape=(80,)
# efficientnetb0/block4a_project_bn/moving_variance:0: shape=(80,)
# efficientnetb0/block4a_project_conv/kernel:0: shape=(1, 1, 240, 80)
# efficientnetb0/block4a_se_expand/bias:0: shape=(240,)
# efficientnetb0/block4a_se_expand/kernel:0: shape=(1, 1, 10, 240)
# efficientnetb0/block4a_se_reduce/bias:0: shape=(10,)
# efficientnetb0/block4a_se_reduce/kernel:0: shape=(1, 1, 240, 10)
# efficientnetb0/block4b_bn/beta:0: shape=(480,)
# efficientnetb0/block4b_bn/gamma:0: shape=(480,)
# efficientnetb0/block4b_bn/moving_mean:0: shape=(480,)
# efficientnetb0/block4b_bn/moving_variance:0: shape=(480,)
# efficientnetb0/block4b_dwconv/depthwise_kernel:0: shape=(3, 3, 480, 1)
# efficientnetb0/block4b_expand_bn/beta:0: shape=(480,)
# efficientnetb0/block4b_expand_bn/gamma:0: shape=(480,)
# efficientnetb0/block4b_expand_bn/moving_mean:0: shape=(480,)
# efficientnetb0/block4b_expand_bn/moving_variance:0: shape=(480,)
# efficientnetb0/block4b_expand_conv/kernel:0: shape=(1, 1, 80, 480)
# efficientnetb0/block4b_project_bn/beta:0: shape=(80,)
# efficientnetb0/block4b_project_bn/gamma:0: shape=(80,)
# efficientnetb0/block4b_project_bn/moving_mean:0: shape=(80,)
# efficientnetb0/block4b_project_bn/moving_variance:0: shape=(80,)
# efficientnetb0/block4b_project_conv/kernel:0: shape=(1, 1, 480, 80)
# efficientnetb0/block4b_se_expand/bias:0: shape=(480,)
# efficientnetb0/block4b_se_expand/kernel:0: shape=(1, 1, 20, 480)
# efficientnetb0/block4b_se_reduce/bias:0: shape=(20,)
# efficientnetb0/block4b_se_reduce/kernel:0: shape=(1, 1, 480, 20)
# efficientnetb0/block4c_bn/beta:0: shape=(480,)
# efficientnetb0/block4c_bn/gamma:0: shape=(480,)
# efficientnetb0/block4c_bn/moving_mean:0: shape=(480,)
# efficientnetb0/block4c_bn/moving_variance:0: shape=(480,)
# efficientnetb0/block4c_dwconv/depthwise_kernel:0: shape=(3, 3, 480, 1)
# efficientnetb0/block4c_expand_bn/beta:0: shape=(480,)
# efficientnetb0/block4c_expand_bn/gamma:0: shape=(480,)
# efficientnetb0/block4c_expand_bn/moving_mean:0: shape=(480,)
# efficientnetb0/block4c_expand_bn/moving_variance:0: shape=(480,)
# efficientnetb0/block4c_expand_conv/kernel:0: shape=(1, 1, 80, 480)
# efficientnetb0/block4c_project_bn/beta:0: shape=(80,)
# efficientnetb0/block4c_project_bn/gamma:0: shape=(80,)
# efficientnetb0/block4c_project_bn/moving_mean:0: shape=(80,)
# efficientnetb0/block4c_project_bn/moving_variance:0: shape=(80,)
# efficientnetb0/block4c_project_conv/kernel:0: shape=(1, 1, 480, 80)
# efficientnetb0/block4c_se_expand/bias:0: shape=(480,)
# efficientnetb0/block4c_se_expand/kernel:0: shape=(1, 1, 20, 480)
# efficientnetb0/block4c_se_reduce/bias:0: shape=(20,)
# efficientnetb0/block4c_se_reduce/kernel:0: shape=(1, 1, 480, 20)
# efficientnetb0/block5a_bn/beta:0: shape=(480,)
# efficientnetb0/block5a_bn/gamma:0: shape=(480,)
# efficientnetb0/block5a_bn/moving_mean:0: shape=(480,)
# efficientnetb0/block5a_bn/moving_variance:0: shape=(480,)
# efficientnetb0/block5a_dwconv/depthwise_kernel:0: shape=(5, 5, 480, 1)
# efficientnetb0/block5a_expand_bn/beta:0: shape=(480,)
# efficientnetb0/block5a_expand_bn/gamma:0: shape=(480,)
# efficientnetb0/block5a_expand_bn/moving_mean:0: shape=(480,)
# efficientnetb0/block5a_expand_bn/moving_variance:0: shape=(480,)
# efficientnetb0/block5a_expand_conv/kernel:0: shape=(1, 1, 80, 480)
# efficientnetb0/block5a_project_bn/beta:0: shape=(112,)
# efficientnetb0/block5a_project_bn/gamma:0: shape=(112,)
# efficientnetb0/block5a_project_bn/moving_mean:0: shape=(112,)
# efficientnetb0/block5a_project_bn/moving_variance:0: shape=(112,)
# efficientnetb0/block5a_project_conv/kernel:0: shape=(1, 1, 480, 112)
# efficientnetb0/block5a_se_expand/bias:0: shape=(480,)
# efficientnetb0/block5a_se_expand/kernel:0: shape=(1, 1, 20, 480)
# efficientnetb0/block5a_se_reduce/bias:0: shape=(20,)
# efficientnetb0/block5a_se_reduce/kernel:0: shape=(1, 1, 480, 20)
# efficientnetb0/block5b_bn/beta:0: shape=(672,)
# efficientnetb0/block5b_bn/gamma:0: shape=(672,)
# efficientnetb0/block5b_bn/moving_mean:0: shape=(672,)
# efficientnetb0/block5b_bn/moving_variance:0: shape=(672,)
# efficientnetb0/block5b_dwconv/depthwise_kernel:0: shape=(5, 5, 672, 1)
# efficientnetb0/block5b_expand_bn/beta:0: shape=(672,)
# efficientnetb0/block5b_expand_bn/gamma:0: shape=(672,)
# efficientnetb0/block5b_expand_bn/moving_mean:0: shape=(672,)
# efficientnetb0/block5b_expand_bn/moving_variance:0: shape=(672,)
# efficientnetb0/block5b_expand_conv/kernel:0: shape=(1, 1, 112, 672)
# efficientnetb0/block5b_project_bn/beta:0: shape=(112,)
# efficientnetb0/block5b_project_bn/gamma:0: shape=(112,)
# efficientnetb0/block5b_project_bn/moving_mean:0: shape=(112,)
# efficientnetb0/block5b_project_bn/moving_variance:0: shape=(112,)
# efficientnetb0/block5b_project_conv/kernel:0: shape=(1, 1, 672, 112)
# efficientnetb0/block5b_se_expand/bias:0: shape=(672,)
# efficientnetb0/block5b_se_expand/kernel:0: shape=(1, 1, 28, 672)
# efficientnetb0/block5b_se_reduce/bias:0: shape=(28,)
# efficientnetb0/block5b_se_reduce/kernel:0: shape=(1, 1, 672, 28)
# efficientnetb0/block5c_bn/beta:0: shape=(672,)
# efficientnetb0/block5c_bn/gamma:0: shape=(672,)
# efficientnetb0/block5c_bn/moving_mean:0: shape=(672,)
# efficientnetb0/block5c_bn/moving_variance:0: shape=(672,)
# efficientnetb0/block5c_dwconv/depthwise_kernel:0: shape=(5, 5, 672, 1)
# efficientnetb0/block5c_expand_bn/beta:0: shape=(672,)
# efficientnetb0/block5c_expand_bn/gamma:0: shape=(672,)
# efficientnetb0/block5c_expand_bn/moving_mean:0: shape=(672,)
# efficientnetb0/block5c_expand_bn/moving_variance:0: shape=(672,)
# efficientnetb0/block5c_expand_conv/kernel:0: shape=(1, 1, 112, 672)
# efficientnetb0/block5c_project_bn/beta:0: shape=(112,)
# efficientnetb0/block5c_project_bn/gamma:0: shape=(112,)
# efficientnetb0/block5c_project_bn/moving_mean:0: shape=(112,)
# efficientnetb0/block5c_project_bn/moving_variance:0: shape=(112,)
# efficientnetb0/block5c_project_conv/kernel:0: shape=(1, 1, 672, 112)
# efficientnetb0/block5c_se_expand/bias:0: shape=(672,)
# efficientnetb0/block5c_se_expand/kernel:0: shape=(1, 1, 28, 672)
# efficientnetb0/block5c_se_reduce/bias:0: shape=(28,)
# efficientnetb0/block5c_se_reduce/kernel:0: shape=(1, 1, 672, 28)
# efficientnetb0/block6a_bn/beta:0: shape=(672,)
# efficientnetb0/block6a_bn/gamma:0: shape=(672,)
# efficientnetb0/block6a_bn/moving_mean:0: shape=(672,)
# efficientnetb0/block6a_bn/moving_variance:0: shape=(672,)
# efficientnetb0/block6a_dwconv/depthwise_kernel:0: shape=(5, 5, 672, 1)
# efficientnetb0/block6a_expand_bn/beta:0: shape=(672,)
# efficientnetb0/block6a_expand_bn/gamma:0: shape=(672,)
# efficientnetb0/block6a_expand_bn/moving_mean:0: shape=(672,)
# efficientnetb0/block6a_expand_bn/moving_variance:0: shape=(672,)
# efficientnetb0/block6a_expand_conv/kernel:0: shape=(1, 1, 112, 672)
# efficientnetb0/block6a_project_bn/beta:0: shape=(192,)
# efficientnetb0/block6a_project_bn/gamma:0: shape=(192,)
# efficientnetb0/block6a_project_bn/moving_mean:0: shape=(192,)
# efficientnetb0/block6a_project_bn/moving_variance:0: shape=(192,)
# efficientnetb0/block6a_project_conv/kernel:0: shape=(1, 1, 672, 192)
# efficientnetb0/block6a_se_expand/bias:0: shape=(672,)
# efficientnetb0/block6a_se_expand/kernel:0: shape=(1, 1, 28, 672)
# efficientnetb0/block6a_se_reduce/bias:0: shape=(28,)
# efficientnetb0/block6a_se_reduce/kernel:0: shape=(1, 1, 672, 28)
# efficientnetb0/block6b_bn/beta:0: shape=(1152,)
# efficientnetb0/block6b_bn/gamma:0: shape=(1152,)
# efficientnetb0/block6b_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block6b_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block6b_dwconv/depthwise_kernel:0: shape=(5, 5, 1152, 1)
# efficientnetb0/block6b_expand_bn/beta:0: shape=(1152,)
# efficientnetb0/block6b_expand_bn/gamma:0: shape=(1152,)
# efficientnetb0/block6b_expand_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block6b_expand_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block6b_expand_conv/kernel:0: shape=(1, 1, 192, 1152)
# efficientnetb0/block6b_project_bn/beta:0: shape=(192,)
# efficientnetb0/block6b_project_bn/gamma:0: shape=(192,)
# efficientnetb0/block6b_project_bn/moving_mean:0: shape=(192,)
# efficientnetb0/block6b_project_bn/moving_variance:0: shape=(192,)
# efficientnetb0/block6b_project_conv/kernel:0: shape=(1, 1, 1152, 192)
# efficientnetb0/block6b_se_expand/bias:0: shape=(1152,)
# efficientnetb0/block6b_se_expand/kernel:0: shape=(1, 1, 48, 1152)
# efficientnetb0/block6b_se_reduce/bias:0: shape=(48,)
# efficientnetb0/block6b_se_reduce/kernel:0: shape=(1, 1, 1152, 48)
# efficientnetb0/block6c_bn/beta:0: shape=(1152,)
# efficientnetb0/block6c_bn/gamma:0: shape=(1152,)
# efficientnetb0/block6c_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block6c_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block6c_dwconv/depthwise_kernel:0: shape=(5, 5, 1152, 1)
# efficientnetb0/block6c_expand_bn/beta:0: shape=(1152,)
# efficientnetb0/block6c_expand_bn/gamma:0: shape=(1152,)
# efficientnetb0/block6c_expand_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block6c_expand_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block6c_expand_conv/kernel:0: shape=(1, 1, 192, 1152)
# efficientnetb0/block6c_project_bn/beta:0: shape=(192,)
# efficientnetb0/block6c_project_bn/gamma:0: shape=(192,)
# efficientnetb0/block6c_project_bn/moving_mean:0: shape=(192,)
# efficientnetb0/block6c_project_bn/moving_variance:0: shape=(192,)
# efficientnetb0/block6c_project_conv/kernel:0: shape=(1, 1, 1152, 192)
# efficientnetb0/block6c_se_expand/bias:0: shape=(1152,)
# efficientnetb0/block6c_se_expand/kernel:0: shape=(1, 1, 48, 1152)
# efficientnetb0/block6c_se_reduce/bias:0: shape=(48,)
# efficientnetb0/block6c_se_reduce/kernel:0: shape=(1, 1, 1152, 48)
# efficientnetb0/block6d_bn/beta:0: shape=(1152,)
# efficientnetb0/block6d_bn/gamma:0: shape=(1152,)
# efficientnetb0/block6d_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block6d_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block6d_dwconv/depthwise_kernel:0: shape=(5, 5, 1152, 1)
# efficientnetb0/block6d_expand_bn/beta:0: shape=(1152,)
# efficientnetb0/block6d_expand_bn/gamma:0: shape=(1152,)
# efficientnetb0/block6d_expand_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block6d_expand_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block6d_expand_conv/kernel:0: shape=(1, 1, 192, 1152)
# efficientnetb0/block6d_project_bn/beta:0: shape=(192,)
# efficientnetb0/block6d_project_bn/gamma:0: shape=(192,)
# efficientnetb0/block6d_project_bn/moving_mean:0: shape=(192,)
# efficientnetb0/block6d_project_bn/moving_variance:0: shape=(192,)
# efficientnetb0/block6d_project_conv/kernel:0: shape=(1, 1, 1152, 192)
# efficientnetb0/block6d_se_expand/bias:0: shape=(1152,)
# efficientnetb0/block6d_se_expand/kernel:0: shape=(1, 1, 48, 1152)
# efficientnetb0/block6d_se_reduce/bias:0: shape=(48,)
# efficientnetb0/block6d_se_reduce/kernel:0: shape=(1, 1, 1152, 48)
# efficientnetb0/block7a_bn/beta:0: shape=(1152,)
# efficientnetb0/block7a_bn/gamma:0: shape=(1152,)
# efficientnetb0/block7a_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block7a_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block7a_dwconv/depthwise_kernel:0: shape=(3, 3, 1152, 1)
# efficientnetb0/block7a_expand_bn/beta:0: shape=(1152,)
# efficientnetb0/block7a_expand_bn/gamma:0: shape=(1152,)
# efficientnetb0/block7a_expand_bn/moving_mean:0: shape=(1152,)
# efficientnetb0/block7a_expand_bn/moving_variance:0: shape=(1152,)
# efficientnetb0/block7a_expand_conv/kernel:0: shape=(1, 1, 192, 1152)
# efficientnetb0/block7a_project_bn/beta:0: shape=(320,)
# efficientnetb0/block7a_project_bn/gamma:0: shape=(320,)
# efficientnetb0/block7a_project_bn/moving_mean:0: shape=(320,)
# efficientnetb0/block7a_project_bn/moving_variance:0: shape=(320,)
# efficientnetb0/block7a_project_conv/kernel:0: shape=(1, 1, 1152, 320)
# efficientnetb0/block7a_se_expand/bias:0: shape=(1152,)
# efficientnetb0/block7a_se_expand/kernel:0: shape=(1, 1, 48, 1152)
# efficientnetb0/block7a_se_reduce/bias:0: shape=(48,)
# efficientnetb0/block7a_se_reduce/kernel:0: shape=(1, 1, 1152, 48)
# efficientnetb0/normalization/count:0: shape=()
# efficientnetb0/normalization/mean:0: shape=(3,)
# efficientnetb0/normalization/variance:0: shape=(3,)
# efficientnetb0/stem_bn/beta:0: shape=(32,)
# efficientnetb0/stem_bn/gamma:0: shape=(32,)
# efficientnetb0/stem_bn/moving_mean:0: shape=(32,)
# efficientnetb0/stem_bn/moving_variance:0: shape=(32,)
# efficientnetb0/stem_conv/kernel:0: shape=(3, 3, 3, 32)
# efficientnetb0/top_bn/beta:0: shape=(1280,)
# efficientnetb0/top_bn/gamma:0: shape=(1280,)
# efficientnetb0/top_bn/moving_mean:0: shape=(1280,)
# efficientnetb0/top_bn/moving_variance:0: shape=(1280,)
# efficientnetb0/top_conv/kernel:0: shape=(1, 1, 320, 1280)
