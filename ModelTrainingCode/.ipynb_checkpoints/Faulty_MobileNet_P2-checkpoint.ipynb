# %%
import os
import glob
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import (preprocess_input)
from tensorflow.keras.callbacks import EarlyStopping, Callback
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
import matplotlib.pyplot as plt

# %%
# === CONFIG ===
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

BASE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_DATASET_F1"
CLASSES = ["BLIGHT", "BLAST", "BROWNSPOT", "HEALTHY"]
IMG_SIZE = (224, 224)
BATCH_SIZE = 16  # ✅ Smaller for BN layers
EPOCHS = 60
LEARNING_RATE = 1e-5  # ✅ Lower for frozen backbone

# %%
# === Load filepaths & labels ===
all_filepaths, all_labels = [], []
for idx, class_name in enumerate(CLASSES):
    aug_path = os.path.join(BASE_PATH, class_name, "augmented")
    files = glob.glob(os.path.join(aug_path, "*.jpg")) + \
            glob.glob(os.path.join(aug_path, "*.jpeg")) + \
            glob.glob(os.path.join(aug_path, "*.png"))
    all_filepaths.extend(files)
    all_labels.extend([idx] * len(files))

print(f"✅ Total images found: {len(all_filepaths)}")
# Out:
# ✅ Total images found: 32460

# %%
# === tf.data.Dataset ===
filepaths_ds = tf.data.Dataset.from_tensor_slices(all_filepaths)
labels_ds = tf.data.Dataset.from_tensor_slices(all_labels)
ds = tf.data.Dataset.zip((filepaths_ds, labels_ds)).shuffle(len(all_filepaths), seed=SEED)

train_size = int(0.8 * len(all_filepaths))
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)

print(f"✅ Train samples: {train_size} | Val samples: {len(all_filepaths) - train_size}")
# Out:
# ✅ Train samples: 25968 | Val samples: 6492

# %%
# === Color Jitter ===
def color_jitter(image):
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.05)
    return tf.clip_by_value(image, 0.0, 255.0)  # Important: keep in original range if using preprocess_input

# === GridMask ===
def grid_mask(image, d_min=50, d_max=100, ratio=0.5):
    h, w, _ = image.shape
    d = tf.random.uniform([], d_min, d_max, dtype=tf.int32)
    l = tf.cast(tf.cast(d, tf.float32) * ratio, tf.int32)

    mask = tf.ones([h, w], dtype=tf.float32)

    for i in range(0, h, d):
        for j in range(0, w, d):
            y1 = i
            y2 = tf.minimum(i + l, h)
            x1 = j
            x2 = tf.minimum(j + l, w)

            y_range = tf.range(y1, y2)
            x_range = tf.range(x1, x2)
            yy, xx = tf.meshgrid(y_range, x_range, indexing='ij')
            indices = tf.stack([yy, xx], axis=-1)
            indices = tf.reshape(indices, [-1, 2])

            mask = tf.tensor_scatter_nd_update(
                mask,
                indices,
                tf.zeros([(y2 - y1) * (x2 - x1)], dtype=tf.float32)
            )

    mask = tf.expand_dims(mask, axis=-1)
    mask = tf.tile(mask, [1, 1, 3])
    return image * mask

# === Image Processor ===
def process_img(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)

    img = color_jitter(img)  # keep values 0-255
    img = grid_mask(img)     # keep values 0-255

    img = preprocess_input(img)  # ✅ For ResNet50: scale to [-1, 1] the same way as pretraining

    label = tf.one_hot(label, depth=len(CLASSES))
    return img, label

# %%
# === Final Pipeline ===
train_ds = train_ds.map(process_img).batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(process_img).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.mobilenet import preprocess_input

# Reload dataset & pipeline same as Phase 1
# (Reuse `process_img`, `cutmix`, etc.)

model = load_model(r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\Faulty_MobileNetV3_Phase1.h5")
for layer in model.layers:
    layer.trainable = True
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy']
)

# %%
# === Learning rate logger ===
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        # If using a scheduler, it might be a callable or tensor
        if hasattr(lr, '__call__'):
            lr = lr(self.model.optimizer.iterations)
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"📉 Learning rate at epoch {epoch+1}: {lr:.6f}")

        

# === Compute class weights ===
y_train_int = np.argmax(np.concatenate([labels.numpy() for _, labels in train_ds.unbatch().batch(BATCH_SIZE)]), axis=1)
class_weights = dict(enumerate(class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(CLASSES)),
    y=y_train_int
)))
print("✅ Computed class weights:", class_weights)
# Out:
# ✅ Computed class weights: {0: 0.9976947902259106, 1: 1.0065116279069768, 2: 0.9925087907047851, 3: 1.003400309119011}

# %%
# === Train ===
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[EarlyStopping(patience=4, restore_best_weights=True), LearningRateLogger()],
    class_weight=class_weights
)
# Out:
# Epoch 1/60
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0352s vs `on_train_batch_end` time: 0.0407s). Check your callbacks.
# 📉 Learning rate at epoch 1: 0.000010====] - ETA: 0s - loss: 0.7237 - accuracy: 0.7473
# 1623/1623 [==============================] - 221s 132ms/step - loss: 0.7237 - accuracy: 0.7473 - val_loss: 0.6260 - val_accuracy: 0.7985
# Epoch 2/60
# 📉 Learning rate at epoch 2: 0.000010====] - ETA: 0s - loss: 0.6514 - accuracy: 0.7893
# 1623/1623 [==============================] - 163s 101ms/step - loss: 0.6514 - accuracy: 0.7893 - val_loss: 0.6020 - val_accuracy: 0.8148
# Epoch 3/60
# 📉 Learning rate at epoch 3: 0.000010====] - ETA: 0s - loss: 0.6096 - accuracy: 0.8084
# 1623/1623 [==============================] - 157s 97ms/step - loss: 0.6096 - accuracy: 0.8084 - val_loss: 0.5499 - val_accuracy: 0.8383
# Epoch 4/60
# 📉 Learning rate at epoch 4: 0.000010====] - ETA: 0s - loss: 0.5841 - accuracy: 0.8253
# 1623/1623 [==============================] - 152s 93ms/step - loss: 0.5841 - accuracy: 0.8253 - val_loss: 0.5341 - val_accuracy: 0.8450
# Epoch 5/60
# 📉 Learning rate at epoch 5: 0.000010====] - ETA: 0s - loss: 0.5566 - accuracy: 0.8401
# 1623/1623 [==============================] - 154s 95ms/step - loss: 0.5566 - accuracy: 0.8401 - val_loss: 0.5194 - val_accuracy: 0.8574
# Epoch 6/60
# 📉 Learning rate at epoch 6: 0.000010====] - ETA: 0s - loss: 0.5392 - accuracy: 0.8510
# 1623/1623 [==============================] - 166s 102ms/step - loss: 0.5392 - accuracy: 0.8510 - val_loss: 0.5058 - val_accuracy: 0.8646
# Epoch 7/60
# 📉 Learning rate at epoch 7: 0.000010====] - ETA: 0s - loss: 0.5216 - accuracy: 0.8609
# 1623/1623 [==============================] - 166s 102ms/step - loss: 0.5216 - accuracy: 0.8609 - val_loss: 0.5209 - val_accuracy: 0.8564
# Epoch 8/60
# 📉 Learning rate at epoch 8: 0.000010====] - ETA: 0s - loss: 0.5110 - accuracy: 0.8637
# 1623/1623 [==============================] - 166s 102ms/step - loss: 0.5110 - accuracy: 0.8637 - val_loss: 0.4629 - val_accuracy: 0.8854
# Epoch 9/60
# 📉 Learning rate at epoch 9: 0.000010====] - ETA: 0s - loss: 0.4936 - accuracy: 0.8738
# 1623/1623 [==============================] - 163s 100ms/step - loss: 0.4936 - accuracy: 0.8738 - val_loss: 0.4642 - val_accuracy: 0.8835
# Epoch 10/60
# 📉 Learning rate at epoch 10: 0.000010===] - ETA: 0s - loss: 0.4836 - accuracy: 0.8769
# 1623/1623 [==============================] - 160s 99ms/step - loss: 0.4836 - accuracy: 0.8769 - val_loss: 0.4460 - val_accuracy: 0.8945
# Epoch 11/60
# 📉 Learning rate at epoch 11: 0.000010===] - ETA: 0s - loss: 0.4755 - accuracy: 0.8816
# 1623/1623 [==============================] - 171s 105ms/step - loss: 0.4755 - accuracy: 0.8816 - val_loss: 0.4466 - val_accuracy: 0.8948
# Epoch 12/60
# 📉 Learning rate at epoch 12: 0.000010===] - ETA: 0s - loss: 0.4631 - accuracy: 0.8903
# 1623/1623 [==============================] - 171s 105ms/step - loss: 0.4631 - accuracy: 0.8903 - val_loss: 0.4229 - val_accuracy: 0.9097
# Epoch 13/60
# 📉 Learning rate at epoch 13: 0.000010===] - ETA: 0s - loss: 0.4524 - accuracy: 0.8937
# 1623/1623 [==============================] - 170s 105ms/step - loss: 0.4524 - accuracy: 0.8937 - val_loss: 0.4280 - val_accuracy: 0.9047
# Epoch 14/60
# 📉 Learning rate at epoch 14: 0.000010===] - ETA: 0s - loss: 0.4463 - accuracy: 0.8966
# 1623/1623 [==============================] - 166s 102ms/step - loss: 0.4463 - accuracy: 0.8966 - val_loss: 0.4253 - val_accuracy: 0.9039
# Epoch 15/60
# 📉 Learning rate at epoch 15: 0.000010===] - ETA: 0s - loss: 0.4358 - accuracy: 0.8993
# 1623/1623 [==============================] - 171s 105ms/step - loss: 0.4358 - accuracy: 0.8993 - val_loss: 0.4160 - val_accuracy: 0.9071
# Epoch 16/60
# 📉 Learning rate at epoch 16: 0.000010===] - ETA: 0s - loss: 0.4313 - accuracy: 0.9022
# 1623/1623 [==============================] - 170s 104ms/step - loss: 0.4313 - accuracy: 0.9022 - val_loss: 0.4179 - val_accuracy: 0.9013
# Epoch 17/60
# 📉 Learning rate at epoch 17: 0.000010===] - ETA: 0s - loss: 0.4242 - accuracy: 0.9076
# 1623/1623 [==============================] - 170s 105ms/step - loss: 0.4242 - accuracy: 0.9076 - val_loss: 0.3815 - val_accuracy: 0.9231
# Epoch 18/60
# 📉 Learning rate at epoch 18: 0.000010===] - ETA: 0s - loss: 0.4170 - accuracy: 0.9099
# 1623/1623 [==============================] - 169s 104ms/step - loss: 0.4170 - accuracy: 0.9099 - val_loss: 0.4013 - val_accuracy: 0.9154
# Epoch 19/60
# 📉 Learning rate at epoch 19: 0.000010===] - ETA: 0s - loss: 0.4109 - accuracy: 0.9123
# 1623/1623 [==============================] - 168s 103ms/step - loss: 0.4109 - accuracy: 0.9123 - val_loss: 0.3970 - val_accuracy: 0.9162
# Epoch 20/60
# 📉 Learning rate at epoch 20: 0.000010===] - ETA: 0s - loss: 0.4042 - accuracy: 0.9164
# 1623/1623 [==============================] - 168s 103ms/step - loss: 0.4042 - accuracy: 0.9164 - val_loss: 0.3887 - val_accuracy: 0.9190
# Epoch 21/60
# 📉 Learning rate at epoch 21: 0.000010===] - ETA: 0s - loss: 0.3995 - accuracy: 0.9177
# 1623/1623 [==============================] - 170s 105ms/step - loss: 0.3995 - accuracy: 0.9177 - val_loss: 0.3745 - val_accuracy: 0.9245
# Epoch 22/60
# 📉 Learning rate at epoch 22: 0.000010===] - ETA: 0s - loss: 0.3922 - accuracy: 0.9224
# 1623/1623 [==============================] - 157s 97ms/step - loss: 0.3922 - accuracy: 0.9224 - val_loss: 0.3824 - val_accuracy: 0.9261
# Epoch 23/60
# 📉 Learning rate at epoch 23: 0.000010===] - ETA: 0s - loss: 0.3896 - accuracy: 0.9232
# 1623/1623 [==============================] - 165s 102ms/step - loss: 0.3896 - accuracy: 0.9232 - val_loss: 0.3585 - val_accuracy: 0.9327
# Epoch 24/60
# 📉 Learning rate at epoch 24: 0.000010===] - ETA: 0s - loss: 0.3885 - accuracy: 0.9265
# 1623/1623 [==============================] - 186s 114ms/step - loss: 0.3885 - accuracy: 0.9265 - val_loss: 0.3593 - val_accuracy: 0.9336
# Epoch 25/60
# 📉 Learning rate at epoch 25: 0.000010===] - ETA: 0s - loss: 0.3749 - accuracy: 0.9303
# 1623/1623 [==============================] - 188s 116ms/step - loss: 0.3749 - accuracy: 0.9303 - val_loss: 0.3599 - val_accuracy: 0.9336
# Epoch 26/60
# 📉 Learning rate at epoch 26: 0.000010===] - ETA: 0s - loss: 0.3734 - accuracy: 0.9308
# 1623/1623 [==============================] - 174s 107ms/step - loss: 0.3734 - accuracy: 0.9308 - val_loss: 0.3437 - val_accuracy: 0.9401
# Epoch 27/60
# 📉 Learning rate at epoch 27: 0.000010===] - ETA: 0s - loss: 0.3718 - accuracy: 0.9341
# 1623/1623 [==============================] - 175s 108ms/step - loss: 0.3718 - accuracy: 0.9341 - val_loss: 0.3493 - val_accuracy: 0.9382
# Epoch 28/60
# 📉 Learning rate at epoch 28: 0.000010===] - ETA: 0s - loss: 0.3677 - accuracy: 0.9340
# 1623/1623 [==============================] - 176s 109ms/step - loss: 0.3677 - accuracy: 0.9340 - val_loss: 0.3373 - val_accuracy: 0.9456
# Epoch 29/60
# 📉 Learning rate at epoch 29: 0.000010===] - ETA: 0s - loss: 0.3622 - accuracy: 0.9353
# 1623/1623 [==============================] - 162s 99ms/step - loss: 0.3622 - accuracy: 0.9353 - val_loss: 0.3326 - val_accuracy: 0.9469
# Epoch 30/60
# 📉 Learning rate at epoch 30: 0.000010===] - ETA: 0s - loss: 0.3591 - accuracy: 0.9364
# 1623/1623 [==============================] - 175s 108ms/step - loss: 0.3591 - accuracy: 0.9364 - val_loss: 0.3447 - val_accuracy: 0.9393
# Epoch 31/60
# 📉 Learning rate at epoch 31: 0.000010===] - ETA: 0s - loss: 0.3549 - accuracy: 0.9380
# 1623/1623 [==============================] - 173s 107ms/step - loss: 0.3549 - accuracy: 0.9380 - val_loss: 0.3484 - val_accuracy: 0.9339
# Epoch 32/60
# 📉 Learning rate at epoch 32: 0.000010===] - ETA: 0s - loss: 0.3539 - accuracy: 0.9395
# 1623/1623 [==============================] - 163s 100ms/step - loss: 0.3539 - accuracy: 0.9395 - val_loss: 0.3270 - val_accuracy: 0.9479
# Epoch 33/60
# 📉 Learning rate at epoch 33: 0.000010===] - ETA: 0s - loss: 0.3443 - accuracy: 0.9444
# 1623/1623 [==============================] - 163s 101ms/step - loss: 0.3443 - accuracy: 0.9444 - val_loss: 0.3206 - val_accuracy: 0.9490
# Epoch 34/60
# 📉 Learning rate at epoch 34: 0.000010===] - ETA: 0s - loss: 0.3431 - accuracy: 0.9448
# 1623/1623 [==============================] - 162s 100ms/step - loss: 0.3431 - accuracy: 0.9448 - val_loss: 0.3133 - val_accuracy: 0.9567
# Epoch 35/60
# 📉 Learning rate at epoch 35: 0.000010===] - ETA: 0s - loss: 0.3402 - accuracy: 0.9466
# 1623/1623 [==============================] - 159s 98ms/step - loss: 0.3402 - accuracy: 0.9466 - val_loss: 0.3237 - val_accuracy: 0.9481
# Epoch 36/60
# 📉 Learning rate at epoch 36: 0.000010===] - ETA: 0s - loss: 0.3385 - accuracy: 0.9465
# 1623/1623 [==============================] - 158s 97ms/step - loss: 0.3385 - accuracy: 0.9465 - val_loss: 0.3054 - val_accuracy: 0.9576
# Epoch 37/60
# 📉 Learning rate at epoch 37: 0.000010===] - ETA: 0s - loss: 0.3322 - accuracy: 0.9484
# 1623/1623 [==============================] - 165s 102ms/step - loss: 0.3322 - accuracy: 0.9484 - val_loss: 0.3079 - val_accuracy: 0.9563
# Epoch 38/60
# 📉 Learning rate at epoch 38: 0.000010===] - ETA: 0s - loss: 0.3309 - accuracy: 0.9497
# 1623/1623 [==============================] - 164s 101ms/step - loss: 0.3309 - accuracy: 0.9497 - val_loss: 0.3095 - val_accuracy: 0.9549
# Epoch 39/60
# 📉 Learning rate at epoch 39: 0.000010===] - ETA: 0s - loss: 0.3280 - accuracy: 0.9512
# 1623/1623 [==============================] - 166s 102ms/step - loss: 0.3280 - accuracy: 0.9512 - val_loss: 0.3029 - val_accuracy: 0.9579
# Epoch 40/60
# 📉 Learning rate at epoch 40: 0.000010===] - ETA: 0s - loss: 0.3230 - accuracy: 0.9545
# 1623/1623 [==============================] - 163s 101ms/step - loss: 0.3230 - accuracy: 0.9545 - val_loss: 0.2967 - val_accuracy: 0.9641
# Epoch 41/60
# 📉 Learning rate at epoch 41: 0.000010===] - ETA: 0s - loss: 0.3211 - accuracy: 0.9542
# 1623/1623 [==============================] - 166s 102ms/step - loss: 0.3211 - accuracy: 0.9542 - val_loss: 0.2931 - val_accuracy: 0.9623
# Epoch 42/60
# 📉 Learning rate at epoch 42: 0.000010===] - ETA: 0s - loss: 0.3199 - accuracy: 0.9536
# 1623/1623 [==============================] - 164s 101ms/step - loss: 0.3199 - accuracy: 0.9536 - val_loss: 0.2947 - val_accuracy: 0.9618
# Epoch 43/60
# 📉 Learning rate at epoch 43: 0.000010===] - ETA: 0s - loss: 0.3145 - accuracy: 0.9569
# 1623/1623 [==============================] - 161s 99ms/step - loss: 0.3145 - accuracy: 0.9569 - val_loss: 0.3035 - val_accuracy: 0.9593
# Epoch 44/60
# 📉 Learning rate at epoch 44: 0.000010===] - ETA: 0s - loss: 0.3122 - accuracy: 0.9564
# 1623/1623 [==============================] - 164s 101ms/step - loss: 0.3122 - accuracy: 0.9564 - val_loss: 0.2907 - val_accuracy: 0.9655
# Epoch 45/60
# 📉 Learning rate at epoch 45: 0.000010===] - ETA: 0s - loss: 0.3110 - accuracy: 0.9594
# 1623/1623 [==============================] - 169s 104ms/step - loss: 0.3110 - accuracy: 0.9594 - val_loss: 0.3044 - val_accuracy: 0.9593
# Epoch 46/60
# 📉 Learning rate at epoch 46: 0.000010===] - ETA: 0s - loss: 0.3089 - accuracy: 0.9595
# 1623/1623 [==============================] - 164s 101ms/step - loss: 0.3089 - accuracy: 0.9595 - val_loss: 0.2935 - val_accuracy: 0.9630
# Epoch 47/60
# 📉 Learning rate at epoch 47: 0.000010===] - ETA: 0s - loss: 0.3045 - accuracy: 0.9623
# 1623/1623 [==============================] - 150s 92ms/step - loss: 0.3045 - accuracy: 0.9623 - val_loss: 0.2852 - val_accuracy: 0.9692
# Epoch 48/60
# 📉 Learning rate at epoch 48: 0.000010===] - ETA: 0s - loss: 0.3008 - accuracy: 0.9636
# 1623/1623 [==============================] - 150s 92ms/step - loss: 0.3008 - accuracy: 0.9636 - val_loss: 0.2863 - val_accuracy: 0.9673
# Epoch 49/60
# 📉 Learning rate at epoch 49: 0.000010===] - ETA: 0s - loss: 0.3022 - accuracy: 0.9616
# 1623/1623 [==============================] - 149s 92ms/step - loss: 0.3022 - accuracy: 0.9616 - val_loss: 0.2971 - val_accuracy: 0.9604
# Epoch 50/60
# 📉 Learning rate at epoch 50: 0.000010===] - ETA: 0s - loss: 0.2961 - accuracy: 0.9650
# 1623/1623 [==============================] - 149s 92ms/step - loss: 0.2961 - accuracy: 0.9650 - val_loss: 0.2790 - val_accuracy: 0.9680
# Epoch 51/60
# 📉 Learning rate at epoch 51: 0.000010===] - ETA: 0s - loss: 0.2970 - accuracy: 0.9640
# 1623/1623 [==============================] - 149s 92ms/step - loss: 0.2970 - accuracy: 0.9640 - val_loss: 0.2880 - val_accuracy: 0.9661
# Epoch 52/60
# 📉 Learning rate at epoch 52: 0.000010===] - ETA: 0s - loss: 0.2928 - accuracy: 0.9682
# 1623/1623 [==============================] - 149s 92ms/step - loss: 0.2928 - accuracy: 0.9682 - val_loss: 0.2843 - val_accuracy: 0.9687
# Epoch 53/60
# 📉 Learning rate at epoch 53: 0.000010===] - ETA: 0s - loss: 0.2927 - accuracy: 0.9670
# 1623/1623 [==============================] - 154s 95ms/step - loss: 0.2927 - accuracy: 0.9670 - val_loss: 0.2773 - val_accuracy: 0.9726
# Epoch 54/60
# 📉 Learning rate at epoch 54: 0.000010===] - ETA: 0s - loss: 0.2894 - accuracy: 0.9668
# 1623/1623 [==============================] - 161s 99ms/step - loss: 0.2894 - accuracy: 0.9668 - val_loss: 0.2861 - val_accuracy: 0.9686
# Epoch 55/60
# 📉 Learning rate at epoch 55: 0.000010===] - ETA: 0s - loss: 0.2876 - accuracy: 0.9689
# 1623/1623 [==============================] - 163s 100ms/step - loss: 0.2876 - accuracy: 0.9689 - val_loss: 0.2720 - val_accuracy: 0.9726
# Epoch 56/60
# 📉 Learning rate at epoch 56: 0.000010===] - ETA: 0s - loss: 0.2832 - accuracy: 0.9698
# 1623/1623 [==============================] - 188s 116ms/step - loss: 0.2832 - accuracy: 0.9698 - val_loss: 0.2709 - val_accuracy: 0.9732
# Epoch 57/60
# 📉 Learning rate at epoch 57: 0.000010===] - ETA: 0s - loss: 0.2826 - accuracy: 0.9717
# 1623/1623 [==============================] - 152s 94ms/step - loss: 0.2826 - accuracy: 0.9717 - val_loss: 0.2631 - val_accuracy: 0.9764
# Epoch 58/60
# 📉 Learning rate at epoch 58: 0.000010===] - ETA: 0s - loss: 0.2834 - accuracy: 0.9704
# 1623/1623 [==============================] - 156s 96ms/step - loss: 0.2834 - accuracy: 0.9704 - val_loss: 0.2662 - val_accuracy: 0.9763
# Epoch 59/60
# 📉 Learning rate at epoch 59: 0.000010===] - ETA: 0s - loss: 0.2783 - accuracy: 0.9729
# 1623/1623 [==============================] - 151s 93ms/step - loss: 0.2783 - accuracy: 0.9729 - val_loss: 0.2611 - val_accuracy: 0.9784
# Epoch 60/60
# 📉 Learning rate at epoch 60: 0.000010===] - ETA: 0s - loss: 0.2763 - accuracy: 0.9737
# 1623/1623 [==============================] - 151s 93ms/step - loss: 0.2763 - accuracy: 0.9737 - val_loss: 0.2712 - val_accuracy: 0.9727

# %%
# === Evaluate ===
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=CLASSES).plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# === Save ===
SAVE_PATH = r"C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\Faulty_MobileNetV3_Phase2.h5"
model.save(SAVE_PATH)
print(f"✅ Model saved at: {SAVE_PATH}")
# Out:
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       BLIGHT       1.00      1.00      1.00      1556
#        BLAST       0.99      0.94      0.96      1666
#    BROWNSPOT       0.99      0.96      0.98      1635
#      HEALTHY       0.92      0.99      0.96      1635
#
#     accuracy                           0.97      6492
#    macro avg       0.97      0.97      0.97      6492
# weighted avg       0.97      0.97      0.97      6492
# ✅ Model saved at: C:\Users\ADITYA DAS\Desktop\Machine Learning\CP_MODEL\Faulty_MobileNetV3_Phase2.h5
